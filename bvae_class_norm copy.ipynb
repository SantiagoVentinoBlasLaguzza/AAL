# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Set paths
project_dir = '/home/diego/Escritorio/azheimer/'  # Adjust to your path
csv_path = os.path.join(project_dir, 'DataBaseSubjects.csv')
tensor_data_dir = os.path.join(project_dir, 'TensorData')

# Load the CSV file
subjects_df = pd.read_csv(csv_path)

# Calculate the median age and print it
median_age = subjects_df['Age'].median()
print(f"Median Age: {median_age}")

# Plot the age distribution
plt.figure(figsize=(8, 6))
sns.histplot(subjects_df['Age'], bins=20, kde=True, color='blue')
plt.axvline(median_age, color='red', linestyle='--', label=f'Median Age: {median_age}')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Plot the sex distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Plot the distribution of AD, CN, and Others
plt.figure(figsize=(8, 6))
sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
plt.title('AD, CN, and Others Distribution')
plt.xlabel('Research Group')
plt.ylabel('Count')
plt.show()

# Group subjects by Research Group and Sex
grouped_data = subjects_df.groupby(['ResearchGroup', 'Sex']).size().unstack().fillna(0)
print(grouped_data)

# Initialize dictionaries for storing tensor paths by group and sex
tensor_groups = {
    'AD_men': [],
    'AD_women': [],
    'CN_men': [],
    'CN_women': [],
    'Other_men': [],
    'Other_women': []
}

# Iterate over subjects and assign tensors to groups
for subject_id in subjects_df['SubjectID']:
    group = subjects_df[subjects_df['SubjectID'] == subject_id]['ResearchGroup'].values[0]
    sex = subjects_df[subjects_df['SubjectID'] == subject_id]['Sex'].values[0]
    file_name = f'{group}_tensor_{subject_id}.pt'
    file_path = os.path.join(tensor_data_dir, file_name)
    
    if os.path.exists(file_path):
        if group == 'AD':
            if sex == 'M':
                tensor_groups['AD_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['AD_women'].append(file_path)
        elif group == 'CN':
            if sex == 'M':
                tensor_groups['CN_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['CN_women'].append(file_path)
        else:  # Others
            if sex == 'M':
                tensor_groups['Other_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['Other_women'].append(file_path)

# Print the number of subjects in each group
for key, value in tensor_groups.items():
    print(f'{key}: {len(value)} subjects')

# Split data into train, validation, and test sets with equal proportions
def split_data(tensors, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    np.random.shuffle(tensors)
    n_total = len(tensors)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    
    train_set = tensors[:n_train]
    val_set = tensors[n_train:n_train + n_val]
    test_set = tensors[n_train + n_val:]
    
    return train_set, val_set, test_set

# Initialize lists for train, validation, and test sets
train_set, val_set, test_set = [], [], []

# Combine groups ensuring equal proportions of gender and research groups
for group in tensor_groups:
    train, val, test = split_data(tensor_groups[group])
    train_set.extend(train)
    val_set.extend(val)
    test_set.extend(test)

# Print final counts of train, validation, and test sets
print(f"Train set: {len(train_set)} subjects")
print(f"Validation set: {len(val_set)} subjects")
print(f"Test set: {len(test_set)} subjects")
# Out:
# Median Age: 74.25
# /tmp/ipykernel_69013/3646991604.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
# /tmp/ipykernel_69013/3646991604.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
# Sex             F   M
# ResearchGroup
# AD             40  55
# CN             52  37
# EMCI            8  10
# LMCI           23  32
# MCI            42  53
# AD_men: 55 subjects
# AD_women: 40 subjects
# CN_men: 37 subjects
# CN_women: 52 subjects
# Other_men: 95 subjects
# Other_women: 73 subjects
# Train set: 244 subjects
# Validation set: 50 subjects
# Test set: 58 subjects

# %%
# Function to normalize each channel of the tensor between 0 and 1
def normalize_tensor(tensor):
    normalized_tensor = torch.zeros_like(tensor)
    for i in range(tensor.shape[0]):  # For each channel
        channel_data = tensor[i]
        min_val = channel_data.min()
        max_val = channel_data.max()
        # Avoid division by zero
        if max_val - min_val != 0:
            normalized_tensor[i] = (channel_data - min_val) / (max_val - min_val)
        else:
            normalized_tensor[i] = channel_data - min_val
    return normalized_tensor

# %%
# Load the tensors and create datasets
def load_tensors(file_paths):
    tensors = []
    for fp in file_paths:
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        #data = normalize_tensor(data)
        tensors.append(data)
    return torch.stack(tensors)


# Load data for train, validation, and test sets
train_data = load_tensors(train_set)

# Function to compute mean and std for each channel
def compute_mean_std(dataset):
    # dataset is a Tensor of shape (N_samples, Channels, Height, Width)
    mean = dataset.mean(dim=(0, 2, 3))
    std = dataset.std(dim=(0, 2, 3))
    return mean, std

# Compute mean and std from training data
train_mean, train_std = compute_mean_std(train_data)

val_data = load_tensors(val_set)
test_data = load_tensors(test_set)

print(f"Train Mean: {train_mean}")
print(f"Train Std: {train_std}")

# Function to normalize dataset using computed mean and std
def normalize_dataset(dataset, mean, std):
    # Subtract mean and divide by std for each channel
    return (dataset - mean[None, :, None, None]) / std[None, :, None, None]

# Normalize datasets
train_data = normalize_dataset(train_data, train_mean, train_std)
val_data = normalize_dataset(val_data, train_mean, train_std)
test_data = normalize_dataset(test_data, train_mean, train_std)

# Print final dataset shapes
print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")

import torch

# Assuming train_set, val_set, test_set are your datasets (could be PyTorch Datasets or DataLoaders)
torch.save(train_data, 'sets/train_set.pt')
torch.save(val_data, 'sets/val_set.pt')
torch.save(test_data, 'sets/test_set.pt')
# Out:
# Train Mean: tensor([0.3380, 0.3244, 3.1163], dtype=torch.float64)
# Train Std: tensor([0.2674, 0.1893, 3.9580], dtype=torch.float64)
# Train data shape: torch.Size([244, 3, 116, 116])
# Validation data shape: torch.Size([50, 3, 116, 116])
# Test data shape: torch.Size([58, 3, 116, 116])

# %%
import random
import matplotlib.pyplot as plt

# Function to plot the three matrices for a given subject's tensor
def plot_matrices(tensor, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    matrix_titles = ['Correlation Matrix', 'Mutual Information Matrix', 'Granger Causality Matrix']

    # Loop through the three matrices
    for i in range(3):
        ax = axes[i]
        cax = ax.matshow(tensor[i], cmap='viridis')
        fig.colorbar(cax, ax=ax)
        ax.set_title(f'{title_prefix} - {matrix_titles[i]}')
        ax.set_xlabel('ROIs')
        ax.set_ylabel('ROIs')

    plt.tight_layout()
    plt.show()

# Choose a random subject from each dataset and plot their matrices
def plot_random_subject_from_dataset(dataset, dataset_name):
    random_subject = random.choice(dataset)
    print(f"Plotting matrices for a random subject from {dataset_name} dataset: {random_subject}")
    
    # Load the tensor for the randomly selected subject
    tensor = torch.load(random_subject)
    
    # Plot the matrices
    plot_matrices(tensor, dataset_name)

# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_set, 'Train')
plot_random_subject_from_dataset(val_set, 'Validation')
plot_random_subject_from_dataset(test_set, 'Test')
# Out:
# Plotting matrices for a random subject from Train dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_129_S_6763.pt
# Plotting matrices for a random subject from Validation dataset: /home/diego/Escritorio/azheimer/TensorData/LMCI_tensor_130_S_4925.pt
# Plotting matrices for a random subject from Test dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_082_S_6690.pt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch.nn as nn
import torch.nn.functional as F

class ConvVAE(nn.Module):
    def __init__(self, latent_dim=30, hidden_dim=2048):
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim
        self.dropout_rate = 0.2

        # Encoder Layers
        self.enc_conv1 = nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1)
        self.enc_bn1 = nn.BatchNorm2d(64)
        self.enc_conv2 = nn.Conv2d(64, 128, 4, 2, 1)
        self.enc_bn2 = nn.BatchNorm2d(128)
        self.enc_conv3 = nn.Conv2d(128, 256, 4, 2, 1)
        self.enc_bn3 = nn.BatchNorm2d(256)
        self.enc_conv4 = nn.Conv2d(256, 512, 4, 2, 1)
        self.enc_bn4 = nn.BatchNorm2d(512)
        self.enc_conv5 = nn.Conv2d(512, 512, 4, 2, 1)
        self.enc_bn5 = nn.BatchNorm2d(512)

        self.flatten_size = 512 * 3 * 3

        self.fc1 = nn.Linear(self.flatten_size, self.hidden_dim)
        self.fc_bn1 = nn.BatchNorm1d(self.hidden_dim)
        self.fc2 = nn.Linear(self.hidden_dim, self.hidden_dim)
        self.fc_bn2 = nn.BatchNorm1d(self.hidden_dim)

        self.fc_mu = nn.Linear(self.hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(self.hidden_dim, latent_dim)

        # Decoder Layers
        self.fc_decode = nn.Linear(latent_dim, self.hidden_dim)
        self.fc_bn3 = nn.BatchNorm1d(self.hidden_dim)
        self.fc_decode2 = nn.Linear(self.hidden_dim, self.hidden_dim)
        self.fc_bn4 = nn.BatchNorm1d(self.hidden_dim)
        self.fc_decode3 = nn.Linear(self.hidden_dim, self.flatten_size)

        self.dec_conv1 = nn.ConvTranspose2d(512, 512, 4, 2, 1)
        self.dec_bn1 = nn.BatchNorm2d(512)
        self.dec_conv2 = nn.ConvTranspose2d(512, 256, 4, 2, 1)
        self.dec_bn2 = nn.BatchNorm2d(256)
        self.dec_conv3 = nn.ConvTranspose2d(256, 128, 4, 2, 1)
        self.dec_bn3 = nn.BatchNorm2d(128)
        self.dec_conv4 = nn.ConvTranspose2d(128, 64, 4, 2, 1)
        self.dec_bn4 = nn.BatchNorm2d(64)
        self.dec_conv5 = nn.ConvTranspose2d(64, 3, 4, 2, 1)

        self.output_padding = nn.ReflectionPad2d((-5, -6, -5, -6))

        self.dropout = nn.Dropout(self.dropout_rate)

    def encode(self, x):
        x = F.relu(self.enc_bn1(self.enc_conv1(x)))
        x = F.relu(self.enc_bn2(self.enc_conv2(x)))
        x = F.relu(self.enc_bn3(self.enc_conv3(x)))
        x = F.relu(self.enc_bn4(self.enc_conv4(x)))
        x = F.relu(self.enc_bn5(self.enc_conv5(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc_bn1(self.fc1(x)))
        x = self.dropout(x)
        x = F.relu(self.fc_bn2(self.fc2(x)))
        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        return mu, logvar

    def decode(self, z):
        x = F.relu(self.fc_bn3(self.fc_decode(z)))
        x = F.relu(self.fc_bn4(self.fc_decode2(x)))
        x = F.relu(self.fc_decode3(x))
        x = x.view(z.size(0), 512, 3, 3)
        x = F.relu(self.dec_bn1(self.dec_conv1(x)))
        x = F.relu(self.dec_bn2(self.dec_conv2(x)))
        x = F.relu(self.dec_bn3(self.dec_conv3(x)))
        x = F.relu(self.dec_bn4(self.dec_conv4(x)))
        x = torch.sigmoid(self.dec_conv5(x))
        x = F.interpolate(x, size=(116, 116), mode='bilinear', align_corners=False)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar, z

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

# %%
def loss_function(recon_x, x, mu, logvar, beta=1):
    # Reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='mean')

    # KL Divergence (normalized per batch)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    KLD = KLD / x.size(0)  # Normalize KLD per batch

    # Total loss
    total_loss = recon_loss + beta * KLD

    return total_loss, recon_loss.item(), KLD.item()

# %%
from torch.utils.data import Dataset, DataLoader

class CustomTensorDataset(Dataset):
    def __init__(self, file_paths):
        self.file_paths = file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        fp = self.file_paths[idx]
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        # Extract the label from the file name
        file_name = os.path.basename(fp)
        # Expected format: '{group}_tensor_{subject_id}.pt'
        group = file_name.split('_')[0]
        # Map group to labels
        if group in ['AD', 'CN']:
            label = group
        else:
            label = 'Others'
        return data, label

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create datasets
train_dataset = TensorDataset(train_data)
val_dataset = TensorDataset(val_data)
# Create the test dataset with labels
test_dataset = CustomTensorDataset(test_set)

# Create data loaders
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False,num_workers=4)
# Create the data loader
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False,num_workers=4)

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize model
latent_dim = 30  # You can adjust the size of the latent space
hidden_dim= 1024*2  # Hidden dimension for the linear layers
model = ConvVAE(latent_dim=latent_dim).to(device)

# Optimizer with L2 regularization (weight decay)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-6)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
# Out:
# Using device: cuda

# %%
# Early stopping parameters
early_stopping_patience = 20
best_val_loss = float('inf')
epochs_without_improvement = 0
model_save_path = os.path.join(project_dir, 'best_beta_vae_model.pth')

# %%
# Lists to store losses
train_total_losses = []
val_total_losses = []
train_recon_losses = []
train_kld_losses = []

num_epochs = 500  # Adjust the number of epochs as needed
beta = 2  # Set the beta value for the loss function

for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0
    train_recon_loss = 0
    train_kld_loss = 0

    for data in train_loader:
        x = data[0].to(device, dtype=torch.float)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar, _ = model(x)
        loss, recon_loss, kld_loss = loss_function(recon_batch, x, mu, logvar, beta=beta)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * x.size(0)  # Multiply by batch size
        train_recon_loss += recon_loss * x.size(0)
        train_kld_loss += kld_loss * x.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_recon_loss = train_recon_loss / len(train_loader.dataset)
    avg_train_kld_loss = train_kld_loss / len(train_loader.dataset)

    train_total_losses.append(avg_train_loss)
    train_recon_losses.append(avg_train_recon_loss)
    train_kld_losses.append(avg_train_kld_loss)
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data in val_loader:
            x = data[0].to(device, dtype=torch.float)
            recon_batch, mu, logvar, _ = model(x)
            loss, _, _ = loss_function(recon_batch, x, mu, logvar, beta=beta)
            val_loss += loss.item() * x.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_total_losses.append(avg_val_loss)
    
    print(f"Epoch {epoch}, Average Training Loss: {avg_train_loss:.6f}, Average Validation Loss: {avg_val_loss:.6f}")
    
    # Step the scheduler
    scheduler.step(avg_val_loss)
    
    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        # Save the model
        torch.save(model.state_dict(), model_save_path)
        print(f"Validation loss improved. Model saved to {model_save_path}")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= early_stopping_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1, Average Training Loss: 6.953903, Average Validation Loss: 1.306893
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 2, Average Training Loss: 7.131731, Average Validation Loss: 1.448731
# Epoch 3, Average Training Loss: 4.570905, Average Validation Loss: 1.569697
# Epoch 4, Average Training Loss: 3.451728, Average Validation Loss: 1.865655
# Epoch 5, Average Training Loss: 2.844938, Average Validation Loss: 1.834566
# Epoch 6, Average Training Loss: 2.320090, Average Validation Loss: 1.648178
# Epoch 7, Average Training Loss: 1.994373, Average Validation Loss: 1.460879
# Epoch 00007: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 8, Average Training Loss: 1.767980, Average Validation Loss: 1.212713
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 9, Average Training Loss: 1.630562, Average Validation Loss: 1.142804
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 10, Average Training Loss: 1.541223, Average Validation Loss: 1.108131
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 11, Average Training Loss: 1.525281, Average Validation Loss: 1.080255
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 12, Average Training Loss: 1.421365, Average Validation Loss: 1.050663
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 13, Average Training Loss: 1.387143, Average Validation Loss: 1.030354
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 14, Average Training Loss: 1.389127, Average Validation Loss: 1.024354
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 15, Average Training Loss: 1.312130, Average Validation Loss: 1.005887
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 16, Average Training Loss: 1.318304, Average Validation Loss: 0.995281
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 17, Average Training Loss: 1.263580, Average Validation Loss: 0.977329
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 18, Average Training Loss: 1.226900, Average Validation Loss: 0.967979
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 19, Average Training Loss: 1.214827, Average Validation Loss: 0.961881
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 20, Average Training Loss: 1.216832, Average Validation Loss: 0.958854
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 21, Average Training Loss: 1.178873, Average Validation Loss: 0.949414
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 22, Average Training Loss: 1.193372, Average Validation Loss: 0.942495
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 23, Average Training Loss: 1.161825, Average Validation Loss: 0.936736
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 24, Average Training Loss: 1.166317, Average Validation Loss: 0.934934
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 25, Average Training Loss: 1.124349, Average Validation Loss: 0.929566
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 26, Average Training Loss: 1.117151, Average Validation Loss: 0.925514
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 27, Average Training Loss: 1.099116, Average Validation Loss: 0.921140
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 28, Average Training Loss: 1.091710, Average Validation Loss: 0.915863
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 29, Average Training Loss: 1.092619, Average Validation Loss: 0.910696
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 30, Average Training Loss: 1.085840, Average Validation Loss: 0.909464
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 31, Average Training Loss: 1.070718, Average Validation Loss: 0.907428
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 32, Average Training Loss: 1.059212, Average Validation Loss: 0.903953
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 33, Average Training Loss: 1.072738, Average Validation Loss: 0.905394
# Epoch 34, Average Training Loss: 1.059556, Average Validation Loss: 0.901011
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 35, Average Training Loss: 1.058177, Average Validation Loss: 0.896196
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 36, Average Training Loss: 1.053608, Average Validation Loss: 0.895989
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 37, Average Training Loss: 1.053910, Average Validation Loss: 0.893958
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 38, Average Training Loss: 1.064585, Average Validation Loss: 0.893069
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 39, Average Training Loss: 1.039288, Average Validation Loss: 0.891583
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 40, Average Training Loss: 1.051263, Average Validation Loss: 0.888186
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 41, Average Training Loss: 1.021653, Average Validation Loss: 0.888481
# Epoch 42, Average Training Loss: 1.026478, Average Validation Loss: 0.884762
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 43, Average Training Loss: 1.013931, Average Validation Loss: 0.884535
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 44, Average Training Loss: 1.019214, Average Validation Loss: 0.884038
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 45, Average Training Loss: 1.005990, Average Validation Loss: 0.881983
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 46, Average Training Loss: 1.025779, Average Validation Loss: 0.881673
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 47, Average Training Loss: 1.006554, Average Validation Loss: 0.879849
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 48, Average Training Loss: 0.992773, Average Validation Loss: 0.877943
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 49, Average Training Loss: 0.999840, Average Validation Loss: 0.877542
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 50, Average Training Loss: 1.001115, Average Validation Loss: 0.875769
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 51, Average Training Loss: 1.011005, Average Validation Loss: 0.874983
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 52, Average Training Loss: 1.010939, Average Validation Loss: 0.874089
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 53, Average Training Loss: 1.003719, Average Validation Loss: 0.872113
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 54, Average Training Loss: 0.986411, Average Validation Loss: 0.870646
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 55, Average Training Loss: 0.983527, Average Validation Loss: 0.871001
# Epoch 56, Average Training Loss: 0.983652, Average Validation Loss: 0.870613
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 57, Average Training Loss: 0.988809, Average Validation Loss: 0.868882
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 58, Average Training Loss: 0.980906, Average Validation Loss: 0.868193
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 59, Average Training Loss: 0.981105, Average Validation Loss: 0.867886
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 60, Average Training Loss: 0.989267, Average Validation Loss: 0.868432
# Epoch 61, Average Training Loss: 0.990702, Average Validation Loss: 0.866252
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 62, Average Training Loss: 0.988953, Average Validation Loss: 0.866259
# Epoch 63, Average Training Loss: 0.985357, Average Validation Loss: 0.866245
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 64, Average Training Loss: 0.965580, Average Validation Loss: 0.865315
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 65, Average Training Loss: 0.965514, Average Validation Loss: 0.864309
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 66, Average Training Loss: 0.982858, Average Validation Loss: 0.864795
# Epoch 67, Average Training Loss: 0.963727, Average Validation Loss: 0.863549
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 68, Average Training Loss: 0.969858, Average Validation Loss: 0.862289
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 69, Average Training Loss: 0.965804, Average Validation Loss: 0.861263
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 70, Average Training Loss: 0.971144, Average Validation Loss: 0.860155
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 71, Average Training Loss: 0.957852, Average Validation Loss: 0.860067
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 72, Average Training Loss: 0.964925, Average Validation Loss: 0.860468
# Epoch 73, Average Training Loss: 0.958819, Average Validation Loss: 0.860090
# Epoch 74, Average Training Loss: 0.963548, Average Validation Loss: 0.859650
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 75, Average Training Loss: 0.964433, Average Validation Loss: 0.859900
# Epoch 76, Average Training Loss: 0.962683, Average Validation Loss: 0.859071
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 77, Average Training Loss: 0.951814, Average Validation Loss: 0.858347
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 78, Average Training Loss: 0.955321, Average Validation Loss: 0.858747
# Epoch 79, Average Training Loss: 0.958904, Average Validation Loss: 0.858041
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 80, Average Training Loss: 0.952415, Average Validation Loss: 0.857385
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 81, Average Training Loss: 0.946816, Average Validation Loss: 0.857210
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 82, Average Training Loss: 0.950656, Average Validation Loss: 0.856855
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 83, Average Training Loss: 0.961769, Average Validation Loss: 0.856480
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 84, Average Training Loss: 0.953297, Average Validation Loss: 0.856136
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 85, Average Training Loss: 0.953084, Average Validation Loss: 0.855729
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 86, Average Training Loss: 0.950422, Average Validation Loss: 0.854636
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 87, Average Training Loss: 0.952475, Average Validation Loss: 0.854562
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 88, Average Training Loss: 0.942328, Average Validation Loss: 0.854313
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 89, Average Training Loss: 0.939449, Average Validation Loss: 0.853799
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 90, Average Training Loss: 0.940133, Average Validation Loss: 0.853264
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 91, Average Training Loss: 0.941347, Average Validation Loss: 0.853262
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 92, Average Training Loss: 0.945250, Average Validation Loss: 0.852661
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 93, Average Training Loss: 0.943055, Average Validation Loss: 0.853229
# Epoch 94, Average Training Loss: 0.944074, Average Validation Loss: 0.852477
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 95, Average Training Loss: 0.933046, Average Validation Loss: 0.852176
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 96, Average Training Loss: 0.940553, Average Validation Loss: 0.851750
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 97, Average Training Loss: 0.937757, Average Validation Loss: 0.851849
# Epoch 98, Average Training Loss: 0.941449, Average Validation Loss: 0.851144
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 99, Average Training Loss: 0.937960, Average Validation Loss: 0.851716
# Epoch 100, Average Training Loss: 0.934986, Average Validation Loss: 0.850677
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 101, Average Training Loss: 0.939151, Average Validation Loss: 0.851153
# Epoch 102, Average Training Loss: 0.926573, Average Validation Loss: 0.850116
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 103, Average Training Loss: 0.925693, Average Validation Loss: 0.849564
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 104, Average Training Loss: 0.932524, Average Validation Loss: 0.849888
# Epoch 105, Average Training Loss: 0.928608, Average Validation Loss: 0.849446
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 106, Average Training Loss: 0.933559, Average Validation Loss: 0.849652
# Epoch 107, Average Training Loss: 0.928640, Average Validation Loss: 0.849884
# Epoch 108, Average Training Loss: 0.931566, Average Validation Loss: 0.849119
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 109, Average Training Loss: 0.922680, Average Validation Loss: 0.848977
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 110, Average Training Loss: 0.922242, Average Validation Loss: 0.848901
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 111, Average Training Loss: 0.929070, Average Validation Loss: 0.848197
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 112, Average Training Loss: 0.925661, Average Validation Loss: 0.848069
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 113, Average Training Loss: 0.927762, Average Validation Loss: 0.848538
# Epoch 114, Average Training Loss: 0.929785, Average Validation Loss: 0.847562
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 115, Average Training Loss: 0.923785, Average Validation Loss: 0.847567
# Epoch 116, Average Training Loss: 0.924489, Average Validation Loss: 0.847042
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 117, Average Training Loss: 0.925565, Average Validation Loss: 0.847886
# Epoch 118, Average Training Loss: 0.923907, Average Validation Loss: 0.847845
# Epoch 119, Average Training Loss: 0.932293, Average Validation Loss: 0.847279
# Epoch 120, Average Training Loss: 0.920486, Average Validation Loss: 0.846842
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 121, Average Training Loss: 0.918782, Average Validation Loss: 0.847043
# Epoch 122, Average Training Loss: 0.916153, Average Validation Loss: 0.846957
# Epoch 123, Average Training Loss: 0.922551, Average Validation Loss: 0.846251
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 124, Average Training Loss: 0.916835, Average Validation Loss: 0.846088
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 125, Average Training Loss: 0.916683, Average Validation Loss: 0.847054
# Epoch 126, Average Training Loss: 0.916568, Average Validation Loss: 0.846716
# Epoch 127, Average Training Loss: 0.912559, Average Validation Loss: 0.846134
# Epoch 128, Average Training Loss: 0.919687, Average Validation Loss: 0.845692
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 129, Average Training Loss: 0.922320, Average Validation Loss: 0.845779
# Epoch 130, Average Training Loss: 0.914818, Average Validation Loss: 0.845545
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 131, Average Training Loss: 0.921066, Average Validation Loss: 0.845240
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 132, Average Training Loss: 0.913937, Average Validation Loss: 0.844906
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 133, Average Training Loss: 0.923981, Average Validation Loss: 0.845859
# Epoch 134, Average Training Loss: 0.915551, Average Validation Loss: 0.845003
# Epoch 135, Average Training Loss: 0.915154, Average Validation Loss: 0.845154
# Epoch 136, Average Training Loss: 0.912509, Average Validation Loss: 0.844798
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 137, Average Training Loss: 0.918775, Average Validation Loss: 0.844856
# Epoch 138, Average Training Loss: 0.916529, Average Validation Loss: 0.844906
# Epoch 139, Average Training Loss: 0.909783, Average Validation Loss: 0.844430
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 140, Average Training Loss: 0.916374, Average Validation Loss: 0.844439
# Epoch 141, Average Training Loss: 0.910144, Average Validation Loss: 0.844940
# Epoch 142, Average Training Loss: 0.907436, Average Validation Loss: 0.844163
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 143, Average Training Loss: 0.913311, Average Validation Loss: 0.844373
# Epoch 144, Average Training Loss: 0.914248, Average Validation Loss: 0.843738
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 145, Average Training Loss: 0.912335, Average Validation Loss: 0.843770
# Epoch 146, Average Training Loss: 0.910215, Average Validation Loss: 0.843472
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 147, Average Training Loss: 0.914665, Average Validation Loss: 0.844143
# Epoch 148, Average Training Loss: 0.905235, Average Validation Loss: 0.843145
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 149, Average Training Loss: 0.910014, Average Validation Loss: 0.843936
# Epoch 150, Average Training Loss: 0.905893, Average Validation Loss: 0.843271
# Epoch 151, Average Training Loss: 0.908920, Average Validation Loss: 0.843281
# Epoch 152, Average Training Loss: 0.906225, Average Validation Loss: 0.843013
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 153, Average Training Loss: 0.903528, Average Validation Loss: 0.842866
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 154, Average Training Loss: 0.908834, Average Validation Loss: 0.842771
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 155, Average Training Loss: 0.903794, Average Validation Loss: 0.842922
# Epoch 156, Average Training Loss: 0.906145, Average Validation Loss: 0.842259
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 157, Average Training Loss: 0.910573, Average Validation Loss: 0.842798
# Epoch 158, Average Training Loss: 0.905229, Average Validation Loss: 0.842096
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 159, Average Training Loss: 0.909094, Average Validation Loss: 0.842479
# Epoch 160, Average Training Loss: 0.900864, Average Validation Loss: 0.842493
# Epoch 161, Average Training Loss: 0.912331, Average Validation Loss: 0.842993
# Epoch 162, Average Training Loss: 0.910507, Average Validation Loss: 0.841972
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 163, Average Training Loss: 0.907622, Average Validation Loss: 0.842378
# Epoch 164, Average Training Loss: 0.905243, Average Validation Loss: 0.842134
# Epoch 165, Average Training Loss: 0.901755, Average Validation Loss: 0.841694
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 166, Average Training Loss: 0.901286, Average Validation Loss: 0.841455
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 167, Average Training Loss: 0.908121, Average Validation Loss: 0.842246
# Epoch 168, Average Training Loss: 0.901347, Average Validation Loss: 0.841423
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 169, Average Training Loss: 0.906376, Average Validation Loss: 0.841639
# Epoch 170, Average Training Loss: 0.902607, Average Validation Loss: 0.841775
# Epoch 171, Average Training Loss: 0.908661, Average Validation Loss: 0.841903
# Epoch 172, Average Training Loss: 0.899436, Average Validation Loss: 0.841470
# Epoch 00172: reducing learning rate of group 0 to 2.5000e-05.
# Epoch 173, Average Training Loss: 0.909007, Average Validation Loss: 0.841130
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 174, Average Training Loss: 0.905962, Average Validation Loss: 0.841326
# Epoch 175, Average Training Loss: 0.899342, Average Validation Loss: 0.841115
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 176, Average Training Loss: 0.901215, Average Validation Loss: 0.840690
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 177, Average Training Loss: 0.904447, Average Validation Loss: 0.840835
# Epoch 178, Average Training Loss: 0.894819, Average Validation Loss: 0.840512
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 179, Average Training Loss: 0.906843, Average Validation Loss: 0.840923
# Epoch 180, Average Training Loss: 0.901035, Average Validation Loss: 0.840777
# Epoch 181, Average Training Loss: 0.904407, Average Validation Loss: 0.840728
# Epoch 182, Average Training Loss: 0.899678, Average Validation Loss: 0.840709
# Epoch 183, Average Training Loss: 0.897507, Average Validation Loss: 0.840668
# Epoch 184, Average Training Loss: 0.905600, Average Validation Loss: 0.840927
# Epoch 00184: reducing learning rate of group 0 to 1.2500e-05.
# Epoch 185, Average Training Loss: 0.903125, Average Validation Loss: 0.840242
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 186, Average Training Loss: 0.900341, Average Validation Loss: 0.840346
# Epoch 187, Average Training Loss: 0.898338, Average Validation Loss: 0.840236
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 188, Average Training Loss: 0.903204, Average Validation Loss: 0.840288
# Epoch 189, Average Training Loss: 0.901305, Average Validation Loss: 0.840588
# Epoch 190, Average Training Loss: 0.902184, Average Validation Loss: 0.840243
# Epoch 191, Average Training Loss: 0.895408, Average Validation Loss: 0.840441
# Epoch 00191: reducing learning rate of group 0 to 6.2500e-06.
# Epoch 192, Average Training Loss: 0.903427, Average Validation Loss: 0.840586
# Epoch 193, Average Training Loss: 0.903315, Average Validation Loss: 0.840291
# Epoch 194, Average Training Loss: 0.899716, Average Validation Loss: 0.840434
# Epoch 195, Average Training Loss: 0.897690, Average Validation Loss: 0.839961
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 196, Average Training Loss: 0.897399, Average Validation Loss: 0.840009
# Epoch 197, Average Training Loss: 0.901396, Average Validation Loss: 0.840020
# Epoch 198, Average Training Loss: 0.901815, Average Validation Loss: 0.840186
# Epoch 199, Average Training Loss: 0.907596, Average Validation Loss: 0.840098
# Epoch 200, Average Training Loss: 0.901895, Average Validation Loss: 0.840350
# Epoch 201, Average Training Loss: 0.895809, Average Validation Loss: 0.840171
# Epoch 00201: reducing learning rate of group 0 to 3.1250e-06.
# Epoch 202, Average Training Loss: 0.907031, Average Validation Loss: 0.840158
# Epoch 203, Average Training Loss: 0.899678, Average Validation Loss: 0.840182
# Epoch 204, Average Training Loss: 0.901837, Average Validation Loss: 0.840044
# Epoch 205, Average Training Loss: 0.900794, Average Validation Loss: 0.840286
# Epoch 206, Average Training Loss: 0.897909, Average Validation Loss: 0.840107
# Epoch 207, Average Training Loss: 0.897416, Average Validation Loss: 0.840228
# Epoch 00207: reducing learning rate of group 0 to 1.5625e-06.
# Epoch 208, Average Training Loss: 0.901907, Average Validation Loss: 0.840314
# Epoch 209, Average Training Loss: 0.901380, Average Validation Loss: 0.840362
# Epoch 210, Average Training Loss: 0.899261, Average Validation Loss: 0.840368
# Epoch 211, Average Training Loss: 0.899981, Average Validation Loss: 0.840078
# Epoch 212, Average Training Loss: 0.901728, Average Validation Loss: 0.840401
# Epoch 213, Average Training Loss: 0.896434, Average Validation Loss: 0.840179
# Epoch 00213: reducing learning rate of group 0 to 7.8125e-07.
# Epoch 214, Average Training Loss: 0.903624, Average Validation Loss: 0.840005
# Epoch 215, Average Training Loss: 0.899907, Average Validation Loss: 0.840115
# Early stopping triggered.

# %%
# Plot training and validation loss over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_total_losses) + 1), train_total_losses, label='Training Loss')
plt.plot(range(1, len(val_total_losses) + 1), val_total_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
# Plot reconstruction loss and KL divergence over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Reconstruction Loss')
plt.plot(range(1, len(train_kld_losses) + 1), train_kld_losses, label='KL Divergence')
plt.plot(range(1, len(train_total_losses) + 1), beta * np.array(train_kld_losses), label='Beta * KL Divergence')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Reconstruction Loss and KL Divergence over Epochs')
plt.legend()
plt.show()

# %%
model.load_state_dict(torch.load(model_save_path))


model.eval()
test_loss = 0
with torch.no_grad():
    for data in test_loader:
        x = data[0].to(device, dtype=torch.float)
        recon_batch, mu, logvar, z = model(x)
        loss , _ , _ = loss_function(recon_batch, x, mu, logvar)
        test_loss += loss.item()
avg_test_loss = test_loss / len(test_loader.dataset)
print(f"Average Test Loss: {avg_test_loss:.4f}")
# Out:
# Average Test Loss: 0.0028

# %%
import matplotlib.pyplot as plt

# Function to display original and reconstructed images
def visualize_reconstruction(model, data_loader):
    model.eval()
    with torch.no_grad():
        data = next(iter(data_loader))
        x = data[0].to(device, dtype=torch.float)
        recon_x, _, _ , _ = model(x)
        
        # Move tensors to CPU and convert to numpy
        x = x.cpu().numpy()
        recon_x = recon_x.cpu().numpy()
        
        n = min(x.shape[0], 5)  # Number of samples to display
        for i in range(n):
            fig, axes = plt.subplots(2, 3, figsize=(12, 6))
            for j in range(3):
                axes[0, j].imshow(x[i, j], cmap='viridis')
                axes[0, j].set_title(f'Original - Matrix {j+1}')
                axes[0, j].axis('off')
                axes[1, j].imshow(recon_x[i, j], cmap='viridis')
                axes[1, j].set_title(f'Reconstructed - Matrix {j+1}')
                axes[1, j].axis('off')
            plt.show()

# Visualize reconstructions on test data
visualize_reconstruction(model, test_loader)

# %%
# Save the trained model
model_save_path = os.path.join(project_dir, 'conv_vae_model.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /home/diego/Escritorio/azheimer/conv_vae_model.pth

# %%
# Load the model
model = ConvVAE(latent_dim=latent_dim).to(device)
model.load_state_dict(torch.load(model_save_path))
model.eval()
# Out:
# ConvVAE(
#   (enc_conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (enc_conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (enc_conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (enc_conv4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (enc_conv5): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_bn5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=4608, out_features=2048, bias=True)
#   (fc_bn1): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2048, out_features=2048, bias=True)
#   (fc_bn2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_mu): Linear(in_features=2048, out_features=30, bias=True)
#   (fc_logvar): Linear(in_features=2048, out_features=30, bias=True)
#   (fc_decode): Linear(in_features=30, out_features=2048, bias=True)
#   (fc_bn3): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_decode2): Linear(in_features=2048, out_features=2048, bias=True)
#   (fc_bn4): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_decode3): Linear(in_features=2048, out_features=4608, bias=True)
#   (dec_conv1): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dec_conv2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dec_conv3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dec_conv4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dec_conv5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (output_padding): ReflectionPad2d((-5, -6, -5, -6))
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model.eval()
latents = []
labels = []

with torch.no_grad():
    for data, label in test_loader:
        x = data.to(device, dtype=torch.float)
        mu, logvar = model.encode(x)
        z = model.reparameterize(mu, logvar)
        latents.append(mu.cpu())
        labels.extend(label)  # Collect labels

# Concatenate all latent vectors and convert labels to a NumPy array
latents = torch.cat(latents, dim=0).numpy()
labels = np.array(labels)

# %%
from sklearn.manifold import TSNE

# Reduce latent dimensions to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
latents_2d = tsne.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
from sklearn.decomposition import PCA

# Reduce latent dimensions to 2D using PCA
pca = PCA(n_components=2)
latents_2d = pca.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
# Function to extract latent representations and labels for AD and CN subjects
def extract_latents_and_labels(file_paths, model, device):
    latents = []
    labels = []
    
    model.eval()
    with torch.no_grad():
        for fp in file_paths:
            file_name = os.path.basename(fp)
            group = file_name.split('_')[0]
            if group not in ['AD', 'CN']:
                continue  # Skip "Others" category
            label = 1 if group == 'AD' else 0  # Assign labels: AD=1, CN=0
            data = torch.load(fp)
            if isinstance(data, np.ndarray):
                data = torch.tensor(data)
            data = normalize_tensor(data)
            x = data.unsqueeze(0).to(device, dtype=torch.float)  # Add batch dimension
            mu, logvar = model.encode(x)
            z = model.reparameterize(mu, logvar)
            latents.append(mu.cpu().numpy().squeeze()) # Squeeze to remove batch dimension, mu instead of z
            labels.append(label)
    return np.array(latents), np.array(labels)

# %%
# Combine train and validation file paths
train_val_set = train_set + val_set

# Extract latents and labels for training (train + validation sets)
X_train, y_train = extract_latents_and_labels(train_val_set, model, device)

# Extract latents and labels for test set
X_test, y_test = extract_latents_and_labels(test_set, model, device)

# Print the shapes
print(f"Training data shape: {X_train.shape}, Training labels shape: {y_train.shape}")
print(f"Test data shape: {X_test.shape}, Test labels shape: {y_test.shape}")
# Out:
# Training data shape: (153, 30), Training labels shape: (153,)
# Test data shape: (31, 30), Test labels shape: (31,)

# %%
from collections import Counter

print(f"Training labels distribution: {Counter(y_train)}")
print(f"Test labels distribution: {Counter(y_test)}")
# Out:
# Training labels distribution: Counter({1: 80, 0: 73})
# Test labels distribution: Counter({0: 16, 1: 15})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
)

# Define classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM (Linear Kernel)": SVC(kernel='linear', probability=True),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "Neural Network": MLPClassifier(hidden_layer_sizes=(50,), max_iter=1000),
}

# Dictionary to store performance metrics
performance_metrics = {}

# Train and evaluate each classifier
for name, clf in classifiers.items():
    # Train the classifier
    clf.fit(X_train, y_train)
    # Predict on test set
    y_pred = clf.predict(X_test)
    y_proba = clf.predict_proba(X_test)[:, 1] if hasattr(clf, "predict_proba") else None
    # Compute metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
    # Store metrics
    performance_metrics[name] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "ROC AUC": roc_auc,
    }
    # Print classification report
    print(f"Classifier: {name}")
    print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
    print("-" * 50)
# Out:
# Classifier: Logistic Regression
#               precision    recall  f1-score   support
#
#           CN       0.50      0.56      0.53        16
#           AD       0.46      0.40      0.43        15
#
#     accuracy                           0.48        31
#    macro avg       0.48      0.48      0.48        31
# weighted avg       0.48      0.48      0.48        31
#
# --------------------------------------------------
# Classifier: SVM (Linear Kernel)
#               precision    recall  f1-score   support
#
#           CN       0.53      0.56      0.55        16
#           AD       0.50      0.47      0.48        15
#
#     accuracy                           0.52        31
#    macro avg       0.51      0.51      0.51        31
# weighted avg       0.52      0.52      0.52        31
#
# --------------------------------------------------
# Classifier: Random Forest
#               precision    recall  f1-score   support
#
#           CN       0.58      0.44      0.50        16
#           AD       0.53      0.67      0.59        15
#
#     accuracy                           0.55        31
#    macro avg       0.55      0.55      0.54        31
# weighted avg       0.56      0.55      0.54        31
#
# --------------------------------------------------
# Classifier: k-NN
#               precision    recall  f1-score   support
#
#           CN       0.47      0.44      0.45        16
#           AD       0.44      0.47      0.45        15
#
#     accuracy                           0.45        31
#    macro avg       0.45      0.45      0.45        31
# weighted avg       0.45      0.45      0.45        31
#
# --------------------------------------------------
# Classifier: Gradient Boosting
#               precision    recall  f1-score   support
#
#           CN       0.71      0.62      0.67        16
#           AD       0.65      0.73      0.69        15
#
#     accuracy                           0.68        31
#    macro avg       0.68      0.68      0.68        31
# weighted avg       0.68      0.68      0.68        31
#
# --------------------------------------------------
# Classifier: Neural Network
#               precision    recall  f1-score   support
#
#           CN       0.50      0.50      0.50        16
#           AD       0.47      0.47      0.47        15
#
#     accuracy                           0.48        31
#    macro avg       0.48      0.48      0.48        31
# weighted avg       0.48      0.48      0.48        31
#
# --------------------------------------------------

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")

# Evaluate the best model
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
# Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#           CN       0.43      0.38      0.40        16
#           AD       0.41      0.47      0.44        15
#
#     accuracy                           0.42        31
#    macro avg       0.42      0.42      0.42        31
# weighted avg       0.42      0.42      0.42        31

# %%
import matplotlib.pyplot as plt

# Assuming you have trained a Random Forest classifier named 'best_rf'
importances = best_rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices], color="r", align="center")
plt.xticks(range(X_train.shape[1]), indices)
plt.xlabel("Feature Index")
plt.ylabel("Importance")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'class_weight': [None, 'balanced']
}

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit to training data
grid_search.fit(X_train, y_train)

# Best parameters and estimator
print(f"Best parameters: {grid_search.best_params_}")
best_rf = grid_search.best_estimator_

# Evaluate on test data
y_pred = best_rf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
# Best parameters: {'class_weight': 'balanced', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 300}
#               precision    recall  f1-score   support
#
#           CN       0.55      0.38      0.44        16
#           AD       0.50      0.67      0.57        15
#
#     accuracy                           0.52        31
#    macro avg       0.52      0.52      0.51        31
# weighted avg       0.52      0.52      0.51        31

# %%
from sklearn.ensemble import VotingClassifier

# Initialize individual classifiers
clf1 = LogisticRegression(max_iter=1000, random_state=42)
clf2 = RandomForestClassifier(n_estimators=200, random_state=42)
clf3 = GradientBoostingClassifier(n_estimators=200, random_state=42)

# Create a voting classifier
voting_clf = VotingClassifier(
    estimators=[('lr', clf1), ('rf', clf2), ('gb', clf3)],
    voting='soft'  # Use 'hard' for majority voting
)

# Fit the voting classifier
voting_clf.fit(X_train, y_train)

# Evaluate on test data
y_pred = voting_clf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
#               precision    recall  f1-score   support
#
#           CN       0.67      0.50      0.57        16
#           AD       0.58      0.73      0.65        15
#
#     accuracy                           0.61        31
#    macro avg       0.62      0.62      0.61        31
# weighted avg       0.62      0.61      0.61        31

# %%
from sklearn.feature_selection import RFE

# Initialize a classifier
estimator = RandomForestClassifier(n_estimators=200, random_state=42)

# Initialize RFE
selector = RFE(estimator, n_features_to_select=10, step=1)
selector = selector.fit(X_train, y_train)

# Transform datasets
X_train_selected = selector.transform(X_train)
X_test_selected = selector.transform(X_test)

# Retrain classifier on selected features
estimator.fit(X_train_selected, y_train)

# Evaluate on test data
y_pred = estimator.predict(X_test_selected)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
#               precision    recall  f1-score   support
#
#           CN       0.44      0.25      0.32        16
#           AD       0.45      0.67      0.54        15
#
#     accuracy                           0.45        31
#    macro avg       0.45      0.46      0.43        31
# weighted avg       0.45      0.45      0.43        31

# %%
# Assume we've identified that Random Forest and Gradient Boosting perform best

# Hyperparameter tuning for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5],
    'class_weight': [None, 'balanced']
}
grid_rf = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid_rf,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_rf.fit(X_train, y_train)
best_rf = grid_rf.best_estimator_

# Hyperparameter tuning for Gradient Boosting
param_grid_gb = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
}
grid_gb = GridSearchCV(
    GradientBoostingClassifier(random_state=42),
    param_grid_gb,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_gb.fit(X_train, y_train)
best_gb = grid_gb.best_estimator_

# Feature selection using feature importances from Random Forest
import numpy as np

# Get feature importances
importances = best_rf.feature_importances_

# Select top features
indices = np.argsort(importances)[::-1]
top_n = 10  # Number of top features to select
selected_features = indices[:top_n]

# Transform datasets
X_train_selected = X_train[:, selected_features]
X_test_selected = X_test[:, selected_features]

# Retrain best models on selected features
best_rf.fit(X_train_selected, y_train)
best_gb.fit(X_train_selected, y_train)

# Evaluate on test data
y_pred_rf = best_rf.predict(X_test_selected)
y_pred_gb = best_gb.predict(X_test_selected)

# Print classification reports
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf, target_names=["CN", "AD"]))
print("Gradient Boosting Classification Report:")
print(classification_report(y_test, y_pred_gb, target_names=["CN", "AD"]))

# Ensemble with Voting Classifier
from sklearn.ensemble import VotingClassifier

voting_clf = VotingClassifier(
    estimators=[('rf', best_rf), ('gb', best_gb)],
    voting='soft'
)
voting_clf.fit(X_train_selected, y_train)
y_pred_voting = voting_clf.predict(X_test_selected)
print("Voting Classifier Classification Report:")
print(classification_report(y_test, y_pred_voting, target_names=["CN", "AD"]))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#           CN       0.50      0.31      0.38        16
#           AD       0.48      0.67      0.56        15
#
#     accuracy                           0.48        31
#    macro avg       0.49      0.49      0.47        31
# weighted avg       0.49      0.48      0.47        31
#
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#           CN       0.73      0.50      0.59        16
#           AD       0.60      0.80      0.69        15
#
#     accuracy                           0.65        31
#    macro avg       0.66      0.65      0.64        31
# weighted avg       0.67      0.65      0.64        31
#
# Voting Classifier Classification Report:
#               precision    recall  f1-score   support
#
#           CN       0.70      0.44      0.54        16
#           AD       0.57      0.80      0.67        15
#
#     accuracy                           0.61        31
#    macro avg       0.64      0.62      0.60        31
# weighted avg       0.64      0.61      0.60        31
