# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Set paths
project_dir = '/home/diego/Escritorio/azheimer/'  # Adjust to your path
csv_path = os.path.join(project_dir, 'DataBaseSubjects.csv')
tensor_data_dir = os.path.join(project_dir, 'TensorData')

# Load the CSV file
subjects_df = pd.read_csv(csv_path)

# Calculate the median age and print it
median_age = subjects_df['Age'].median()
print(f"Median Age: {median_age}")

# Plot the age distribution
plt.figure(figsize=(8, 6))
sns.histplot(subjects_df['Age'], bins=20, kde=True, color='blue')
plt.axvline(median_age, color='red', linestyle='--', label=f'Median Age: {median_age}')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Plot the sex distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Plot the distribution of AD, CN, and Others
plt.figure(figsize=(8, 6))
sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
plt.title('AD, CN, and Others Distribution')
plt.xlabel('Research Group')
plt.ylabel('Count')
plt.show()

# Group subjects by Research Group and Sex
grouped_data = subjects_df.groupby(['ResearchGroup', 'Sex']).size().unstack().fillna(0)
print(grouped_data)

# Initialize dictionaries for storing tensor paths by group and sex
tensor_groups = {
    'AD_men': [],
    'AD_women': [],
    'CN_men': [],
    'CN_women': [],
    'Other_men': [],
    'Other_women': []
}

# Iterate over subjects and assign tensors to groups
for subject_id in subjects_df['SubjectID']:
    group = subjects_df[subjects_df['SubjectID'] == subject_id]['ResearchGroup'].values[0]
    sex = subjects_df[subjects_df['SubjectID'] == subject_id]['Sex'].values[0]
    file_name = f'{group}_tensor_{subject_id}.pt'
    file_path = os.path.join(tensor_data_dir, file_name)
    
    if os.path.exists(file_path):
        if group == 'AD':
            if sex == 'M':
                tensor_groups['AD_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['AD_women'].append(file_path)
        elif group == 'CN':
            if sex == 'M':
                tensor_groups['CN_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['CN_women'].append(file_path)
        else:  # Others
            if sex == 'M':
                tensor_groups['Other_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['Other_women'].append(file_path)

# Print the number of subjects in each group
for key, value in tensor_groups.items():
    print(f'{key}: {len(value)} subjects')

# Split data into train, validation, and test sets with equal proportions
def split_data(tensors, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    np.random.shuffle(tensors)
    n_total = len(tensors)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    
    train_set = tensors[:n_train]
    val_set = tensors[n_train:n_train + n_val]
    test_set = tensors[n_train + n_val:]
    
    return train_set, val_set, test_set

# Initialize lists for train, validation, and test sets
train_set, val_set, test_set = [], [], []

# Combine groups ensuring equal proportions of gender and research groups
for group in tensor_groups:
    train, val, test = split_data(tensor_groups[group])
    train_set.extend(train)
    val_set.extend(val)
    test_set.extend(test)

# Print final counts of train, validation, and test sets
print(f"Train set: {len(train_set)} subjects")
print(f"Validation set: {len(val_set)} subjects")
print(f"Test set: {len(test_set)} subjects")
# Out:
# Median Age: 74.25
# /tmp/ipykernel_13404/3646991604.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
# /tmp/ipykernel_13404/3646991604.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
# Sex             F   M
# ResearchGroup
# AD             40  55
# CN             52  37
# EMCI            8  10
# LMCI           23  32
# MCI            42  53
# AD_men: 55 subjects
# AD_women: 40 subjects
# CN_men: 37 subjects
# CN_women: 52 subjects
# Other_men: 95 subjects
# Other_women: 73 subjects
# Train set: 244 subjects
# Validation set: 50 subjects
# Test set: 58 subjects

# %%
# Function to normalize each channel of the tensor between 0 and 1
def normalize_tensor(tensor):
    normalized_tensor = torch.zeros_like(tensor)
    for i in range(tensor.shape[0]):  # For each channel
        channel_data = tensor[i]
        min_val = channel_data.min()
        max_val = channel_data.max()
        # Avoid division by zero
        if max_val - min_val != 0:
            normalized_tensor[i] = (channel_data - min_val) / (max_val - min_val)
        else:
            normalized_tensor[i] = channel_data - min_val
    return normalized_tensor

# %%
# Load the tensors and create datasets
def load_tensors(file_paths):
    tensors = []
    for fp in file_paths:
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        tensors.append(data)
    return torch.stack(tensors)


# Load data for train, validation, and test sets
train_data = load_tensors(train_set)
val_data = load_tensors(val_set)
test_data = load_tensors(test_set)

# Print final dataset shapes
print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")

import torch

# Assuming train_set, val_set, test_set are your datasets (could be PyTorch Datasets or DataLoaders)
torch.save(train_data, 'sets/train_set.pt')
torch.save(val_data, 'sets/val_set.pt')
torch.save(test_data, 'sets/test_set.pt')
# Out:
# Train data shape: torch.Size([244, 3, 116, 116])
# Validation data shape: torch.Size([50, 3, 116, 116])
# Test data shape: torch.Size([58, 3, 116, 116])

# %%
import random
import matplotlib.pyplot as plt

# Function to plot the three matrices for a given subject's tensor
def plot_matrices(tensor, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    matrix_titles = ['Correlation Matrix', 'Mutual Information Matrix', 'Granger Causality Matrix']

    # Loop through the three matrices
    for i in range(3):
        ax = axes[i]
        cax = ax.matshow(tensor[i], cmap='viridis')
        fig.colorbar(cax, ax=ax)
        ax.set_title(f'{title_prefix} - {matrix_titles[i]}')
        ax.set_xlabel('ROIs')
        ax.set_ylabel('ROIs')

    plt.tight_layout()
    plt.show()

# Choose a random subject from each dataset and plot their matrices
def plot_random_subject_from_dataset(dataset, dataset_name):
    random_subject = random.choice(dataset)
    print(f"Plotting matrices for a random subject from {dataset_name} dataset: {random_subject}")
    
    # Load the tensor for the randomly selected subject
    tensor = torch.load(random_subject)
    
    # Plot the matrices
    plot_matrices(tensor, dataset_name)

# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_set, 'Train')
plot_random_subject_from_dataset(val_set, 'Validation')
plot_random_subject_from_dataset(test_set, 'Test')
# Out:
# Plotting matrices for a random subject from Train dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_057_S_6869.pt
# Plotting matrices for a random subject from Validation dataset: /home/diego/Escritorio/azheimer/TensorData/MCI_tensor_006_S_6657.pt
# Plotting matrices for a random subject from Test dataset: /home/diego/Escritorio/azheimer/TensorData/CN_tensor_130_S_6161.pt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ConvVAE(nn.Module):
    def __init__(self, latent_dim=2, hidden_dim=1024):  # Added hidden_dim
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim  # New hidden dimension for the linear layers
        self.dropout_rate = 0.2  # Dropout rate

        # Encoder Layers
        self.enc_conv1 = nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1)    # Output: (64, 58, 58)
        self.enc_conv2 = nn.Conv2d(64, 128, 4, 2, 1)  # Output: (128, 29, 29)
        self.enc_conv3 = nn.Conv2d(128, 256, 4, 2, 1)  # Output: (256, 14, 14)
        self.enc_conv4 = nn.Conv2d(256, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.enc_conv5 = nn.Conv2d(512, 512, 4, 2, 1)  # Output: (512, 3, 3)

        # Compute the size after convolutional layers to flatten
        self.flatten_size = 512 * 3 * 3  # Updated to 4608

        # Linear layers after the convolutional layers in the encoder
        self.fc1 = nn.Linear(self.flatten_size, self.hidden_dim)  # New linear layer
        self.fc2 = nn.Linear(self.hidden_dim, self.hidden_dim)    # Second linear layer
        
        # Latent space
        self.fc_mu = nn.Linear(self.hidden_dim, latent_dim)  # Adjusted to latent space
        self.fc_logvar = nn.Linear(self.hidden_dim, latent_dim)

        # Decoder Layers
        self.fc_decode = nn.Linear(latent_dim, self.hidden_dim)
        self.fc_decode2 = nn.Linear(self.hidden_dim, self.hidden_dim)  # Second linear layer
        self.fc_decode3 = nn.Linear(self.hidden_dim, self.flatten_size)  # Map back to the flattened convolutional output

        self.dec_conv1 = nn.ConvTranspose2d(512, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.dec_conv2 = nn.ConvTranspose2d(512, 256, 4, 2, 1)  # Output: (256, 15, 15)
        self.dec_conv3 = nn.ConvTranspose2d(256, 128, 4, 2, 1)  # Output: (128, 31, 31)
        self.dec_conv4 = nn.ConvTranspose2d(128, 64, 4, 2, 1)   # Output: (64, 63, 63)
        self.dec_conv5 = nn.ConvTranspose2d(64, 3, 4, 2, 1)     # Output: (3, 127, 127)

        # Adjust output size to (3, 116, 116)
        self.output_padding = nn.ReflectionPad2d((-5, -6, -5, -6))  # Crop to (3, 116, 116)

        # Dropout layer
        self.dropout = nn.Dropout(self.dropout_rate)

    def encode(self, x):
        # Apply convolutional layers
        x1 = F.relu(self.enc_conv1(x))
        x2 = F.relu(self.enc_conv2(x1))
        x3 = F.relu(self.enc_conv3(x2))
        x4 = F.relu(self.enc_conv4(x3))
        x5 = F.relu(self.enc_conv5(x4))
        x5 = x5.view(x.size(0), -1)  # Flatten the output
        
        # Apply fully connected layers
        x5 = F.relu(self.fc1(x5))  # First linear layer
        x5 = self.dropout(x5)
        x5 = F.relu(self.fc2(x5))  # Second linear layer

        # Get the latent space variables
        mu = self.fc_mu(x5)
        logvar = self.fc_logvar(x5)
        return mu, logvar

    def decode(self, z):
        # Apply fully connected layers
        x = F.relu(self.fc_decode(z))  # First linear layer in decoder
        x = F.relu(self.fc_decode2(x))  # Second linear layer in decoder
        x = F.relu(self.fc_decode3(x))  # Map to the size before deconvolution
        x = x.view(z.size(0), 512, 3, 3)  # Reshape to convolutional output dimensions
        
        # Apply transposed convolutional layers to upsample
        x = F.relu(self.dec_conv1(x))
        x = F.relu(self.dec_conv2(x))
        x = F.relu(self.dec_conv3(x))
        x = F.relu(self.dec_conv4(x))
        x = torch.sigmoid(self.dec_conv5(x))
        x = F.interpolate(x, size=(116, 116), mode='bilinear', align_corners=False)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar, z

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

# %%
def loss_function(recon_x, x, mu, logvar, beta=1):
    # Reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='mean')

    # KL Divergence (normalized per batch)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    KLD = KLD / x.size(0)  # Normalize KLD per batch

    # Total loss
    total_loss = recon_loss + beta * KLD

    return total_loss, recon_loss.item(), KLD.item()

# %%
from torch.utils.data import Dataset, DataLoader

class CustomTensorDataset(Dataset):
    def __init__(self, file_paths):
        self.file_paths = file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        fp = self.file_paths[idx]
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        # Extract the label from the file name
        file_name = os.path.basename(fp)
        # Expected format: '{group}_tensor_{subject_id}.pt'
        group = file_name.split('_')[0]
        # Map group to labels
        if group in ['AD', 'CN']:
            label = group
        else:
            label = 'Others'
        return data, label

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create datasets
train_dataset = TensorDataset(train_data)
val_dataset = TensorDataset(val_data)
# Create the test dataset with labels
test_dataset = CustomTensorDataset(test_set)

# Create data loaders
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Create the data loader
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize model
latent_dim = 30  # You can adjust the size of the latent space
hidden_dim= 1024*2  # Hidden dimension for the linear layers
model = ConvVAE(latent_dim=latent_dim).to(device)

# Optimizer with L2 regularization (weight decay)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-6)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
# Out:
# Using device: cuda

# %%
# Early stopping parameters
early_stopping_patience = 50
best_val_loss = float('inf')
epochs_without_improvement = 0
model_save_path = os.path.join(project_dir, 'best_beta_vae_model.pth')

# %%
# Lists to store losses
train_total_losses = []
val_total_losses = []
train_recon_losses = []
train_kld_losses = []

num_epochs = 500  # Adjust the number of epochs as needed
beta = 100  # Set the beta value for the loss function

for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0
    train_recon_loss = 0
    train_kld_loss = 0

    for data in train_loader:
        x = data[0].to(device, dtype=torch.float)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar, _ = model(x)
        loss, recon_loss, kld_loss = loss_function(recon_batch, x, mu, logvar, beta=beta)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * x.size(0)  # Multiply by batch size
        train_recon_loss += recon_loss * x.size(0)
        train_kld_loss += kld_loss * x.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_recon_loss = train_recon_loss / len(train_loader.dataset)
    avg_train_kld_loss = train_kld_loss / len(train_loader.dataset)

    train_total_losses.append(avg_train_loss)
    train_recon_losses.append(avg_train_recon_loss)
    train_kld_losses.append(avg_train_kld_loss)
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data in val_loader:
            x = data[0].to(device, dtype=torch.float)
            recon_batch, mu, logvar, _ = model(x)
            loss, _, _ = loss_function(recon_batch, x, mu, logvar, beta=beta)
            val_loss += loss.item() * x.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_total_losses.append(avg_val_loss)
    
    print(f"Epoch {epoch}, Average Training Loss: {avg_train_loss:.6f}, Average Validation Loss: {avg_val_loss:.6f}")
    
    # Step the scheduler
    scheduler.step(avg_val_loss)
    
    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        # Save the model
        torch.save(model.state_dict(), model_save_path)
        print(f"Validation loss improved. Model saved to {model_save_path}")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= early_stopping_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1, Average Training Loss: 0.404652, Average Validation Loss: 0.149154
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 2, Average Training Loss: 0.140439, Average Validation Loss: 0.090945
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 3, Average Training Loss: 0.058295, Average Validation Loss: 0.031842
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 4, Average Training Loss: 0.036234, Average Validation Loss: 0.028840
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 5, Average Training Loss: 0.031770, Average Validation Loss: 0.025509
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 6, Average Training Loss: 0.028211, Average Validation Loss: 0.022884
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 7, Average Training Loss: 0.025701, Average Validation Loss: 0.021894
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 8, Average Training Loss: 0.024598, Average Validation Loss: 0.021033
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 9, Average Training Loss: 0.023659, Average Validation Loss: 0.020177
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 10, Average Training Loss: 0.022844, Average Validation Loss: 0.019506
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 11, Average Training Loss: 0.021625, Average Validation Loss: 0.019215
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 12, Average Training Loss: 0.021028, Average Validation Loss: 0.017933
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 13, Average Training Loss: 0.020257, Average Validation Loss: 0.017492
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 14, Average Training Loss: 0.019581, Average Validation Loss: 0.017056
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 15, Average Training Loss: 0.019001, Average Validation Loss: 0.016693
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 16, Average Training Loss: 0.018478, Average Validation Loss: 0.016259
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 17, Average Training Loss: 0.018011, Average Validation Loss: 0.015848
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 18, Average Training Loss: 0.017639, Average Validation Loss: 0.015558
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 19, Average Training Loss: 0.017075, Average Validation Loss: 0.015121
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 20, Average Training Loss: 0.016415, Average Validation Loss: 0.014431
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 21, Average Training Loss: 0.015876, Average Validation Loss: 0.013901
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 22, Average Training Loss: 0.015221, Average Validation Loss: 0.013375
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 23, Average Training Loss: 0.014780, Average Validation Loss: 0.012997
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 24, Average Training Loss: 0.014329, Average Validation Loss: 0.012646
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 25, Average Training Loss: 0.014068, Average Validation Loss: 0.012380
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 26, Average Training Loss: 0.013795, Average Validation Loss: 0.012413
# Epoch 27, Average Training Loss: 0.013576, Average Validation Loss: 0.012475
# Epoch 28, Average Training Loss: 0.013478, Average Validation Loss: 0.012184
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 29, Average Training Loss: 0.013384, Average Validation Loss: 0.012032
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 30, Average Training Loss: 0.013163, Average Validation Loss: 0.011902
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 31, Average Training Loss: 0.012998, Average Validation Loss: 0.011802
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 32, Average Training Loss: 0.012945, Average Validation Loss: 0.011928
# Epoch 33, Average Training Loss: 0.012927, Average Validation Loss: 0.011974
# Epoch 34, Average Training Loss: 0.012793, Average Validation Loss: 0.011558
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 35, Average Training Loss: 0.012776, Average Validation Loss: 0.011542
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 36, Average Training Loss: 0.012774, Average Validation Loss: 0.011704
# Epoch 37, Average Training Loss: 0.012575, Average Validation Loss: 0.011621
# Epoch 38, Average Training Loss: 0.012650, Average Validation Loss: 0.011599
# Epoch 39, Average Training Loss: 0.012568, Average Validation Loss: 0.011662
# Epoch 40, Average Training Loss: 0.012546, Average Validation Loss: 0.011361
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 41, Average Training Loss: 0.012367, Average Validation Loss: 0.011402
# Epoch 42, Average Training Loss: 0.012292, Average Validation Loss: 0.011338
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 43, Average Training Loss: 0.012272, Average Validation Loss: 0.011275
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 44, Average Training Loss: 0.012294, Average Validation Loss: 0.011335
# Epoch 45, Average Training Loss: 0.012370, Average Validation Loss: 0.011727
# Epoch 46, Average Training Loss: 0.012310, Average Validation Loss: 0.011217
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 47, Average Training Loss: 0.012254, Average Validation Loss: 0.011402
# Epoch 48, Average Training Loss: 0.012165, Average Validation Loss: 0.011253
# Epoch 49, Average Training Loss: 0.012091, Average Validation Loss: 0.011314
# Epoch 50, Average Training Loss: 0.012031, Average Validation Loss: 0.011372
# Epoch 51, Average Training Loss: 0.012073, Average Validation Loss: 0.011346
# Epoch 52, Average Training Loss: 0.012033, Average Validation Loss: 0.011133
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 53, Average Training Loss: 0.011983, Average Validation Loss: 0.011229
# Epoch 54, Average Training Loss: 0.011934, Average Validation Loss: 0.011141
# Epoch 55, Average Training Loss: 0.012028, Average Validation Loss: 0.011108
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 56, Average Training Loss: 0.011951, Average Validation Loss: 0.010981
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 57, Average Training Loss: 0.011826, Average Validation Loss: 0.011224
# Epoch 58, Average Training Loss: 0.011870, Average Validation Loss: 0.010964
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 59, Average Training Loss: 0.011847, Average Validation Loss: 0.011102
# Epoch 60, Average Training Loss: 0.011824, Average Validation Loss: 0.011014
# Epoch 61, Average Training Loss: 0.011720, Average Validation Loss: 0.010965
# Epoch 62, Average Training Loss: 0.011776, Average Validation Loss: 0.010933
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 63, Average Training Loss: 0.011707, Average Validation Loss: 0.010946
# Epoch 64, Average Training Loss: 0.011746, Average Validation Loss: 0.010898
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 65, Average Training Loss: 0.011648, Average Validation Loss: 0.010962
# Epoch 66, Average Training Loss: 0.011621, Average Validation Loss: 0.010932
# Epoch 67, Average Training Loss: 0.011636, Average Validation Loss: 0.010922
# Epoch 68, Average Training Loss: 0.011614, Average Validation Loss: 0.010855
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 69, Average Training Loss: 0.011604, Average Validation Loss: 0.010959
# Epoch 70, Average Training Loss: 0.011704, Average Validation Loss: 0.011122
# Epoch 71, Average Training Loss: 0.011565, Average Validation Loss: 0.011152
# Epoch 72, Average Training Loss: 0.011586, Average Validation Loss: 0.011029
# Epoch 73, Average Training Loss: 0.011593, Average Validation Loss: 0.011202
# Epoch 74, Average Training Loss: 0.011598, Average Validation Loss: 0.010974
# Epoch 00074: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 75, Average Training Loss: 0.011594, Average Validation Loss: 0.010879
# Epoch 76, Average Training Loss: 0.011461, Average Validation Loss: 0.010827
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 77, Average Training Loss: 0.011498, Average Validation Loss: 0.010800
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 78, Average Training Loss: 0.011489, Average Validation Loss: 0.010753
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 79, Average Training Loss: 0.011483, Average Validation Loss: 0.010866
# Epoch 80, Average Training Loss: 0.011404, Average Validation Loss: 0.010764
# Epoch 81, Average Training Loss: 0.011409, Average Validation Loss: 0.010872
# Epoch 82, Average Training Loss: 0.011446, Average Validation Loss: 0.010681
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 83, Average Training Loss: 0.011481, Average Validation Loss: 0.010784
# Epoch 84, Average Training Loss: 0.011401, Average Validation Loss: 0.010709
# Epoch 85, Average Training Loss: 0.011412, Average Validation Loss: 0.010754
# Epoch 86, Average Training Loss: 0.011391, Average Validation Loss: 0.010811
# Epoch 87, Average Training Loss: 0.011442, Average Validation Loss: 0.010841
# Epoch 88, Average Training Loss: 0.011450, Average Validation Loss: 0.010711
# Epoch 00088: reducing learning rate of group 0 to 2.5000e-05.
# Epoch 89, Average Training Loss: 0.011372, Average Validation Loss: 0.010761
# Epoch 90, Average Training Loss: 0.011395, Average Validation Loss: 0.010788
# Epoch 91, Average Training Loss: 0.011378, Average Validation Loss: 0.010680
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 92, Average Training Loss: 0.011391, Average Validation Loss: 0.010782
# Epoch 93, Average Training Loss: 0.011360, Average Validation Loss: 0.010781
# Epoch 94, Average Training Loss: 0.011366, Average Validation Loss: 0.010774
# Epoch 00094: reducing learning rate of group 0 to 1.2500e-05.
# Epoch 95, Average Training Loss: 0.011337, Average Validation Loss: 0.010750
# Epoch 96, Average Training Loss: 0.011352, Average Validation Loss: 0.010758
# Epoch 97, Average Training Loss: 0.011349, Average Validation Loss: 0.010767
# Epoch 98, Average Training Loss: 0.011355, Average Validation Loss: 0.010836
# Epoch 99, Average Training Loss: 0.011358, Average Validation Loss: 0.010796
# Epoch 100, Average Training Loss: 0.011326, Average Validation Loss: 0.010743
# Epoch 00100: reducing learning rate of group 0 to 6.2500e-06.
# Epoch 101, Average Training Loss: 0.011329, Average Validation Loss: 0.010723
# Epoch 102, Average Training Loss: 0.011339, Average Validation Loss: 0.010745
# Epoch 103, Average Training Loss: 0.011354, Average Validation Loss: 0.010739
# Epoch 104, Average Training Loss: 0.011384, Average Validation Loss: 0.010741
# Epoch 105, Average Training Loss: 0.011331, Average Validation Loss: 0.010722
# Epoch 106, Average Training Loss: 0.011301, Average Validation Loss: 0.010761
# Epoch 00106: reducing learning rate of group 0 to 3.1250e-06.
# Epoch 107, Average Training Loss: 0.011337, Average Validation Loss: 0.010668
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 108, Average Training Loss: 0.011330, Average Validation Loss: 0.010694
# Epoch 109, Average Training Loss: 0.011337, Average Validation Loss: 0.010656
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 110, Average Training Loss: 0.011325, Average Validation Loss: 0.010756
# Epoch 111, Average Training Loss: 0.011349, Average Validation Loss: 0.010793
# Epoch 112, Average Training Loss: 0.011345, Average Validation Loss: 0.010723
# Epoch 113, Average Training Loss: 0.011301, Average Validation Loss: 0.010746
# Epoch 114, Average Training Loss: 0.011306, Average Validation Loss: 0.010739
# Epoch 115, Average Training Loss: 0.011281, Average Validation Loss: 0.010678
# Epoch 00115: reducing learning rate of group 0 to 1.5625e-06.
# Epoch 116, Average Training Loss: 0.011316, Average Validation Loss: 0.010644
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 117, Average Training Loss: 0.011320, Average Validation Loss: 0.010795
# Epoch 118, Average Training Loss: 0.011312, Average Validation Loss: 0.010700
# Epoch 119, Average Training Loss: 0.011333, Average Validation Loss: 0.010684
# Epoch 120, Average Training Loss: 0.011335, Average Validation Loss: 0.010842
# Epoch 121, Average Training Loss: 0.011326, Average Validation Loss: 0.010807
# Epoch 122, Average Training Loss: 0.011295, Average Validation Loss: 0.010792
# Epoch 00122: reducing learning rate of group 0 to 7.8125e-07.
# Epoch 123, Average Training Loss: 0.011315, Average Validation Loss: 0.010710
# Epoch 124, Average Training Loss: 0.011357, Average Validation Loss: 0.010777
# Epoch 125, Average Training Loss: 0.011302, Average Validation Loss: 0.010635
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 126, Average Training Loss: 0.011321, Average Validation Loss: 0.010716
# Epoch 127, Average Training Loss: 0.011327, Average Validation Loss: 0.010810
# Epoch 128, Average Training Loss: 0.011315, Average Validation Loss: 0.010817
# Epoch 129, Average Training Loss: 0.011305, Average Validation Loss: 0.010708
# Epoch 130, Average Training Loss: 0.011296, Average Validation Loss: 0.010759
# Epoch 131, Average Training Loss: 0.011310, Average Validation Loss: 0.010790
# Epoch 00131: reducing learning rate of group 0 to 3.9063e-07.
# Epoch 132, Average Training Loss: 0.011299, Average Validation Loss: 0.010644
# Epoch 133, Average Training Loss: 0.011270, Average Validation Loss: 0.010655
# Epoch 134, Average Training Loss: 0.011325, Average Validation Loss: 0.010720
# Epoch 135, Average Training Loss: 0.011314, Average Validation Loss: 0.010657
# Epoch 136, Average Training Loss: 0.011300, Average Validation Loss: 0.010734
# Epoch 137, Average Training Loss: 0.011297, Average Validation Loss: 0.010723
# Epoch 00137: reducing learning rate of group 0 to 1.9531e-07.
# Epoch 138, Average Training Loss: 0.011332, Average Validation Loss: 0.010714
# Epoch 139, Average Training Loss: 0.011338, Average Validation Loss: 0.010679
# Epoch 140, Average Training Loss: 0.011344, Average Validation Loss: 0.010731
# Epoch 141, Average Training Loss: 0.011308, Average Validation Loss: 0.010733
# Epoch 142, Average Training Loss: 0.011292, Average Validation Loss: 0.010717
# Epoch 143, Average Training Loss: 0.011325, Average Validation Loss: 0.010626
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 144, Average Training Loss: 0.011336, Average Validation Loss: 0.010829
# Epoch 145, Average Training Loss: 0.011359, Average Validation Loss: 0.010762
# Epoch 146, Average Training Loss: 0.011318, Average Validation Loss: 0.010708
# Epoch 147, Average Training Loss: 0.011341, Average Validation Loss: 0.010669
# Epoch 148, Average Training Loss: 0.011349, Average Validation Loss: 0.010688
# Epoch 149, Average Training Loss: 0.011277, Average Validation Loss: 0.010789
# Epoch 00149: reducing learning rate of group 0 to 9.7656e-08.
# Epoch 150, Average Training Loss: 0.011331, Average Validation Loss: 0.010739
# Epoch 151, Average Training Loss: 0.011385, Average Validation Loss: 0.010631
# Epoch 152, Average Training Loss: 0.011276, Average Validation Loss: 0.010760
# Epoch 153, Average Training Loss: 0.011372, Average Validation Loss: 0.010711
# Epoch 154, Average Training Loss: 0.011344, Average Validation Loss: 0.010727
# Epoch 155, Average Training Loss: 0.011345, Average Validation Loss: 0.010687
# Epoch 00155: reducing learning rate of group 0 to 4.8828e-08.
# Epoch 156, Average Training Loss: 0.011338, Average Validation Loss: 0.010745
# Epoch 157, Average Training Loss: 0.011314, Average Validation Loss: 0.010820
# Epoch 158, Average Training Loss: 0.011310, Average Validation Loss: 0.010864
# Epoch 159, Average Training Loss: 0.011342, Average Validation Loss: 0.010682
# Epoch 160, Average Training Loss: 0.011317, Average Validation Loss: 0.010672
# Epoch 161, Average Training Loss: 0.011303, Average Validation Loss: 0.010762
# Epoch 00161: reducing learning rate of group 0 to 2.4414e-08.
# Epoch 162, Average Training Loss: 0.011324, Average Validation Loss: 0.010715
# Epoch 163, Average Training Loss: 0.011292, Average Validation Loss: 0.010700
# Epoch 164, Average Training Loss: 0.011329, Average Validation Loss: 0.010719
# Epoch 165, Average Training Loss: 0.011321, Average Validation Loss: 0.010667
# Epoch 166, Average Training Loss: 0.011366, Average Validation Loss: 0.010654
# Epoch 167, Average Training Loss: 0.011341, Average Validation Loss: 0.010830
# Epoch 00167: reducing learning rate of group 0 to 1.2207e-08.
# Epoch 168, Average Training Loss: 0.011288, Average Validation Loss: 0.010671
# Epoch 169, Average Training Loss: 0.011321, Average Validation Loss: 0.010790
# Epoch 170, Average Training Loss: 0.011310, Average Validation Loss: 0.010695
# Epoch 171, Average Training Loss: 0.011299, Average Validation Loss: 0.010769
# Epoch 172, Average Training Loss: 0.011355, Average Validation Loss: 0.010635
# Epoch 173, Average Training Loss: 0.011329, Average Validation Loss: 0.010703
# Epoch 174, Average Training Loss: 0.011369, Average Validation Loss: 0.010795
# Epoch 175, Average Training Loss: 0.011351, Average Validation Loss: 0.010648
# Epoch 176, Average Training Loss: 0.011306, Average Validation Loss: 0.010780
# Epoch 177, Average Training Loss: 0.011380, Average Validation Loss: 0.010669
# Epoch 178, Average Training Loss: 0.011268, Average Validation Loss: 0.010735
# Epoch 179, Average Training Loss: 0.011356, Average Validation Loss: 0.010745
# Epoch 180, Average Training Loss: 0.011293, Average Validation Loss: 0.010695
# Epoch 181, Average Training Loss: 0.011337, Average Validation Loss: 0.010788
# Epoch 182, Average Training Loss: 0.011311, Average Validation Loss: 0.010772
# Epoch 183, Average Training Loss: 0.011384, Average Validation Loss: 0.010739
# Epoch 184, Average Training Loss: 0.011331, Average Validation Loss: 0.010794
# Epoch 185, Average Training Loss: 0.011330, Average Validation Loss: 0.010725
# Epoch 186, Average Training Loss: 0.011325, Average Validation Loss: 0.010707
# Epoch 187, Average Training Loss: 0.011335, Average Validation Loss: 0.010813
# Epoch 188, Average Training Loss: 0.011314, Average Validation Loss: 0.010723
# Epoch 189, Average Training Loss: 0.011294, Average Validation Loss: 0.010665
# Epoch 190, Average Training Loss: 0.011431, Average Validation Loss: 0.010636
# Epoch 191, Average Training Loss: 0.011286, Average Validation Loss: 0.010662
# Epoch 192, Average Training Loss: 0.011338, Average Validation Loss: 0.010692
# Epoch 193, Average Training Loss: 0.011320, Average Validation Loss: 0.010669
# Early stopping triggered.

# %%
# Plot training and validation loss over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_total_losses) + 1), train_total_losses, label='Training Loss')
plt.plot(range(1, len(val_total_losses) + 1), val_total_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
# Plot reconstruction loss and KL divergence over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Reconstruction Loss')
plt.plot(range(1, len(train_kld_losses) + 1), train_kld_losses, label='KL Divergence')
plt.plot(range(1, len(train_total_losses) + 1), beta * np.array(train_kld_losses), label='Beta * KL Divergence')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Reconstruction Loss and KL Divergence over Epochs')
plt.legend()
plt.show()

# %%
model.eval()
test_loss = 0
with torch.no_grad():
    for data in test_loader:
        x = data[0].to(device, dtype=torch.float)
        recon_batch, mu, logvar, z = model(x)
        loss , _ , _ = loss_function(recon_batch, x, mu, logvar)
        test_loss += loss.item()
avg_test_loss = test_loss / len(test_loader.dataset)
print(f"Average Test Loss: {avg_test_loss:.4f}")
# Out:
# Average Test Loss: 0.0004

# %%
import matplotlib.pyplot as plt

# Function to display original and reconstructed images
def visualize_reconstruction(model, data_loader):
    model.eval()
    with torch.no_grad():
        data = next(iter(data_loader))
        x = data[0].to(device, dtype=torch.float)
        recon_x, _, _ , _ = model(x)
        
        # Move tensors to CPU and convert to numpy
        x = x.cpu().numpy()
        recon_x = recon_x.cpu().numpy()
        
        n = min(x.shape[0], 5)  # Number of samples to display
        for i in range(n):
            fig, axes = plt.subplots(2, 3, figsize=(12, 6))
            for j in range(3):
                axes[0, j].imshow(x[i, j], cmap='viridis')
                axes[0, j].set_title(f'Original - Matrix {j+1}')
                axes[0, j].axis('off')
                axes[1, j].imshow(recon_x[i, j], cmap='viridis')
                axes[1, j].set_title(f'Reconstructed - Matrix {j+1}')
                axes[1, j].axis('off')
            plt.show()

# Visualize reconstructions on test data
visualize_reconstruction(model, test_loader)

# %%
# Save the trained model
model_save_path = os.path.join(project_dir, 'conv_vae_model.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /home/diego/Escritorio/azheimer/conv_vae_model.pth

# %%
# Load the model
model = ConvVAE(latent_dim=latent_dim).to(device)
model.load_state_dict(torch.load(model_save_path))
model.eval()
# Out:
# ConvVAE(
#   (enc_conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv5): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (fc1): Linear(in_features=4608, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc_mu): Linear(in_features=1024, out_features=30, bias=True)
#   (fc_logvar): Linear(in_features=1024, out_features=30, bias=True)
#   (fc_decode): Linear(in_features=30, out_features=1024, bias=True)
#   (fc_decode2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc_decode3): Linear(in_features=1024, out_features=4608, bias=True)
#   (dec_conv1): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (output_padding): ReflectionPad2d((-5, -6, -5, -6))
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model.eval()
latents = []
labels = []

with torch.no_grad():
    for data, label in test_loader:
        x = data.to(device, dtype=torch.float)
        mu, logvar = model.encode(x)
        z = model.reparameterize(mu, logvar)
        latents.append(z.cpu())
        labels.extend(label)  # Collect labels

# Concatenate all latent vectors and convert labels to a NumPy array
latents = torch.cat(latents, dim=0).numpy()
labels = np.array(labels)

# %%
from sklearn.manifold import TSNE

# Reduce latent dimensions to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
latents_2d = tsne.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
from sklearn.decomposition import PCA

# Reduce latent dimensions to 2D using PCA
pca = PCA(n_components=2)
latents_2d = pca.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
# Function to extract latent representations and labels for AD and CN subjects
def extract_latents_and_labels(file_paths, model, device):
    latents = []
    labels = []
    
    model.eval()
    with torch.no_grad():
        for fp in file_paths:
            file_name = os.path.basename(fp)
            group = file_name.split('_')[0]
            if group not in ['AD', 'CN']:
                continue  # Skip "Others" category
            label = 1 if group == 'AD' else 0  # Assign labels: AD=1, CN=0
            data = torch.load(fp)
            if isinstance(data, np.ndarray):
                data = torch.tensor(data)
            data = normalize_tensor(data)
            x = data.unsqueeze(0).to(device, dtype=torch.float)  # Add batch dimension
            mu, logvar = model.encode(x)
            z = model.reparameterize(mu, logvar)
            latents.append(mu.cpu().numpy().squeeze()) # Squeeze to remove batch dimension, mu instead of z
            labels.append(label)
    return np.array(latents), np.array(labels)

# %%
# Combine train and validation file paths
train_val_set = train_set + val_set

# Extract latents and labels for training (train + validation sets)
X_train, y_train = extract_latents_and_labels(train_val_set, model, device)

# Extract latents and labels for test set
X_test, y_test = extract_latents_and_labels(test_set, model, device)

# Print the shapes
print(f"Training data shape: {X_train.shape}, Training labels shape: {y_train.shape}")
print(f"Test data shape: {X_test.shape}, Test labels shape: {y_test.shape}")
# Out:
# Training data shape: (153, 30), Training labels shape: (153,)
# Test data shape: (31, 30), Test labels shape: (31,)

# %%
from collections import Counter

print(f"Training labels distribution: {Counter(y_train)}")
print(f"Test labels distribution: {Counter(y_test)}")
# Out:
# Training labels distribution: Counter({1: 80, 0: 73})
# Test labels distribution: Counter({0: 16, 1: 15})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
)

# Define classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM (Linear Kernel)": SVC(kernel='linear', probability=True),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "Neural Network": MLPClassifier(hidden_layer_sizes=(50,), max_iter=1000),
}

# Dictionary to store performance metrics
performance_metrics = {}

# Train and evaluate each classifier
for name, clf in classifiers.items():
    # Train the classifier
    clf.fit(X_train, y_train)
    # Predict on test set
    y_pred = clf.predict(X_test)
    y_proba = clf.predict_proba(X_test)[:, 1] if hasattr(clf, "predict_proba") else None
    # Compute metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
    # Store metrics
    performance_metrics[name] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "ROC AUC": roc_auc,
    }
    # Print classification report
    print(f"Classifier: {name}")
    print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
    print("-" * 50)
# Out:
# Classifier: Logistic Regression
#               precision    recall  f1-score   support
#
#           CN       0.57      0.50      0.53        16
#           AD       0.53      0.60      0.56        15
#
#     accuracy                           0.55        31
#    macro avg       0.55      0.55      0.55        31
# weighted avg       0.55      0.55      0.55        31
#
# --------------------------------------------------
# Classifier: SVM (Linear Kernel)
#               precision    recall  f1-score   support
#
#           CN       0.56      0.56      0.56        16
#           AD       0.53      0.53      0.53        15
#
#     accuracy                           0.55        31
#    macro avg       0.55      0.55      0.55        31
# weighted avg       0.55      0.55      0.55        31
#
# --------------------------------------------------
# Classifier: Random Forest
#               precision    recall  f1-score   support
#
#           CN       0.69      0.69      0.69        16
#           AD       0.67      0.67      0.67        15
#
#     accuracy                           0.68        31
#    macro avg       0.68      0.68      0.68        31
# weighted avg       0.68      0.68      0.68        31
#
# --------------------------------------------------
# Classifier: k-NN
#               precision    recall  f1-score   support
#
#           CN       0.65      0.81      0.72        16
#           AD       0.73      0.53      0.62        15
#
#     accuracy                           0.68        31
#    macro avg       0.69      0.67      0.67        31
# weighted avg       0.69      0.68      0.67        31
#
# --------------------------------------------------
# Classifier: Gradient Boosting
#               precision    recall  f1-score   support
#
#           CN       0.61      0.69      0.65        16
#           AD       0.62      0.53      0.57        15
#
#     accuracy                           0.61        31
#    macro avg       0.61      0.61      0.61        31
# weighted avg       0.61      0.61      0.61        31
#
# --------------------------------------------------
# Classifier: Neural Network
#               precision    recall  f1-score   support
#
#           CN       0.56      0.56      0.56        16
#           AD       0.53      0.53      0.53        15
#
#     accuracy                           0.55        31
#    macro avg       0.55      0.55      0.55        31
# weighted avg       0.55      0.55      0.55        31
#
# --------------------------------------------------

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")

# Evaluate the best model
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
# Best parameters: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#           CN       0.61      0.69      0.65        16
#           AD       0.62      0.53      0.57        15
#
#     accuracy                           0.61        31
#    macro avg       0.61      0.61      0.61        31
# weighted avg       0.61      0.61      0.61        31

# %%
import matplotlib.pyplot as plt

# Assuming you have trained a Random Forest classifier named 'best_rf'
importances = best_rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices], color="r", align="center")
plt.xticks(range(X_train.shape[1]), indices)
plt.xlabel("Feature Index")
plt.ylabel("Importance")
plt.show()
