# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Set paths
project_dir = '/home/diego/Escritorio/azheimer/'  # Adjust to your path
csv_path = os.path.join(project_dir, 'DataBaseSubjects.csv')
tensor_data_dir = os.path.join(project_dir, 'TensorData')

# Load the CSV file
subjects_df = pd.read_csv(csv_path)

# Calculate the median age and print it
median_age = subjects_df['Age'].median()
print(f"Median Age: {median_age}")

# Plot the age distribution
plt.figure(figsize=(8, 6))
sns.histplot(subjects_df['Age'], bins=20, kde=True, color='blue')
plt.axvline(median_age, color='red', linestyle='--', label=f'Median Age: {median_age}')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Plot the sex distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Plot the distribution of AD, CN, and Others
plt.figure(figsize=(8, 6))
sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
plt.title('AD, CN, and Others Distribution')
plt.xlabel('Research Group')
plt.ylabel('Count')
plt.show()

# Group subjects by Research Group and Sex
grouped_data = subjects_df.groupby(['ResearchGroup', 'Sex']).size().unstack().fillna(0)
print(grouped_data)

# Initialize dictionaries for storing tensor paths by group and sex
tensor_groups = {
    'AD_men': [],
    'AD_women': [],
    'CN_men': [],
    'CN_women': [],
    'Other_men': [],
    'Other_women': []
}

# Iterate over subjects and assign tensors to groups
for subject_id in subjects_df['SubjectID']:
    group = subjects_df[subjects_df['SubjectID'] == subject_id]['ResearchGroup'].values[0]
    sex = subjects_df[subjects_df['SubjectID'] == subject_id]['Sex'].values[0]
    file_name = f'{group}_tensor_{subject_id}.pt'
    file_path = os.path.join(tensor_data_dir, file_name)
    
    if os.path.exists(file_path):
        if group == 'AD':
            if sex == 'M':
                tensor_groups['AD_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['AD_women'].append(file_path)
        elif group == 'CN':
            if sex == 'M':
                tensor_groups['CN_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['CN_women'].append(file_path)
        else:  # Others
            if sex == 'M':
                tensor_groups['Other_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['Other_women'].append(file_path)

# Print the number of subjects in each group
for key, value in tensor_groups.items():
    print(f'{key}: {len(value)} subjects')

# Split data into train, validation, and test sets with equal proportions
def split_data(tensors, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    np.random.shuffle(tensors)
    n_total = len(tensors)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    
    train_set = tensors[:n_train]
    val_set = tensors[n_train:n_train + n_val]
    test_set = tensors[n_train + n_val:]
    
    return train_set, val_set, test_set

# Initialize lists for train, validation, and test sets
train_set, val_set, test_set = [], [], []

# Combine groups ensuring equal proportions of gender and research groups
for group in tensor_groups:
    train, val, test = split_data(tensor_groups[group])
    train_set.extend(train)
    val_set.extend(val)
    test_set.extend(test)

# Print final counts of train, validation, and test sets
print(f"Train set: {len(train_set)} subjects")
print(f"Validation set: {len(val_set)} subjects")
print(f"Test set: {len(test_set)} subjects")
# Out:
# Median Age: 74.25
# /tmp/ipykernel_10799/3646991604.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
# /tmp/ipykernel_10799/3646991604.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
# Sex             F   M
# ResearchGroup
# AD             40  55
# CN             52  37
# EMCI            8  10
# LMCI           23  32
# MCI            42  53
# AD_men: 55 subjects
# AD_women: 40 subjects
# CN_men: 37 subjects
# CN_women: 52 subjects
# Other_men: 95 subjects
# Other_women: 73 subjects
# Train set: 244 subjects
# Validation set: 50 subjects
# Test set: 58 subjects

# %%
# Function to normalize each channel of the tensor between 0 and 1
def normalize_tensor(tensor):
    normalized_tensor = torch.zeros_like(tensor)
    for i in range(tensor.shape[0]):  # For each channel
        channel_data = tensor[i]
        min_val = channel_data.min()
        max_val = channel_data.max()
        # Avoid division by zero
        if max_val - min_val != 0:
            normalized_tensor[i] = (channel_data - min_val) / (max_val - min_val)
        else:
            normalized_tensor[i] = channel_data - min_val
    return normalized_tensor

# %%
# Load the tensors and create datasets
def load_tensors(file_paths):
    tensors = []
    for fp in file_paths:
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        tensors.append(data)
    return torch.stack(tensors)


# Load data for train, validation, and test sets
train_data = load_tensors(train_set)
val_data = load_tensors(val_set)
test_data = load_tensors(test_set)

# Print final dataset shapes
print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")

import torch

# Assuming train_set, val_set, test_set are your datasets (could be PyTorch Datasets or DataLoaders)
torch.save(train_data, 'sets/train_set.pt')
torch.save(val_data, 'sets/val_set.pt')
torch.save(test_data, 'sets/test_set.pt')
# Out:
# Train data shape: torch.Size([244, 3, 116, 116])
# Validation data shape: torch.Size([50, 3, 116, 116])
# Test data shape: torch.Size([58, 3, 116, 116])

# %%
import random
import matplotlib.pyplot as plt

# Function to plot the three matrices for a given subject's tensor
def plot_matrices(tensor, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    matrix_titles = ['Correlation Matrix', 'Mutual Information Matrix', 'Granger Causality Matrix']

    # Loop through the three matrices
    for i in range(3):
        ax = axes[i]
        cax = ax.matshow(tensor[i], cmap='viridis')
        fig.colorbar(cax, ax=ax)
        ax.set_title(f'{title_prefix} - {matrix_titles[i]}')
        ax.set_xlabel('ROIs')
        ax.set_ylabel('ROIs')

    plt.tight_layout()
    plt.show()

# Choose a random subject from each dataset and plot their matrices
def plot_random_subject_from_dataset(dataset, dataset_name):
    random_subject = random.choice(dataset)
    print(f"Plotting matrices for a random subject from {dataset_name} dataset: {random_subject}")
    
    # Load the tensor for the randomly selected subject
    tensor = torch.load(random_subject)
    
    # Plot the matrices
    plot_matrices(tensor, dataset_name)

# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_set, 'Train')
plot_random_subject_from_dataset(val_set, 'Validation')
plot_random_subject_from_dataset(test_set, 'Test')
# Out:
# Plotting matrices for a random subject from Train dataset: /home/diego/Escritorio/azheimer/TensorData/CN_tensor_301_S_6224.pt
# Plotting matrices for a random subject from Validation dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_003_S_6833.pt
# Plotting matrices for a random subject from Test dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_130_S_4730.pt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ConvVAE(nn.Module):
    def __init__(self, latent_dim=2, hidden_dim=1024):  # Added hidden_dim
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim  # New hidden dimension for the linear layers
        self.dropout_rate = 0.2  # Dropout rate

        # Encoder Layers
        self.enc_conv1 = nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1)    # Output: (64, 58, 58)
        self.enc_conv2 = nn.Conv2d(64, 128, 4, 2, 1)  # Output: (128, 29, 29)
        self.enc_conv3 = nn.Conv2d(128, 256, 4, 2, 1)  # Output: (256, 14, 14)
        self.enc_conv4 = nn.Conv2d(256, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.enc_conv5 = nn.Conv2d(512, 512, 4, 2, 1)  # Output: (512, 3, 3)

        # Compute the size after convolutional layers to flatten
        self.flatten_size = 512 * 3 * 3  # Updated to 4608

        # Linear layers after the convolutional layers in the encoder
        self.fc1 = nn.Linear(self.flatten_size, self.hidden_dim)  # New linear layer
        self.fc2 = nn.Linear(self.hidden_dim, self.hidden_dim)    # Second linear layer
        
        # Latent space
        self.fc_mu = nn.Linear(self.hidden_dim, latent_dim)  # Adjusted to latent space
        self.fc_logvar = nn.Linear(self.hidden_dim, latent_dim)

        # Decoder Layers
        self.fc_decode = nn.Linear(latent_dim, self.hidden_dim)
        self.fc_decode2 = nn.Linear(self.hidden_dim, self.hidden_dim)  # Second linear layer
        self.fc_decode3 = nn.Linear(self.hidden_dim, self.flatten_size)  # Map back to the flattened convolutional output

        self.dec_conv1 = nn.ConvTranspose2d(512, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.dec_conv2 = nn.ConvTranspose2d(512, 256, 4, 2, 1)  # Output: (256, 15, 15)
        self.dec_conv3 = nn.ConvTranspose2d(256, 128, 4, 2, 1)  # Output: (128, 31, 31)
        self.dec_conv4 = nn.ConvTranspose2d(128, 64, 4, 2, 1)   # Output: (64, 63, 63)
        self.dec_conv5 = nn.ConvTranspose2d(64, 3, 4, 2, 1)     # Output: (3, 127, 127)

        # Adjust output size to (3, 116, 116)
        self.output_padding = nn.ReflectionPad2d((-5, -6, -5, -6))  # Crop to (3, 116, 116)

        # Dropout layer
        self.dropout = nn.Dropout(self.dropout_rate)

    def encode(self, x):
        # Apply convolutional layers
        x1 = F.relu(self.enc_conv1(x))
        x2 = F.relu(self.enc_conv2(x1))
        x3 = F.relu(self.enc_conv3(x2))
        x4 = F.relu(self.enc_conv4(x3))
        x5 = F.relu(self.enc_conv5(x4))
        x5 = x5.view(x.size(0), -1)  # Flatten the output
        
        # Apply fully connected layers
        x5 = F.relu(self.fc1(x5))  # First linear layer
        x5 = self.dropout(x5)
        x5 = F.relu(self.fc2(x5))  # Second linear layer

        # Get the latent space variables
        mu = self.fc_mu(x5)
        logvar = self.fc_logvar(x5)
        return mu, logvar

    def decode(self, z):
        # Apply fully connected layers
        x = F.relu(self.fc_decode(z))  # First linear layer in decoder
        x = F.relu(self.fc_decode2(x))  # Second linear layer in decoder
        x = F.relu(self.fc_decode3(x))  # Map to the size before deconvolution
        x = x.view(z.size(0), 512, 3, 3)  # Reshape to convolutional output dimensions
        
        # Apply transposed convolutional layers to upsample
        x = F.relu(self.dec_conv1(x))
        x = F.relu(self.dec_conv2(x))
        x = F.relu(self.dec_conv3(x))
        x = F.relu(self.dec_conv4(x))
        x = torch.sigmoid(self.dec_conv5(x))
        x = F.interpolate(x, size=(116, 116), mode='bilinear', align_corners=False)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar, z

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

# %%
def loss_function(recon_x, x, mu, logvar, beta=1):
    # Reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='mean')

    # KL Divergence (normalized per batch)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    KLD = KLD / x.size(0)  # Normalize KLD per batch

    # Total loss
    total_loss = recon_loss + beta * KLD

    return total_loss, recon_loss.item(), KLD.item()

# %%
from torch.utils.data import Dataset, DataLoader

class CustomTensorDataset(Dataset):
    def __init__(self, file_paths):
        self.file_paths = file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        fp = self.file_paths[idx]
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        # Extract the label from the file name
        file_name = os.path.basename(fp)
        # Expected format: '{group}_tensor_{subject_id}.pt'
        group = file_name.split('_')[0]
        # Map group to labels
        if group in ['AD', 'CN']:
            label = group
        else:
            label = 'Others'
        return data, label

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create datasets
train_dataset = TensorDataset(train_data)
val_dataset = TensorDataset(val_data)
# Create the test dataset with labels
test_dataset = CustomTensorDataset(test_set)

# Create data loaders
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Create the data loader
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize model
latent_dim = 30  # You can adjust the size of the latent space
hidden_dim= 1024*2  # Hidden dimension for the linear layers
model = ConvVAE(latent_dim=latent_dim).to(device)

# Optimizer with L2 regularization (weight decay)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-6)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
# Out:
# Using device: cuda

# %%
# Early stopping parameters
early_stopping_patience = 50
best_val_loss = float('inf')
epochs_without_improvement = 0
model_save_path = os.path.join(project_dir, 'best_beta_vae_model.pth')

# %%
# Lists to store losses
train_total_losses = []
val_total_losses = []
train_recon_losses = []
train_kld_losses = []

num_epochs = 500  # Adjust the number of epochs as needed
beta = 100  # Set the beta value for the loss function

for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0
    train_recon_loss = 0
    train_kld_loss = 0

    for data in train_loader:
        x = data[0].to(device, dtype=torch.float)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar, _ = model(x)
        loss, recon_loss, kld_loss = loss_function(recon_batch, x, mu, logvar, beta=beta)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * x.size(0)  # Multiply by batch size
        train_recon_loss += recon_loss * x.size(0)
        train_kld_loss += kld_loss * x.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_recon_loss = train_recon_loss / len(train_loader.dataset)
    avg_train_kld_loss = train_kld_loss / len(train_loader.dataset)

    train_total_losses.append(avg_train_loss)
    train_recon_losses.append(avg_train_recon_loss)
    train_kld_losses.append(avg_train_kld_loss)
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data in val_loader:
            x = data[0].to(device, dtype=torch.float)
            recon_batch, mu, logvar, _ = model(x)
            loss, _, _ = loss_function(recon_batch, x, mu, logvar, beta=beta)
            val_loss += loss.item() * x.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_total_losses.append(avg_val_loss)
    
    print(f"Epoch {epoch}, Average Training Loss: {avg_train_loss:.6f}, Average Validation Loss: {avg_val_loss:.6f}")
    
    # Step the scheduler
    scheduler.step(avg_val_loss)
    
    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        # Save the model
        torch.save(model.state_dict(), model_save_path)
        print(f"Validation loss improved. Model saved to {model_save_path}")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= early_stopping_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1, Average Training Loss: 0.440137, Average Validation Loss: 0.149133
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 2, Average Training Loss: 0.141759, Average Validation Loss: 0.085016
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 3, Average Training Loss: 0.057325, Average Validation Loss: 0.032026
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 4, Average Training Loss: 0.036376, Average Validation Loss: 0.029262
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 5, Average Training Loss: 0.033104, Average Validation Loss: 0.027488
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 6, Average Training Loss: 0.030300, Average Validation Loss: 0.025311
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 7, Average Training Loss: 0.028362, Average Validation Loss: 0.024216
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 8, Average Training Loss: 0.027008, Average Validation Loss: 0.023225
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 9, Average Training Loss: 0.025702, Average Validation Loss: 0.022063
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 10, Average Training Loss: 0.024319, Average Validation Loss: 0.020761
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 11, Average Training Loss: 0.022816, Average Validation Loss: 0.019516
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 12, Average Training Loss: 0.021799, Average Validation Loss: 0.018750
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 13, Average Training Loss: 0.020877, Average Validation Loss: 0.018288
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 14, Average Training Loss: 0.020290, Average Validation Loss: 0.018008
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 15, Average Training Loss: 0.019827, Average Validation Loss: 0.017546
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 16, Average Training Loss: 0.019221, Average Validation Loss: 0.017151
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 17, Average Training Loss: 0.018774, Average Validation Loss: 0.016603
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 18, Average Training Loss: 0.018090, Average Validation Loss: 0.016078
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 19, Average Training Loss: 0.017245, Average Validation Loss: 0.015339
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 20, Average Training Loss: 0.016644, Average Validation Loss: 0.014789
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 21, Average Training Loss: 0.015950, Average Validation Loss: 0.014183
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 22, Average Training Loss: 0.015280, Average Validation Loss: 0.013683
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 23, Average Training Loss: 0.014825, Average Validation Loss: 0.013445
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 24, Average Training Loss: 0.014500, Average Validation Loss: 0.013058
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 25, Average Training Loss: 0.014078, Average Validation Loss: 0.012987
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 26, Average Training Loss: 0.013868, Average Validation Loss: 0.013005
# Epoch 27, Average Training Loss: 0.013789, Average Validation Loss: 0.012769
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 28, Average Training Loss: 0.013477, Average Validation Loss: 0.012637
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 29, Average Training Loss: 0.013323, Average Validation Loss: 0.012574
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 30, Average Training Loss: 0.013193, Average Validation Loss: 0.012299
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 31, Average Training Loss: 0.012979, Average Validation Loss: 0.012314
# Epoch 32, Average Training Loss: 0.012851, Average Validation Loss: 0.012207
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 33, Average Training Loss: 0.012823, Average Validation Loss: 0.012342
# Epoch 34, Average Training Loss: 0.012773, Average Validation Loss: 0.012251
# Epoch 35, Average Training Loss: 0.012604, Average Validation Loss: 0.012226
# Epoch 36, Average Training Loss: 0.012593, Average Validation Loss: 0.012368
# Epoch 37, Average Training Loss: 0.012404, Average Validation Loss: 0.012040
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 38, Average Training Loss: 0.012426, Average Validation Loss: 0.012073
# Epoch 39, Average Training Loss: 0.012316, Average Validation Loss: 0.012203
# Epoch 40, Average Training Loss: 0.012245, Average Validation Loss: 0.011986
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 41, Average Training Loss: 0.012150, Average Validation Loss: 0.012028
# Epoch 42, Average Training Loss: 0.012245, Average Validation Loss: 0.011880
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 43, Average Training Loss: 0.012130, Average Validation Loss: 0.011989
# Epoch 44, Average Training Loss: 0.012168, Average Validation Loss: 0.011841
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 45, Average Training Loss: 0.011973, Average Validation Loss: 0.011914
# Epoch 46, Average Training Loss: 0.012004, Average Validation Loss: 0.011869
# Epoch 47, Average Training Loss: 0.012133, Average Validation Loss: 0.011894
# Epoch 48, Average Training Loss: 0.011909, Average Validation Loss: 0.012034
# Epoch 49, Average Training Loss: 0.011809, Average Validation Loss: 0.011846
# Epoch 50, Average Training Loss: 0.011755, Average Validation Loss: 0.011737
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 51, Average Training Loss: 0.011878, Average Validation Loss: 0.011820
# Epoch 52, Average Training Loss: 0.011689, Average Validation Loss: 0.011685
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 53, Average Training Loss: 0.011739, Average Validation Loss: 0.011787
# Epoch 54, Average Training Loss: 0.011676, Average Validation Loss: 0.011724
# Epoch 55, Average Training Loss: 0.011670, Average Validation Loss: 0.011888
# Epoch 56, Average Training Loss: 0.011722, Average Validation Loss: 0.011692
# Epoch 57, Average Training Loss: 0.011674, Average Validation Loss: 0.011665
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 58, Average Training Loss: 0.011609, Average Validation Loss: 0.011673
# Epoch 59, Average Training Loss: 0.011473, Average Validation Loss: 0.011802
# Epoch 60, Average Training Loss: 0.011579, Average Validation Loss: 0.011582
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 61, Average Training Loss: 0.011493, Average Validation Loss: 0.011606
# Epoch 62, Average Training Loss: 0.011492, Average Validation Loss: 0.011878
# Epoch 63, Average Training Loss: 0.011474, Average Validation Loss: 0.011804
# Epoch 64, Average Training Loss: 0.011496, Average Validation Loss: 0.011554
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 65, Average Training Loss: 0.011462, Average Validation Loss: 0.011700
# Epoch 66, Average Training Loss: 0.011394, Average Validation Loss: 0.011659
# Epoch 67, Average Training Loss: 0.011397, Average Validation Loss: 0.011618
# Epoch 68, Average Training Loss: 0.011377, Average Validation Loss: 0.011595
# Epoch 69, Average Training Loss: 0.011293, Average Validation Loss: 0.011608
# Epoch 70, Average Training Loss: 0.011301, Average Validation Loss: 0.011499
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 71, Average Training Loss: 0.011322, Average Validation Loss: 0.011601
# Epoch 72, Average Training Loss: 0.011336, Average Validation Loss: 0.011640
# Epoch 73, Average Training Loss: 0.011347, Average Validation Loss: 0.011512
# Epoch 74, Average Training Loss: 0.011286, Average Validation Loss: 0.011484
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 75, Average Training Loss: 0.011236, Average Validation Loss: 0.011563
# Epoch 76, Average Training Loss: 0.011222, Average Validation Loss: 0.011425
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 77, Average Training Loss: 0.011212, Average Validation Loss: 0.011531
# Epoch 78, Average Training Loss: 0.011251, Average Validation Loss: 0.011528
# Epoch 79, Average Training Loss: 0.011200, Average Validation Loss: 0.011334
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 80, Average Training Loss: 0.011160, Average Validation Loss: 0.011370
# Epoch 81, Average Training Loss: 0.011232, Average Validation Loss: 0.011437
# Epoch 82, Average Training Loss: 0.011228, Average Validation Loss: 0.011489
# Epoch 83, Average Training Loss: 0.011155, Average Validation Loss: 0.011365
# Epoch 84, Average Training Loss: 0.011114, Average Validation Loss: 0.011622
# Epoch 85, Average Training Loss: 0.011166, Average Validation Loss: 0.011353
# Epoch 00085: reducing learning rate of group 0 to 5.0000e-05.
# Epoch 86, Average Training Loss: 0.011056, Average Validation Loss: 0.011409
# Epoch 87, Average Training Loss: 0.011034, Average Validation Loss: 0.011342
# Epoch 88, Average Training Loss: 0.011006, Average Validation Loss: 0.011364
# Epoch 89, Average Training Loss: 0.011047, Average Validation Loss: 0.011394
# Epoch 90, Average Training Loss: 0.011031, Average Validation Loss: 0.011408
# Epoch 91, Average Training Loss: 0.010992, Average Validation Loss: 0.011437
# Epoch 00091: reducing learning rate of group 0 to 2.5000e-05.
# Epoch 92, Average Training Loss: 0.011027, Average Validation Loss: 0.011375
# Epoch 93, Average Training Loss: 0.010964, Average Validation Loss: 0.011420
# Epoch 94, Average Training Loss: 0.011010, Average Validation Loss: 0.011421
# Epoch 95, Average Training Loss: 0.010987, Average Validation Loss: 0.011393
# Epoch 96, Average Training Loss: 0.010990, Average Validation Loss: 0.011386
# Epoch 97, Average Training Loss: 0.011035, Average Validation Loss: 0.011470
# Epoch 00097: reducing learning rate of group 0 to 1.2500e-05.
# Epoch 98, Average Training Loss: 0.010965, Average Validation Loss: 0.011347
# Epoch 99, Average Training Loss: 0.010942, Average Validation Loss: 0.011336
# Epoch 100, Average Training Loss: 0.011011, Average Validation Loss: 0.011415
# Epoch 101, Average Training Loss: 0.010961, Average Validation Loss: 0.011401
# Epoch 102, Average Training Loss: 0.010953, Average Validation Loss: 0.011341
# Epoch 103, Average Training Loss: 0.010994, Average Validation Loss: 0.011367
# Epoch 00103: reducing learning rate of group 0 to 6.2500e-06.
# Epoch 104, Average Training Loss: 0.011008, Average Validation Loss: 0.011340
# Epoch 105, Average Training Loss: 0.010953, Average Validation Loss: 0.011342
# Epoch 106, Average Training Loss: 0.010947, Average Validation Loss: 0.011331
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 107, Average Training Loss: 0.010996, Average Validation Loss: 0.011321
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 108, Average Training Loss: 0.010996, Average Validation Loss: 0.011353
# Epoch 109, Average Training Loss: 0.010971, Average Validation Loss: 0.011356
# Epoch 110, Average Training Loss: 0.010996, Average Validation Loss: 0.011331
# Epoch 111, Average Training Loss: 0.010993, Average Validation Loss: 0.011428
# Epoch 112, Average Training Loss: 0.010992, Average Validation Loss: 0.011251
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 113, Average Training Loss: 0.010960, Average Validation Loss: 0.011380
# Epoch 114, Average Training Loss: 0.010972, Average Validation Loss: 0.011248
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 115, Average Training Loss: 0.010960, Average Validation Loss: 0.011404
# Epoch 116, Average Training Loss: 0.010953, Average Validation Loss: 0.011381
# Epoch 117, Average Training Loss: 0.010979, Average Validation Loss: 0.011314
# Epoch 118, Average Training Loss: 0.010982, Average Validation Loss: 0.011419
# Epoch 119, Average Training Loss: 0.010941, Average Validation Loss: 0.011400
# Epoch 120, Average Training Loss: 0.010947, Average Validation Loss: 0.011296
# Epoch 00120: reducing learning rate of group 0 to 3.1250e-06.
# Epoch 121, Average Training Loss: 0.010959, Average Validation Loss: 0.011292
# Epoch 122, Average Training Loss: 0.010947, Average Validation Loss: 0.011322
# Epoch 123, Average Training Loss: 0.010959, Average Validation Loss: 0.011338
# Epoch 124, Average Training Loss: 0.010982, Average Validation Loss: 0.011301
# Epoch 125, Average Training Loss: 0.010929, Average Validation Loss: 0.011277
# Epoch 126, Average Training Loss: 0.010978, Average Validation Loss: 0.011311
# Epoch 00126: reducing learning rate of group 0 to 1.5625e-06.
# Epoch 127, Average Training Loss: 0.010923, Average Validation Loss: 0.011336
# Epoch 128, Average Training Loss: 0.010931, Average Validation Loss: 0.011347
# Epoch 129, Average Training Loss: 0.010925, Average Validation Loss: 0.011321
# Epoch 130, Average Training Loss: 0.010988, Average Validation Loss: 0.011411
# Epoch 131, Average Training Loss: 0.010934, Average Validation Loss: 0.011301
# Epoch 132, Average Training Loss: 0.010959, Average Validation Loss: 0.011374
# Epoch 00132: reducing learning rate of group 0 to 7.8125e-07.
# Epoch 133, Average Training Loss: 0.010955, Average Validation Loss: 0.011318
# Epoch 134, Average Training Loss: 0.010957, Average Validation Loss: 0.011340
# Epoch 135, Average Training Loss: 0.010942, Average Validation Loss: 0.011353
# Epoch 136, Average Training Loss: 0.010983, Average Validation Loss: 0.011358
# Epoch 137, Average Training Loss: 0.010982, Average Validation Loss: 0.011245
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 138, Average Training Loss: 0.010919, Average Validation Loss: 0.011427
# Epoch 139, Average Training Loss: 0.010977, Average Validation Loss: 0.011301
# Epoch 140, Average Training Loss: 0.010927, Average Validation Loss: 0.011332
# Epoch 141, Average Training Loss: 0.010929, Average Validation Loss: 0.011388
# Epoch 142, Average Training Loss: 0.010925, Average Validation Loss: 0.011358
# Epoch 143, Average Training Loss: 0.010957, Average Validation Loss: 0.011373
# Epoch 00143: reducing learning rate of group 0 to 3.9063e-07.
# Epoch 144, Average Training Loss: 0.010954, Average Validation Loss: 0.011315
# Epoch 145, Average Training Loss: 0.010925, Average Validation Loss: 0.011252
# Epoch 146, Average Training Loss: 0.010958, Average Validation Loss: 0.011292
# Epoch 147, Average Training Loss: 0.010952, Average Validation Loss: 0.011306
# Epoch 148, Average Training Loss: 0.010962, Average Validation Loss: 0.011311
# Epoch 149, Average Training Loss: 0.010927, Average Validation Loss: 0.011345
# Epoch 00149: reducing learning rate of group 0 to 1.9531e-07.
# Epoch 150, Average Training Loss: 0.010940, Average Validation Loss: 0.011329
# Epoch 151, Average Training Loss: 0.010945, Average Validation Loss: 0.011386
# Epoch 152, Average Training Loss: 0.010980, Average Validation Loss: 0.011331
# Epoch 153, Average Training Loss: 0.010918, Average Validation Loss: 0.011339
# Epoch 154, Average Training Loss: 0.010927, Average Validation Loss: 0.011348
# Epoch 155, Average Training Loss: 0.010938, Average Validation Loss: 0.011362
# Epoch 00155: reducing learning rate of group 0 to 9.7656e-08.
# Epoch 156, Average Training Loss: 0.010941, Average Validation Loss: 0.011350
# Epoch 157, Average Training Loss: 0.010931, Average Validation Loss: 0.011352
# Epoch 158, Average Training Loss: 0.010930, Average Validation Loss: 0.011286
# Epoch 159, Average Training Loss: 0.010967, Average Validation Loss: 0.011404
# Epoch 160, Average Training Loss: 0.010963, Average Validation Loss: 0.011285
# Epoch 161, Average Training Loss: 0.010970, Average Validation Loss: 0.011295
# Epoch 00161: reducing learning rate of group 0 to 4.8828e-08.
# Epoch 162, Average Training Loss: 0.010912, Average Validation Loss: 0.011242
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 163, Average Training Loss: 0.010979, Average Validation Loss: 0.011343
# Epoch 164, Average Training Loss: 0.010929, Average Validation Loss: 0.011289
# Epoch 165, Average Training Loss: 0.010948, Average Validation Loss: 0.011451
# Epoch 166, Average Training Loss: 0.010944, Average Validation Loss: 0.011362
# Epoch 167, Average Training Loss: 0.010954, Average Validation Loss: 0.011299
# Epoch 168, Average Training Loss: 0.010975, Average Validation Loss: 0.011266
# Epoch 00168: reducing learning rate of group 0 to 2.4414e-08.
# Epoch 169, Average Training Loss: 0.010959, Average Validation Loss: 0.011322
# Epoch 170, Average Training Loss: 0.010979, Average Validation Loss: 0.011321
# Epoch 171, Average Training Loss: 0.010931, Average Validation Loss: 0.011402
# Epoch 172, Average Training Loss: 0.010946, Average Validation Loss: 0.011327
# Epoch 173, Average Training Loss: 0.010920, Average Validation Loss: 0.011335
# Epoch 174, Average Training Loss: 0.010931, Average Validation Loss: 0.011330
# Epoch 00174: reducing learning rate of group 0 to 1.2207e-08.
# Epoch 175, Average Training Loss: 0.010967, Average Validation Loss: 0.011391
# Epoch 176, Average Training Loss: 0.010934, Average Validation Loss: 0.011299
# Epoch 177, Average Training Loss: 0.010944, Average Validation Loss: 0.011300
# Epoch 178, Average Training Loss: 0.010987, Average Validation Loss: 0.011318
# Epoch 179, Average Training Loss: 0.010980, Average Validation Loss: 0.011361
# Epoch 180, Average Training Loss: 0.010924, Average Validation Loss: 0.011357
# Epoch 181, Average Training Loss: 0.010933, Average Validation Loss: 0.011424
# Epoch 182, Average Training Loss: 0.010952, Average Validation Loss: 0.011342
# Epoch 183, Average Training Loss: 0.010957, Average Validation Loss: 0.011364
# Epoch 184, Average Training Loss: 0.010965, Average Validation Loss: 0.011291
# Epoch 185, Average Training Loss: 0.010950, Average Validation Loss: 0.011316
# Epoch 186, Average Training Loss: 0.010960, Average Validation Loss: 0.011363
# Epoch 187, Average Training Loss: 0.010939, Average Validation Loss: 0.011239
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 188, Average Training Loss: 0.010916, Average Validation Loss: 0.011265
# Epoch 189, Average Training Loss: 0.010943, Average Validation Loss: 0.011285
# Epoch 190, Average Training Loss: 0.010945, Average Validation Loss: 0.011290
# Epoch 191, Average Training Loss: 0.010950, Average Validation Loss: 0.011320
# Epoch 192, Average Training Loss: 0.010952, Average Validation Loss: 0.011299
# Epoch 193, Average Training Loss: 0.010958, Average Validation Loss: 0.011344
# Epoch 194, Average Training Loss: 0.010951, Average Validation Loss: 0.011362
# Epoch 195, Average Training Loss: 0.010980, Average Validation Loss: 0.011261
# Epoch 196, Average Training Loss: 0.010967, Average Validation Loss: 0.011288
# Epoch 197, Average Training Loss: 0.010923, Average Validation Loss: 0.011358
# Epoch 198, Average Training Loss: 0.010924, Average Validation Loss: 0.011384
# Epoch 199, Average Training Loss: 0.010962, Average Validation Loss: 0.011325
# Epoch 200, Average Training Loss: 0.010981, Average Validation Loss: 0.011287
# Epoch 201, Average Training Loss: 0.010941, Average Validation Loss: 0.011335
# Epoch 202, Average Training Loss: 0.010942, Average Validation Loss: 0.011314
# Epoch 203, Average Training Loss: 0.010918, Average Validation Loss: 0.011376
# Epoch 204, Average Training Loss: 0.010991, Average Validation Loss: 0.011269
# Epoch 205, Average Training Loss: 0.010938, Average Validation Loss: 0.011432
# Epoch 206, Average Training Loss: 0.010957, Average Validation Loss: 0.011291
# Epoch 207, Average Training Loss: 0.010936, Average Validation Loss: 0.011244
# Epoch 208, Average Training Loss: 0.010982, Average Validation Loss: 0.011302
# Epoch 209, Average Training Loss: 0.010941, Average Validation Loss: 0.011273
# Epoch 210, Average Training Loss: 0.010926, Average Validation Loss: 0.011403
# Epoch 211, Average Training Loss: 0.010945, Average Validation Loss: 0.011319
# Epoch 212, Average Training Loss: 0.010964, Average Validation Loss: 0.011412
# Epoch 213, Average Training Loss: 0.010943, Average Validation Loss: 0.011410
# Epoch 214, Average Training Loss: 0.010950, Average Validation Loss: 0.011388
# Epoch 215, Average Training Loss: 0.010964, Average Validation Loss: 0.011318
# Epoch 216, Average Training Loss: 0.010937, Average Validation Loss: 0.011277
# Epoch 217, Average Training Loss: 0.010955, Average Validation Loss: 0.011379
# Epoch 218, Average Training Loss: 0.010992, Average Validation Loss: 0.011343
# Epoch 219, Average Training Loss: 0.010962, Average Validation Loss: 0.011354
# Epoch 220, Average Training Loss: 0.010947, Average Validation Loss: 0.011395
# Epoch 221, Average Training Loss: 0.010939, Average Validation Loss: 0.011310
# Epoch 222, Average Training Loss: 0.010982, Average Validation Loss: 0.011329
# Epoch 223, Average Training Loss: 0.010925, Average Validation Loss: 0.011341
# Epoch 224, Average Training Loss: 0.010975, Average Validation Loss: 0.011456
# Epoch 225, Average Training Loss: 0.010938, Average Validation Loss: 0.011304
# Epoch 226, Average Training Loss: 0.010988, Average Validation Loss: 0.011297
# Epoch 227, Average Training Loss: 0.010967, Average Validation Loss: 0.011393
# Epoch 228, Average Training Loss: 0.010939, Average Validation Loss: 0.011311
# Epoch 229, Average Training Loss: 0.010967, Average Validation Loss: 0.011410
# Epoch 230, Average Training Loss: 0.010959, Average Validation Loss: 0.011354
# Epoch 231, Average Training Loss: 0.010933, Average Validation Loss: 0.011284
# Epoch 232, Average Training Loss: 0.010949, Average Validation Loss: 0.011337
# Epoch 233, Average Training Loss: 0.010931, Average Validation Loss: 0.011290
# Epoch 234, Average Training Loss: 0.010930, Average Validation Loss: 0.011381
# Epoch 235, Average Training Loss: 0.010975, Average Validation Loss: 0.011295
# Epoch 236, Average Training Loss: 0.010979, Average Validation Loss: 0.011302
# Epoch 237, Average Training Loss: 0.010963, Average Validation Loss: 0.011339
# Early stopping triggered.

# %%
# Plot training and validation loss over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_total_losses) + 1), train_total_losses, label='Training Loss')
plt.plot(range(1, len(val_total_losses) + 1), val_total_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
# Plot reconstruction loss and KL divergence over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Reconstruction Loss')
plt.plot(range(1, len(train_kld_losses) + 1), train_kld_losses, label='KL Divergence')
plt.plot(range(1, len(train_total_losses) + 1), beta * np.array(train_kld_losses), label='Beta * KL Divergence')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Reconstruction Loss and KL Divergence over Epochs')
plt.legend()
plt.show()

# %%
model.eval()
test_loss = 0
with torch.no_grad():
    for data in test_loader:
        x = data[0].to(device, dtype=torch.float)
        recon_batch, mu, logvar, z = model(x)
        loss , _ , _ = loss_function(recon_batch, x, mu, logvar)
        test_loss += loss.item()
avg_test_loss = test_loss / len(test_loader.dataset)
print(f"Average Test Loss: {avg_test_loss:.4f}")
# Out:
# Average Test Loss: 0.0004

# %%
import matplotlib.pyplot as plt

# Function to display original and reconstructed images
def visualize_reconstruction(model, data_loader):
    model.eval()
    with torch.no_grad():
        data = next(iter(data_loader))
        x = data[0].to(device, dtype=torch.float)
        recon_x, _, _ , _ = model(x)
        
        # Move tensors to CPU and convert to numpy
        x = x.cpu().numpy()
        recon_x = recon_x.cpu().numpy()
        
        n = min(x.shape[0], 5)  # Number of samples to display
        for i in range(n):
            fig, axes = plt.subplots(2, 3, figsize=(12, 6))
            for j in range(3):
                axes[0, j].imshow(x[i, j], cmap='viridis')
                axes[0, j].set_title(f'Original - Matrix {j+1}')
                axes[0, j].axis('off')
                axes[1, j].imshow(recon_x[i, j], cmap='viridis')
                axes[1, j].set_title(f'Reconstructed - Matrix {j+1}')
                axes[1, j].axis('off')
            plt.show()

# Visualize reconstructions on test data
visualize_reconstruction(model, test_loader)

# %%
# Save the trained model
model_save_path = os.path.join(project_dir, 'conv_vae_model.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /home/diego/Escritorio/azheimer/conv_vae_model.pth

# %%
# Load the model
model = ConvVAE(latent_dim=latent_dim).to(device)
model.load_state_dict(torch.load(model_save_path))
model.eval()
# Out:
# ConvVAE(
#   (enc_conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv5): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (fc1): Linear(in_features=4608, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc_mu): Linear(in_features=1024, out_features=30, bias=True)
#   (fc_logvar): Linear(in_features=1024, out_features=30, bias=True)
#   (fc_decode): Linear(in_features=30, out_features=1024, bias=True)
#   (fc_decode2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc_decode3): Linear(in_features=1024, out_features=4608, bias=True)
#   (dec_conv1): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (output_padding): ReflectionPad2d((-5, -6, -5, -6))
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model.eval()
latents = []
labels = []

with torch.no_grad():
    for data, label in test_loader:
        x = data.to(device, dtype=torch.float)
        mu, logvar = model.encode(x)
        z = model.reparameterize(mu, logvar)
        latents.append(z.cpu())
        labels.extend(label)  # Collect labels

# Concatenate all latent vectors and convert labels to a NumPy array
latents = torch.cat(latents, dim=0).numpy()
labels = np.array(labels)

# %%
from sklearn.manifold import TSNE

# Reduce latent dimensions to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
latents_2d = tsne.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
from sklearn.decomposition import PCA

# Reduce latent dimensions to 2D using PCA
pca = PCA(n_components=2)
latents_2d = pca.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
# Function to extract latent representations and labels for AD and CN subjects
def extract_latents_and_labels(file_paths, model, device):
    latents = []
    labels = []
    
    model.eval()
    with torch.no_grad():
        for fp in file_paths:
            file_name = os.path.basename(fp)
            group = file_name.split('_')[0]
            if group not in ['AD', 'CN']:
                continue  # Skip "Others" category
            label = 1 if group == 'AD' else 0  # Assign labels: AD=1, CN=0
            data = torch.load(fp)
            if isinstance(data, np.ndarray):
                data = torch.tensor(data)
            data = normalize_tensor(data)
            x = data.unsqueeze(0).to(device, dtype=torch.float)  # Add batch dimension
            mu, logvar = model.encode(x)
            z = model.reparameterize(mu, logvar)
            latents.append(z.cpu().numpy().squeeze())
            labels.append(label)
    return np.array(latents), np.array(labels)

# %%
# Combine train and validation file paths
train_val_set = train_set + val_set

# Extract latents and labels for training (train + validation sets)
X_train, y_train = extract_latents_and_labels(train_val_set, model, device)

# Extract latents and labels for test set
X_test, y_test = extract_latents_and_labels(test_set, model, device)

# Print the shapes
print(f"Training data shape: {X_train.shape}, Training labels shape: {y_train.shape}")
print(f"Test data shape: {X_test.shape}, Test labels shape: {y_test.shape}")
# Out:
# Training data shape: (153, 30), Training labels shape: (153,)
# Test data shape: (31, 30), Test labels shape: (31,)

# %%
from collections import Counter

print(f"Training labels distribution: {Counter(y_train)}")
print(f"Test labels distribution: {Counter(y_test)}")
# Out:
# Training labels distribution: Counter({1: 80, 0: 73})
# Test labels distribution: Counter({0: 16, 1: 15})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
)

# Define classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM (Linear Kernel)": SVC(kernel='linear', probability=True),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "Neural Network": MLPClassifier(hidden_layer_sizes=(50,), max_iter=1000),
}

# Dictionary to store performance metrics
performance_metrics = {}

# Train and evaluate each classifier
for name, clf in classifiers.items():
    # Train the classifier
    clf.fit(X_train, y_train)
    # Predict on test set
    y_pred = clf.predict(X_test)
    y_proba = clf.predict_proba(X_test)[:, 1] if hasattr(clf, "predict_proba") else None
    # Compute metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
    # Store metrics
    performance_metrics[name] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "ROC AUC": roc_auc,
    }
    # Print classification report
    print(f"Classifier: {name}")
    print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
    print("-" * 50)
# Out:
# Classifier: Logistic Regression
#               precision    recall  f1-score   support
#
#           CN       0.62      0.50      0.55        16
#           AD       0.56      0.67      0.61        15
#
#     accuracy                           0.58        31
#    macro avg       0.59      0.58      0.58        31
# weighted avg       0.59      0.58      0.58        31
#
# --------------------------------------------------
# Classifier: SVM (Linear Kernel)
#               precision    recall  f1-score   support
#
#           CN       0.55      0.38      0.44        16
#           AD       0.50      0.67      0.57        15
#
#     accuracy                           0.52        31
#    macro avg       0.52      0.52      0.51        31
# weighted avg       0.52      0.52      0.51        31
#
# --------------------------------------------------
# Classifier: Random Forest
#               precision    recall  f1-score   support
#
#           CN       0.50      0.56      0.53        16
#           AD       0.46      0.40      0.43        15
#
#     accuracy                           0.48        31
#    macro avg       0.48      0.48      0.48        31
# weighted avg       0.48      0.48      0.48        31
#
# --------------------------------------------------
# Classifier: k-NN
#               precision    recall  f1-score   support
#
#           CN       0.42      0.31      0.36        16
#           AD       0.42      0.53      0.47        15
#
#     accuracy                           0.42        31
#    macro avg       0.42      0.42      0.41        31
# weighted avg       0.42      0.42      0.41        31
#
# --------------------------------------------------
# Classifier: Gradient Boosting
#               precision    recall  f1-score   support
#
#           CN       0.47      0.44      0.45        16
#           AD       0.44      0.47      0.45        15
#
#     accuracy                           0.45        31
#    macro avg       0.45      0.45      0.45        31
# weighted avg       0.45      0.45      0.45        31
#
# --------------------------------------------------
# Classifier: Neural Network
#               precision    recall  f1-score   support
#
#           CN       0.35      0.38      0.36        16
#           AD       0.29      0.27      0.28        15
#
#     accuracy                           0.32        31
#    macro avg       0.32      0.32      0.32        31
# weighted avg       0.32      0.32      0.32        31
#
# --------------------------------------------------
