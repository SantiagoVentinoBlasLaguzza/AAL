# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Set paths
project_dir = '/home/diego/Escritorio/azheimer/'  # Adjust to your path
csv_path = os.path.join(project_dir, 'DataBaseSubjects.csv')
tensor_data_dir = os.path.join(project_dir, 'TensorData')

# Load the CSV file
subjects_df = pd.read_csv(csv_path)

# Calculate the median age and print it
median_age = subjects_df['Age'].median()
print(f"Median Age: {median_age}")

# Plot the age distribution
plt.figure(figsize=(8, 6))
sns.histplot(subjects_df['Age'], bins=20, kde=True, color='blue')
plt.axvline(median_age, color='red', linestyle='--', label=f'Median Age: {median_age}')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Plot the sex distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Plot the distribution of AD, CN, and Others
plt.figure(figsize=(8, 6))
sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
plt.title('AD, CN, and Others Distribution')
plt.xlabel('Research Group')
plt.ylabel('Count')
plt.show()

# Group subjects by Research Group and Sex
grouped_data = subjects_df.groupby(['ResearchGroup', 'Sex']).size().unstack().fillna(0)
print(grouped_data)

# Initialize dictionaries for storing tensor paths by group and sex
tensor_groups = {
    'AD_men': [],
    'AD_women': [],
    'CN_men': [],
    'CN_women': [],
    'Other_men': [],
    'Other_women': []
}

# Iterate over subjects and assign tensors to groups
for subject_id in subjects_df['SubjectID']:
    group = subjects_df[subjects_df['SubjectID'] == subject_id]['ResearchGroup'].values[0]
    sex = subjects_df[subjects_df['SubjectID'] == subject_id]['Sex'].values[0]
    file_name = f'{group}_tensor_{subject_id}.pt'
    file_path = os.path.join(tensor_data_dir, file_name)
    
    if os.path.exists(file_path):
        if group == 'AD':
            if sex == 'M':
                tensor_groups['AD_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['AD_women'].append(file_path)
        elif group == 'CN':
            if sex == 'M':
                tensor_groups['CN_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['CN_women'].append(file_path)
        else:  # Others
            if sex == 'M':
                tensor_groups['Other_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['Other_women'].append(file_path)

# Print the number of subjects in each group
for key, value in tensor_groups.items():
    print(f'{key}: {len(value)} subjects')

# Split data into train, validation, and test sets with equal proportions
def split_data(tensors, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    np.random.shuffle(tensors)
    n_total = len(tensors)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    
    train_set = tensors[:n_train]
    val_set = tensors[n_train:n_train + n_val]
    test_set = tensors[n_train + n_val:]
    
    return train_set, val_set, test_set

# Initialize lists for train, validation, and test sets
train_set, val_set, test_set = [], [], []

# Combine groups ensuring equal proportions of gender and research groups
for group in tensor_groups:
    train, val, test = split_data(tensor_groups[group])
    train_set.extend(train)
    val_set.extend(val)
    test_set.extend(test)

# Print final counts of train, validation, and test sets
print(f"Train set: {len(train_set)} subjects")
print(f"Validation set: {len(val_set)} subjects")
print(f"Test set: {len(test_set)} subjects")
# Out:
# Median Age: 74.25
# /tmp/ipykernel_16542/3646991604.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
# /tmp/ipykernel_16542/3646991604.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
# Sex             F   M
# ResearchGroup
# AD             40  55
# CN             52  37
# EMCI            8  10
# LMCI           23  32
# MCI            42  53
# AD_men: 55 subjects
# AD_women: 40 subjects
# CN_men: 37 subjects
# CN_women: 52 subjects
# Other_men: 95 subjects
# Other_women: 73 subjects
# Train set: 244 subjects
# Validation set: 50 subjects
# Test set: 58 subjects

# %%
# Function to normalize each channel of the tensor between 0 and 1
def normalize_tensor(tensor):
    normalized_tensor = torch.zeros_like(tensor)
    for i in range(tensor.shape[0]):  # For each channel
        channel_data = tensor[i]
        min_val = channel_data.min()
        max_val = channel_data.max()
        # Avoid division by zero
        if max_val - min_val != 0:
            normalized_tensor[i] = (channel_data - min_val) / (max_val - min_val)
        else:
            normalized_tensor[i] = channel_data - min_val
    return normalized_tensor

# %%
# Load the tensors and create datasets
def load_tensors(file_paths):
    tensors = []
    for fp in file_paths:
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        tensors.append(data)
    return torch.stack(tensors)


# Load data for train, validation, and test sets
train_data = load_tensors(train_set)
val_data = load_tensors(val_set)
test_data = load_tensors(test_set)

# Print final dataset shapes
print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")
# Out:
# Train data shape: torch.Size([244, 3, 116, 116])
# Validation data shape: torch.Size([50, 3, 116, 116])
# Test data shape: torch.Size([58, 3, 116, 116])

# %%
import random
import matplotlib.pyplot as plt

# Function to plot the three matrices for a given subject's tensor
def plot_matrices(tensor, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    matrix_titles = ['Correlation Matrix', 'Mutual Information Matrix', 'Granger Causality Matrix']

    # Loop through the three matrices
    for i in range(3):
        ax = axes[i]
        cax = ax.matshow(tensor[i], cmap='viridis')
        fig.colorbar(cax, ax=ax)
        ax.set_title(f'{title_prefix} - {matrix_titles[i]}')
        ax.set_xlabel('ROIs')
        ax.set_ylabel('ROIs')

    plt.tight_layout()
    plt.show()

# Choose a random subject from each dataset and plot their matrices
def plot_random_subject_from_dataset(dataset, dataset_name):
    random_subject = random.choice(dataset)
    print(f"Plotting matrices for a random subject from {dataset_name} dataset: {random_subject}")
    
    # Load the tensor for the randomly selected subject
    tensor = torch.load(random_subject)
    
    # Plot the matrices
    plot_matrices(tensor, dataset_name)

# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_set, 'Train')
plot_random_subject_from_dataset(val_set, 'Validation')
plot_random_subject_from_dataset(test_set, 'Test')
# Out:
# Plotting matrices for a random subject from Train dataset: /home/diego/Escritorio/azheimer/TensorData/CN_tensor_018_S_4313.pt
# Plotting matrices for a random subject from Validation dataset: /home/diego/Escritorio/azheimer/TensorData/MCI_tensor_006_S_6651.pt
# Plotting matrices for a random subject from Test dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_135_S_6687.pt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class ConvVAE(nn.Module):
    def __init__(self, latent_dim=2):
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim
        self.dropout_rate = 0.2  # Dropout rate

        # Encoder Layers
        self.enc_conv1 = nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1)    # Output: (64, 58, 58)
        self.enc_conv2 = nn.Conv2d(64, 128, 4, 2, 1)  # Output: (128, 29, 29)
        self.enc_conv3 = nn.Conv2d(128, 256, 4, 2, 1)  # Output: (256, 14, 14)
        self.enc_conv4 = nn.Conv2d(256, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.enc_conv5 = nn.Conv2d(512, 512, 4, 2, 1)  # Output: (512, 3, 3)

        # Compute the size after convolutional layers to flatten
        self.flatten_size = 512 * 3 * 3  # Updated to 4608

        # Latent space
        self.fc_mu = nn.Linear(self.flatten_size, latent_dim)
        self.fc_logvar = nn.Linear(self.flatten_size, latent_dim)

        # Decoder Layers
        self.fc_decode = nn.Linear(latent_dim, self.flatten_size)
        self.dec_conv1 = nn.ConvTranspose2d(512, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.dec_conv2 = nn.ConvTranspose2d(512, 256, 4, 2, 1)  # Output: (256, 15, 15)
        self.dec_conv3 = nn.ConvTranspose2d(256, 128, 4, 2, 1)  # Output: (128, 31, 31)
        self.dec_conv4 = nn.ConvTranspose2d(128, 64, 4, 2, 1)   # Output: (64, 63, 63)
        self.dec_conv5 = nn.ConvTranspose2d(64, 3, 4, 2, 1)     # Output: (3, 127, 127)

        # Adjust output size to (3, 116, 116)
        self.output_padding = nn.ReflectionPad2d((-5, -6, -5, -6))  # Crop to (3, 116, 116)

        # Dropout layer
        self.dropout = nn.Dropout(self.dropout_rate)

    def encode(self, x):
        x1 = F.relu(self.enc_conv1(x))
        x2 = F.relu(self.enc_conv2(x1))
        x3 = F.relu(self.enc_conv3(x2))
        x4 = F.relu(self.enc_conv4(x3))
        x5 = F.relu(self.enc_conv5(x4))
        x5 = x5.view(x.size(0), -1)
        x5 = self.dropout(x5)
        mu = self.fc_mu(x5)
        logvar = self.fc_logvar(x5)
        return mu, logvar

    def decode(self, z):
        x = F.relu(self.fc_decode(z))
        x = x.view(z.size(0), 512, 3, 3)
        x = F.relu(self.dec_conv1(x))
        x = F.relu(self.dec_conv2(x))
        x = F.relu(self.dec_conv3(x))
        x = F.relu(self.dec_conv4(x))
        x = torch.sigmoid(self.dec_conv5(x))
        x = F.interpolate(x, size=(116, 116), mode='bilinear', align_corners=False)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar, z


    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

# %%
def loss_function(recon_x, x, mu, logvar, beta=1):
    # Reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='mean')

    # KL Divergence (normalized per batch)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    KLD = KLD / x.size(0)  # Normalize KLD per batch

    # Total loss
    total_loss = recon_loss + beta * KLD

    return total_loss, recon_loss.item(), KLD.item()

# %%
from torch.utils.data import Dataset, DataLoader

class CustomTensorDataset(Dataset):
    def __init__(self, file_paths):
        self.file_paths = file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        fp = self.file_paths[idx]
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        # Extract the label from the file name
        file_name = os.path.basename(fp)
        # Expected format: '{group}_tensor_{subject_id}.pt'
        group = file_name.split('_')[0]
        # Map group to labels
        if group in ['AD', 'CN']:
            label = group
        else:
            label = 'Others'
        return data, label

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create datasets
train_dataset = TensorDataset(train_data)
val_dataset = TensorDataset(val_data)
# Create the test dataset with labels
test_dataset = CustomTensorDataset(test_set)

# Create data loaders
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Create the data loader
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize model
latent_dim = 10  # You can adjust the size of the latent space
model = ConvVAE(latent_dim=latent_dim).to(device)

# Optimizer with L2 regularization (weight decay)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
# Out:
# Using device: cuda

# %%
# Early stopping parameters
early_stopping_patience = 25
best_val_loss = float('inf')
epochs_without_improvement = 0
model_save_path = os.path.join(project_dir, 'best_beta_vae_model.pth')

# %%
# Lists to store losses
train_total_losses = []
val_total_losses = []
train_recon_losses = []
train_kld_losses = []

num_epochs = 500  # Adjust the number of epochs as needed
beta = 100  # Set the beta value for the loss function

for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0
    train_recon_loss = 0
    train_kld_loss = 0

    for data in train_loader:
        x = data[0].to(device, dtype=torch.float)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar, _ = model(x)
        loss, recon_loss, kld_loss = loss_function(recon_batch, x, mu, logvar, beta=beta)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * x.size(0)  # Multiply by batch size
        train_recon_loss += recon_loss * x.size(0)
        train_kld_loss += kld_loss * x.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_recon_loss = train_recon_loss / len(train_loader.dataset)
    avg_train_kld_loss = train_kld_loss / len(train_loader.dataset)

    train_total_losses.append(avg_train_loss)
    train_recon_losses.append(avg_train_recon_loss)
    train_kld_losses.append(avg_train_kld_loss)
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data in val_loader:
            x = data[0].to(device, dtype=torch.float)
            recon_batch, mu, logvar, _ = model(x)
            loss, _, _ = loss_function(recon_batch, x, mu, logvar, beta=beta)
            val_loss += loss.item() * x.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_total_losses.append(avg_val_loss)
    
    print(f"Epoch {epoch}, Average Training Loss: {avg_train_loss:.6f}, Average Validation Loss: {avg_val_loss:.6f}")
    
    # Step the scheduler
    scheduler.step(avg_val_loss)
    
    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        # Save the model
        torch.save(model.state_dict(), model_save_path)
        print(f"Validation loss improved. Model saved to {model_save_path}")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= early_stopping_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1, Average Training Loss: 11.438727, Average Validation Loss: 0.045276
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 2, Average Training Loss: 0.038856, Average Validation Loss: 0.033053
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 3, Average Training Loss: 0.033003, Average Validation Loss: 0.032170
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 4, Average Training Loss: 0.032403, Average Validation Loss: 0.031986
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 5, Average Training Loss: 0.032310, Average Validation Loss: 0.031863
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 6, Average Training Loss: 0.032094, Average Validation Loss: 0.031607
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 7, Average Training Loss: 0.032004, Average Validation Loss: 0.031641
# Epoch 8, Average Training Loss: 0.031856, Average Validation Loss: 0.031515
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 9, Average Training Loss: 0.031675, Average Validation Loss: 0.031468
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 10, Average Training Loss: 0.031575, Average Validation Loss: 0.031269
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 11, Average Training Loss: 0.031494, Average Validation Loss: 0.031266
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 12, Average Training Loss: 0.031074, Average Validation Loss: 0.030675
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 13, Average Training Loss: 0.031496, Average Validation Loss: 0.023289
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 14, Average Training Loss: 0.028228, Average Validation Loss: 0.028706
# Epoch 15, Average Training Loss: 0.027629, Average Validation Loss: 0.024283
# Epoch 16, Average Training Loss: 0.021165, Average Validation Loss: 0.017780
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 17, Average Training Loss: 0.017749, Average Validation Loss: 0.016686
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 18, Average Training Loss: 0.016692, Average Validation Loss: 0.016008
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 19, Average Training Loss: 0.016200, Average Validation Loss: 0.015947
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 20, Average Training Loss: 0.015943, Average Validation Loss: 0.015250
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 21, Average Training Loss: 0.015299, Average Validation Loss: 0.015422
# Epoch 22, Average Training Loss: 0.015121, Average Validation Loss: 0.014598
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 23, Average Training Loss: 0.014268, Average Validation Loss: 0.013608
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 24, Average Training Loss: 0.013618, Average Validation Loss: 0.013220
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 25, Average Training Loss: 0.013241, Average Validation Loss: 0.012969
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 26, Average Training Loss: 0.013086, Average Validation Loss: 0.013028
# Epoch 27, Average Training Loss: 0.013000, Average Validation Loss: 0.012730
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 28, Average Training Loss: 0.012814, Average Validation Loss: 0.012581
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 29, Average Training Loss: 0.012665, Average Validation Loss: 0.013095
# Epoch 30, Average Training Loss: 0.012847, Average Validation Loss: 0.012650
# Epoch 31, Average Training Loss: 0.012500, Average Validation Loss: 0.012288
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 32, Average Training Loss: 0.012355, Average Validation Loss: 0.012147
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 33, Average Training Loss: 0.012420, Average Validation Loss: 0.012017
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 34, Average Training Loss: 0.012140, Average Validation Loss: 0.011856
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 35, Average Training Loss: 0.012046, Average Validation Loss: 0.011746
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 36, Average Training Loss: 0.011939, Average Validation Loss: 0.011767
# Epoch 37, Average Training Loss: 0.011965, Average Validation Loss: 0.011784
# Epoch 38, Average Training Loss: 0.011896, Average Validation Loss: 0.011857
# Epoch 39, Average Training Loss: 0.011866, Average Validation Loss: 0.011741
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 40, Average Training Loss: 0.011863, Average Validation Loss: 0.011637
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 41, Average Training Loss: 0.011822, Average Validation Loss: 0.011656
# Epoch 42, Average Training Loss: 0.011925, Average Validation Loss: 0.012031
# Epoch 43, Average Training Loss: 0.011959, Average Validation Loss: 0.011673
# Epoch 44, Average Training Loss: 0.011711, Average Validation Loss: 0.011640
# Epoch 45, Average Training Loss: 0.011625, Average Validation Loss: 0.011443
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 46, Average Training Loss: 0.011533, Average Validation Loss: 0.011816
# Epoch 47, Average Training Loss: 0.011691, Average Validation Loss: 0.011435
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 48, Average Training Loss: 0.011562, Average Validation Loss: 0.011400
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 49, Average Training Loss: 0.011555, Average Validation Loss: 0.011426
# Epoch 50, Average Training Loss: 0.011621, Average Validation Loss: 0.011607
# Epoch 51, Average Training Loss: 0.011642, Average Validation Loss: 0.011595
# Epoch 52, Average Training Loss: 0.011877, Average Validation Loss: 0.011417
# Epoch 53, Average Training Loss: 0.011648, Average Validation Loss: 0.011568
# Epoch 54, Average Training Loss: 0.011595, Average Validation Loss: 0.011452
# Epoch 00054: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 55, Average Training Loss: 0.011427, Average Validation Loss: 0.011312
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 56, Average Training Loss: 0.011408, Average Validation Loss: 0.011252
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 57, Average Training Loss: 0.011351, Average Validation Loss: 0.011279
# Epoch 58, Average Training Loss: 0.011386, Average Validation Loss: 0.011399
# Epoch 59, Average Training Loss: 0.011374, Average Validation Loss: 0.011263
# Epoch 60, Average Training Loss: 0.011390, Average Validation Loss: 0.011259
# Epoch 61, Average Training Loss: 0.011390, Average Validation Loss: 0.011328
# Epoch 62, Average Training Loss: 0.011402, Average Validation Loss: 0.011371
# Epoch 00062: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 63, Average Training Loss: 0.011368, Average Validation Loss: 0.011210
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 64, Average Training Loss: 0.011296, Average Validation Loss: 0.011202
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 65, Average Training Loss: 0.011284, Average Validation Loss: 0.011229
# Epoch 66, Average Training Loss: 0.011279, Average Validation Loss: 0.011211
# Epoch 67, Average Training Loss: 0.011273, Average Validation Loss: 0.011196
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 68, Average Training Loss: 0.011274, Average Validation Loss: 0.011179
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 69, Average Training Loss: 0.011279, Average Validation Loss: 0.011199
# Epoch 70, Average Training Loss: 0.011266, Average Validation Loss: 0.011192
# Epoch 71, Average Training Loss: 0.011279, Average Validation Loss: 0.011224
# Epoch 72, Average Training Loss: 0.011308, Average Validation Loss: 0.011198
# Epoch 73, Average Training Loss: 0.011309, Average Validation Loss: 0.011163
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 74, Average Training Loss: 0.011265, Average Validation Loss: 0.011191
# Epoch 75, Average Training Loss: 0.011264, Average Validation Loss: 0.011168
# Epoch 76, Average Training Loss: 0.011242, Average Validation Loss: 0.011222
# Epoch 77, Average Training Loss: 0.011254, Average Validation Loss: 0.011157
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 78, Average Training Loss: 0.011253, Average Validation Loss: 0.011181
# Epoch 79, Average Training Loss: 0.011238, Average Validation Loss: 0.011165
# Epoch 80, Average Training Loss: 0.011265, Average Validation Loss: 0.011189
# Epoch 81, Average Training Loss: 0.011228, Average Validation Loss: 0.011155
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 82, Average Training Loss: 0.011219, Average Validation Loss: 0.011183
# Epoch 83, Average Training Loss: 0.011229, Average Validation Loss: 0.011147
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 84, Average Training Loss: 0.011240, Average Validation Loss: 0.011155
# Epoch 85, Average Training Loss: 0.011252, Average Validation Loss: 0.011181
# Epoch 86, Average Training Loss: 0.011275, Average Validation Loss: 0.011152
# Epoch 87, Average Training Loss: 0.011232, Average Validation Loss: 0.011152
# Epoch 88, Average Training Loss: 0.011236, Average Validation Loss: 0.011161
# Epoch 89, Average Training Loss: 0.011238, Average Validation Loss: 0.011153
# Epoch 00089: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 90, Average Training Loss: 0.011219, Average Validation Loss: 0.011146
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 91, Average Training Loss: 0.011187, Average Validation Loss: 0.011147
# Epoch 92, Average Training Loss: 0.011187, Average Validation Loss: 0.011131
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 93, Average Training Loss: 0.011209, Average Validation Loss: 0.011132
# Epoch 94, Average Training Loss: 0.011215, Average Validation Loss: 0.011146
# Epoch 95, Average Training Loss: 0.011202, Average Validation Loss: 0.011154
# Epoch 96, Average Training Loss: 0.011190, Average Validation Loss: 0.011123
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 97, Average Training Loss: 0.011180, Average Validation Loss: 0.011158
# Epoch 98, Average Training Loss: 0.011173, Average Validation Loss: 0.011144
# Epoch 99, Average Training Loss: 0.011195, Average Validation Loss: 0.011137
# Epoch 100, Average Training Loss: 0.011174, Average Validation Loss: 0.011117
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 101, Average Training Loss: 0.011178, Average Validation Loss: 0.011120
# Epoch 102, Average Training Loss: 0.011182, Average Validation Loss: 0.011136
# Epoch 103, Average Training Loss: 0.011204, Average Validation Loss: 0.011125
# Epoch 104, Average Training Loss: 0.011175, Average Validation Loss: 0.011130
# Epoch 105, Average Training Loss: 0.011175, Average Validation Loss: 0.011146
# Epoch 106, Average Training Loss: 0.011185, Average Validation Loss: 0.011127
# Epoch 00106: reducing learning rate of group 0 to 6.2500e-05.
# Epoch 107, Average Training Loss: 0.011183, Average Validation Loss: 0.011120
# Epoch 108, Average Training Loss: 0.011168, Average Validation Loss: 0.011112
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 109, Average Training Loss: 0.011147, Average Validation Loss: 0.011119
# Epoch 110, Average Training Loss: 0.011159, Average Validation Loss: 0.011111
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 111, Average Training Loss: 0.011150, Average Validation Loss: 0.011108
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 112, Average Training Loss: 0.011175, Average Validation Loss: 0.011113
# Epoch 113, Average Training Loss: 0.011160, Average Validation Loss: 0.011108
# Epoch 114, Average Training Loss: 0.011167, Average Validation Loss: 0.011125
# Epoch 115, Average Training Loss: 0.011157, Average Validation Loss: 0.011106
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 116, Average Training Loss: 0.011152, Average Validation Loss: 0.011101
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 117, Average Training Loss: 0.011145, Average Validation Loss: 0.011116
# Epoch 118, Average Training Loss: 0.011170, Average Validation Loss: 0.011096
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 119, Average Training Loss: 0.011165, Average Validation Loss: 0.011110
# Epoch 120, Average Training Loss: 0.011162, Average Validation Loss: 0.011108
# Epoch 121, Average Training Loss: 0.011161, Average Validation Loss: 0.011108
# Epoch 122, Average Training Loss: 0.011158, Average Validation Loss: 0.011108
# Epoch 123, Average Training Loss: 0.011152, Average Validation Loss: 0.011115
# Epoch 124, Average Training Loss: 0.011153, Average Validation Loss: 0.011109
# Epoch 00124: reducing learning rate of group 0 to 3.1250e-05.
# Epoch 125, Average Training Loss: 0.011156, Average Validation Loss: 0.011109
# Epoch 126, Average Training Loss: 0.011141, Average Validation Loss: 0.011105
# Epoch 127, Average Training Loss: 0.011151, Average Validation Loss: 0.011103
# Epoch 128, Average Training Loss: 0.011160, Average Validation Loss: 0.011101
# Epoch 129, Average Training Loss: 0.011145, Average Validation Loss: 0.011098
# Epoch 130, Average Training Loss: 0.011144, Average Validation Loss: 0.011093
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 131, Average Training Loss: 0.011140, Average Validation Loss: 0.011102
# Epoch 132, Average Training Loss: 0.011150, Average Validation Loss: 0.011104
# Epoch 133, Average Training Loss: 0.011137, Average Validation Loss: 0.011106
# Epoch 134, Average Training Loss: 0.011139, Average Validation Loss: 0.011106
# Epoch 135, Average Training Loss: 0.011147, Average Validation Loss: 0.011106
# Epoch 136, Average Training Loss: 0.011145, Average Validation Loss: 0.011106
# Epoch 00136: reducing learning rate of group 0 to 1.5625e-05.
# Epoch 137, Average Training Loss: 0.011147, Average Validation Loss: 0.011094
# Epoch 138, Average Training Loss: 0.011136, Average Validation Loss: 0.011098
# Epoch 139, Average Training Loss: 0.011140, Average Validation Loss: 0.011098
# Epoch 140, Average Training Loss: 0.011138, Average Validation Loss: 0.011101
# Epoch 141, Average Training Loss: 0.011131, Average Validation Loss: 0.011094
# Epoch 142, Average Training Loss: 0.011135, Average Validation Loss: 0.011090
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 143, Average Training Loss: 0.011130, Average Validation Loss: 0.011101
# Epoch 144, Average Training Loss: 0.011135, Average Validation Loss: 0.011096
# Epoch 145, Average Training Loss: 0.011143, Average Validation Loss: 0.011102
# Epoch 146, Average Training Loss: 0.011139, Average Validation Loss: 0.011091
# Epoch 147, Average Training Loss: 0.011130, Average Validation Loss: 0.011095
# Epoch 148, Average Training Loss: 0.011139, Average Validation Loss: 0.011101
# Epoch 00148: reducing learning rate of group 0 to 7.8125e-06.
# Epoch 149, Average Training Loss: 0.011136, Average Validation Loss: 0.011091
# Epoch 150, Average Training Loss: 0.011133, Average Validation Loss: 0.011101
# Epoch 151, Average Training Loss: 0.011135, Average Validation Loss: 0.011096
# Epoch 152, Average Training Loss: 0.011138, Average Validation Loss: 0.011105
# Epoch 153, Average Training Loss: 0.011134, Average Validation Loss: 0.011098
# Epoch 154, Average Training Loss: 0.011132, Average Validation Loss: 0.011089
# Epoch 00154: reducing learning rate of group 0 to 3.9063e-06.
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 155, Average Training Loss: 0.011142, Average Validation Loss: 0.011096
# Epoch 156, Average Training Loss: 0.011136, Average Validation Loss: 0.011100
# Epoch 157, Average Training Loss: 0.011134, Average Validation Loss: 0.011098
# Epoch 158, Average Training Loss: 0.011132, Average Validation Loss: 0.011099
# Epoch 159, Average Training Loss: 0.011124, Average Validation Loss: 0.011096
# Epoch 160, Average Training Loss: 0.011127, Average Validation Loss: 0.011093
# Epoch 00160: reducing learning rate of group 0 to 1.9531e-06.
# Epoch 161, Average Training Loss: 0.011132, Average Validation Loss: 0.011086
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Epoch 162, Average Training Loss: 0.011139, Average Validation Loss: 0.011091
# Epoch 163, Average Training Loss: 0.011142, Average Validation Loss: 0.011099
# Epoch 164, Average Training Loss: 0.011145, Average Validation Loss: 0.011098
# Epoch 165, Average Training Loss: 0.011132, Average Validation Loss: 0.011094
# Epoch 166, Average Training Loss: 0.011127, Average Validation Loss: 0.011097
# Epoch 167, Average Training Loss: 0.011142, Average Validation Loss: 0.011090
# Epoch 00167: reducing learning rate of group 0 to 9.7656e-07.
# Epoch 168, Average Training Loss: 0.011136, Average Validation Loss: 0.011091
# Epoch 169, Average Training Loss: 0.011137, Average Validation Loss: 0.011093
# Epoch 170, Average Training Loss: 0.011133, Average Validation Loss: 0.011088
# Epoch 171, Average Training Loss: 0.011139, Average Validation Loss: 0.011094
# Epoch 172, Average Training Loss: 0.011136, Average Validation Loss: 0.011096
# Epoch 173, Average Training Loss: 0.011140, Average Validation Loss: 0.011096
# Epoch 00173: reducing learning rate of group 0 to 4.8828e-07.
# Epoch 174, Average Training Loss: 0.011132, Average Validation Loss: 0.011088
# Epoch 175, Average Training Loss: 0.011135, Average Validation Loss: 0.011090
# Epoch 176, Average Training Loss: 0.011135, Average Validation Loss: 0.011096
# Epoch 177, Average Training Loss: 0.011123, Average Validation Loss: 0.011097
# Epoch 178, Average Training Loss: 0.011138, Average Validation Loss: 0.011094
# Epoch 179, Average Training Loss: 0.011131, Average Validation Loss: 0.011097
# Epoch 00179: reducing learning rate of group 0 to 2.4414e-07.
# Epoch 180, Average Training Loss: 0.011131, Average Validation Loss: 0.011090
# Epoch 181, Average Training Loss: 0.011146, Average Validation Loss: 0.011096
# Epoch 182, Average Training Loss: 0.011134, Average Validation Loss: 0.011096
# Epoch 183, Average Training Loss: 0.011139, Average Validation Loss: 0.011091
# Epoch 184, Average Training Loss: 0.011138, Average Validation Loss: 0.011090
# Epoch 185, Average Training Loss: 0.011143, Average Validation Loss: 0.011088
# Epoch 00185: reducing learning rate of group 0 to 1.2207e-07.
# Epoch 186, Average Training Loss: 0.011136, Average Validation Loss: 0.011099
# Early stopping triggered.

# %%
# Plot training and validation loss over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_total_losses) + 1), train_total_losses, label='Training Loss')
plt.plot(range(1, len(val_total_losses) + 1), val_total_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
# Plot reconstruction loss and KL divergence over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Reconstruction Loss')
plt.plot(range(1, len(train_kld_losses) + 1), train_kld_losses, label='KL Divergence')
plt.plot(range(1, len(train_total_losses) + 1), beta * np.array(train_kld_losses), label='Beta * KL Divergence')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Reconstruction Loss and KL Divergence over Epochs')
plt.legend()
plt.show()

# %%
model.eval()
test_loss = 0
with torch.no_grad():
    for data in test_loader:
        x = data[0].to(device, dtype=torch.float)
        recon_batch, mu, logvar, z = model(x)
        loss , _ , _ = loss_function(recon_batch, x, mu, logvar)
        test_loss += loss.item()
avg_test_loss = test_loss / len(test_loader.dataset)
print(f"Average Test Loss: {avg_test_loss:.4f}")
# Out:
# Average Test Loss: 0.0004

# %%
import matplotlib.pyplot as plt

# Function to display original and reconstructed images
def visualize_reconstruction(model, data_loader):
    model.eval()
    with torch.no_grad():
        data = next(iter(data_loader))
        x = data[0].to(device, dtype=torch.float)
        recon_x, _, _ , _ = model(x)
        
        # Move tensors to CPU and convert to numpy
        x = x.cpu().numpy()
        recon_x = recon_x.cpu().numpy()
        
        n = min(x.shape[0], 5)  # Number of samples to display
        for i in range(n):
            fig, axes = plt.subplots(2, 3, figsize=(12, 6))
            for j in range(3):
                axes[0, j].imshow(x[i, j], cmap='viridis')
                axes[0, j].set_title(f'Original - Matrix {j+1}')
                axes[0, j].axis('off')
                axes[1, j].imshow(recon_x[i, j], cmap='viridis')
                axes[1, j].set_title(f'Reconstructed - Matrix {j+1}')
                axes[1, j].axis('off')
            plt.show()

# Visualize reconstructions on test data
visualize_reconstruction(model, test_loader)

# %%
# Save the trained model
model_save_path = os.path.join(project_dir, 'conv_vae_model.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /home/diego/Escritorio/azheimer/conv_vae_model.pth

# %%
# Load the model
model = ConvVAE(latent_dim=latent_dim).to(device)
model.load_state_dict(torch.load(model_save_path))
model.eval()
# Out:
# ConvVAE(
#   (enc_conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv5): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (fc_mu): Linear(in_features=4608, out_features=10, bias=True)
#   (fc_logvar): Linear(in_features=4608, out_features=10, bias=True)
#   (fc_decode): Linear(in_features=10, out_features=4608, bias=True)
#   (dec_conv1): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (output_padding): ReflectionPad2d((-5, -6, -5, -6))
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model.eval()
latents = []
labels = []

with torch.no_grad():
    for data, label in test_loader:
        x = data.to(device, dtype=torch.float)
        mu, logvar = model.encode(x)
        z = model.reparameterize(mu, logvar)
        latents.append(z.cpu())
        labels.extend(label)  # Collect labels

# Concatenate all latent vectors and convert labels to a NumPy array
latents = torch.cat(latents, dim=0).numpy()
labels = np.array(labels)

# %%
from sklearn.manifold import TSNE

# Reduce latent dimensions to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
latents_2d = tsne.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
from sklearn.decomposition import PCA

# Reduce latent dimensions to 2D using PCA
pca = PCA(n_components=2)
latents_2d = pca.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()
