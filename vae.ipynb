# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Set paths
project_dir = '/home/diego/Escritorio/azheimer/'  # Adjust to your path
csv_path = os.path.join(project_dir, 'DataBaseSubjects.csv')
tensor_data_dir = os.path.join(project_dir, 'TensorData')

# Load the CSV file
subjects_df = pd.read_csv(csv_path)

# Calculate the median age and print it
median_age = subjects_df['Age'].median()
print(f"Median Age: {median_age}")

# Plot the age distribution
plt.figure(figsize=(8, 6))
sns.histplot(subjects_df['Age'], bins=20, kde=True, color='blue')
plt.axvline(median_age, color='red', linestyle='--', label=f'Median Age: {median_age}')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Plot the sex distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Plot the distribution of AD, CN, and Others
plt.figure(figsize=(8, 6))
sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
plt.title('AD, CN, and Others Distribution')
plt.xlabel('Research Group')
plt.ylabel('Count')
plt.show()

# Group subjects by Research Group and Sex
grouped_data = subjects_df.groupby(['ResearchGroup', 'Sex']).size().unstack().fillna(0)
print(grouped_data)

# Initialize dictionaries for storing tensor paths by group and sex
tensor_groups = {
    'AD_men': [],
    'AD_women': [],
    'CN_men': [],
    'CN_women': [],
    'Other_men': [],
    'Other_women': []
}

# Iterate over subjects and assign tensors to groups
for subject_id in subjects_df['SubjectID']:
    group = subjects_df[subjects_df['SubjectID'] == subject_id]['ResearchGroup'].values[0]
    sex = subjects_df[subjects_df['SubjectID'] == subject_id]['Sex'].values[0]
    file_name = f'{group}_tensor_{subject_id}.pt'
    file_path = os.path.join(tensor_data_dir, file_name)
    
    if os.path.exists(file_path):
        if group == 'AD':
            if sex == 'M':
                tensor_groups['AD_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['AD_women'].append(file_path)
        elif group == 'CN':
            if sex == 'M':
                tensor_groups['CN_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['CN_women'].append(file_path)
        else:  # Others
            if sex == 'M':
                tensor_groups['Other_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['Other_women'].append(file_path)

# Print the number of subjects in each group
for key, value in tensor_groups.items():
    print(f'{key}: {len(value)} subjects')

# Split data into train, validation, and test sets with equal proportions
def split_data(tensors, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    np.random.shuffle(tensors)
    n_total = len(tensors)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    
    train_set = tensors[:n_train]
    val_set = tensors[n_train:n_train + n_val]
    test_set = tensors[n_train + n_val:]
    
    return train_set, val_set, test_set

# Initialize lists for train, validation, and test sets
train_set, val_set, test_set = [], [], []

# Combine groups ensuring equal proportions of gender and research groups
for group in tensor_groups:
    train, val, test = split_data(tensor_groups[group])
    train_set.extend(train)
    val_set.extend(val)
    test_set.extend(test)

# Print final counts of train, validation, and test sets
print(f"Train set: {len(train_set)} subjects")
print(f"Validation set: {len(val_set)} subjects")
print(f"Test set: {len(test_set)} subjects")
# Out:
# Median Age: 74.25
# /tmp/ipykernel_583573/3646991604.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
# /tmp/ipykernel_583573/3646991604.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
# Sex             F   M
# ResearchGroup
# AD             40  55
# CN             52  37
# EMCI            8  10
# LMCI           23  32
# MCI            42  53
# AD_men: 55 subjects
# AD_women: 40 subjects
# CN_men: 37 subjects
# CN_women: 52 subjects
# Other_men: 95 subjects
# Other_women: 73 subjects
# Train set: 244 subjects
# Validation set: 50 subjects
# Test set: 58 subjects

# %%
# Load the tensors and create datasets
def load_tensors(file_paths):
    tensors = []
    for fp in file_paths:
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        tensors.append(data)
        # Print the dimensions of the loaded tensor
        #print(f"Loaded tensor from {fp}, shape: {data.shape}")
    return torch.stack(tensors)

# Load data for train, validation, and test sets
train_data = load_tensors(train_set)
val_data = load_tensors(val_set)
test_data = load_tensors(test_set)

# Print final dataset shapes
print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")
# Out:
# Train data shape: torch.Size([244, 3, 116, 116])
# Validation data shape: torch.Size([50, 3, 116, 116])
# Test data shape: torch.Size([58, 3, 116, 116])

# %%
import random
import matplotlib.pyplot as plt

# Function to plot the three matrices for a given subject's tensor
def plot_matrices(tensor, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    matrix_titles = ['Correlation Matrix', 'Mutual Information Matrix', 'Granger Causality Matrix']

    # Loop through the three matrices
    for i in range(3):
        ax = axes[i]
        cax = ax.matshow(tensor[i], cmap='viridis')
        fig.colorbar(cax, ax=ax)
        ax.set_title(f'{title_prefix} - {matrix_titles[i]}')
        ax.set_xlabel('ROIs')
        ax.set_ylabel('ROIs')

    plt.tight_layout()
    plt.show()

# Choose a random subject from each dataset and plot their matrices
def plot_random_subject_from_dataset(dataset, dataset_name):
    random_subject = random.choice(dataset)
    print(f"Plotting matrices for a random subject from {dataset_name} dataset: {random_subject}")
    
    # Load the tensor for the randomly selected subject
    tensor = torch.load(random_subject)
    
    # Plot the matrices
    plot_matrices(tensor, dataset_name)

# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_set, 'Train')
plot_random_subject_from_dataset(val_set, 'Validation')
plot_random_subject_from_dataset(test_set, 'Test')
# Out:
# Plotting matrices for a random subject from Train dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_053_S_5070.pt
# Plotting matrices for a random subject from Validation dataset: /home/diego/Escritorio/azheimer/TensorData/MCI_tensor_037_S_0377.pt
# Plotting matrices for a random subject from Test dataset: /home/diego/Escritorio/azheimer/TensorData/MCI_tensor_003_S_6606.pt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class ConvVAE(nn.Module):
    def __init__(self, latent_dim=20):
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim
        
        # Encoder Layers
        self.enc_conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=4, stride=2, padding=1)  # Output: (32, 58, 58)
        self.enc_conv2 = nn.Conv2d(32, 64, 4, 2, 1)  # Output: (64, 29, 29)
        self.enc_conv3 = nn.Conv2d(64, 128, 4, 2, 1)  # Output: (128, 14, 14)
        self.enc_conv4 = nn.Conv2d(128, 256, 4, 2, 1)  # Output: (256, 7, 7)
        
        # Compute the size after convolutional layers to flatten
        self.flatten_size = 256 * 7 * 7
        
        # Latent space
        self.fc_mu = nn.Linear(self.flatten_size, latent_dim)
        self.fc_logvar = nn.Linear(self.flatten_size, latent_dim)
        
        # Decoder Layers
        self.fc_decode = nn.Linear(latent_dim, self.flatten_size)
        self.dec_conv1 = nn.ConvTranspose2d(256, 128, 4, 2, 1)  # Output: (128, 14, 14)
        self.dec_conv2 = nn.ConvTranspose2d(128, 64, 4, 2, 1)   # Output: (64, 28, 28)
        self.dec_conv3 = nn.ConvTranspose2d(64, 32, 4, 2, 1)    # Output: (32, 56, 56)
        self.dec_conv4 = nn.ConvTranspose2d(32, 3, 4, 2, 1)     # Output: (3, 112, 112)
        
        # Since the input size is (3, 116, 116), adjust output size accordingly
        self.output_padding = nn.ConstantPad2d((2, 2, 2, 2), 0)  # Pad to (3, 116, 116)

    def encode(self, x):
        x = F.relu(self.enc_conv1(x))
        x = F.relu(self.enc_conv2(x))
        x = F.relu(self.enc_conv3(x))
        x = F.relu(self.enc_conv4(x))
        x = x.view(-1, self.flatten_size)
        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        x = F.relu(self.fc_decode(z))
        x = x.view(-1, 256, 7, 7)
        x = F.relu(self.dec_conv1(x))
        x = F.relu(self.dec_conv2(x))
        x = F.relu(self.dec_conv3(x))
        x = torch.sigmoid(self.dec_conv4(x))  # Use sigmoid for output activation
        x = self.output_padding(x)  # Adjust output size to (3, 116, 116)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar

# %%
def loss_function(recon_x, x, mu, logvar):
    # Reconstruction loss (Binary Cross Entropy)
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    
    # KL Divergence
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + KLD

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create datasets
train_dataset = TensorDataset(train_data)
val_dataset = TensorDataset(val_data)
test_dataset = TensorDataset(test_data)

# Create data loaders
batch_size = 16

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize model
latent_dim = 20  # You can adjust the size of the latent space
model = ConvVAE(latent_dim=latent_dim).to(device)

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
# Out:
# Using device: cuda

# %%
num_epochs = 250  # Adjust the number of epochs as needed

for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0
    for data in train_loader:
        x = data[0].to(device, dtype=torch.float)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(x)
        loss = loss_function(recon_batch, x, mu, logvar)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    print(f"Epoch {epoch}, Average Training Loss: {avg_train_loss:.4f}")
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data in val_loader:
            x = data[0].to(device, dtype=torch.float)
            recon_batch, mu, logvar = model(x)
            loss = loss_function(recon_batch, x, mu, logvar)
            val_loss += loss.item()
    avg_val_loss = val_loss / len(val_loader.dataset)
    print(f"Epoch {epoch}, Average Validation Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1, Average Training Loss: 319009.9395
# Epoch 1, Average Validation Loss: 243109.0269
# Epoch 2, Average Training Loss: 318925.6035
# Epoch 2, Average Validation Loss: 243016.8800
# Epoch 3, Average Training Loss: 318763.9431
# Epoch 3, Average Validation Loss: 242807.4916
# Epoch 4, Average Training Loss: 318230.6711
# Epoch 4, Average Validation Loss: 241912.1994
# Epoch 5, Average Training Loss: 315793.6942
# Epoch 5, Average Validation Loss: 238610.9081
# Epoch 6, Average Training Loss: 311822.4185
# Epoch 6, Average Validation Loss: 234975.3628
# Epoch 7, Average Training Loss: 307226.6117
# Epoch 7, Average Validation Loss: 231712.8859
# Epoch 8, Average Training Loss: 302904.9470
# Epoch 8, Average Validation Loss: 227653.9791
# Epoch 9, Average Training Loss: 299279.7433
# Epoch 9, Average Validation Loss: 224822.7678
# Epoch 10, Average Training Loss: 296379.0768
# Epoch 10, Average Validation Loss: 222663.5522
# Epoch 11, Average Training Loss: 294339.0318
# Epoch 11, Average Validation Loss: 221235.1353
# Epoch 12, Average Training Loss: 293042.9032
# Epoch 12, Average Validation Loss: 220320.3531
# Epoch 13, Average Training Loss: 292202.9142
# Epoch 13, Average Validation Loss: 219645.2725
# Epoch 14, Average Training Loss: 291520.5548
# Epoch 14, Average Validation Loss: 219121.0653
# Epoch 15, Average Training Loss: 290968.2549
# Epoch 15, Average Validation Loss: 218650.3188
# Epoch 16, Average Training Loss: 290450.7923
# Epoch 16, Average Validation Loss: 218225.4987
# Epoch 17, Average Training Loss: 290008.5359
# Epoch 17, Average Validation Loss: 217887.2700
# Epoch 18, Average Training Loss: 289687.5195
# Epoch 18, Average Validation Loss: 217633.3116
# Epoch 19, Average Training Loss: 289409.8248
# Epoch 19, Average Validation Loss: 217392.7800
# Epoch 20, Average Training Loss: 289184.0466
# Epoch 20, Average Validation Loss: 217228.3163
# Epoch 21, Average Training Loss: 288992.1580
# Epoch 21, Average Validation Loss: 217052.2922
# Epoch 22, Average Training Loss: 288798.1104
# Epoch 22, Average Validation Loss: 216863.7800
# Epoch 23, Average Training Loss: 288639.4693
# Epoch 23, Average Validation Loss: 216804.0003
# Epoch 24, Average Training Loss: 288506.5248
# Epoch 24, Average Validation Loss: 216622.2781
# Epoch 25, Average Training Loss: 288365.7874
# Epoch 25, Average Validation Loss: 216546.2216
# Epoch 26, Average Training Loss: 288272.6872
# Epoch 26, Average Validation Loss: 216433.3706
# Epoch 27, Average Training Loss: 288178.1460
# Epoch 27, Average Validation Loss: 216343.6291
# Epoch 28, Average Training Loss: 288089.9265
# Epoch 28, Average Validation Loss: 216292.8966
# Epoch 29, Average Training Loss: 288002.5220
# Epoch 29, Average Validation Loss: 216201.1228
# Epoch 30, Average Training Loss: 287932.3414
# Epoch 30, Average Validation Loss: 216155.8816
# Epoch 31, Average Training Loss: 287871.4124
# Epoch 31, Average Validation Loss: 216095.3062
# Epoch 32, Average Training Loss: 287801.0143
# Epoch 32, Average Validation Loss: 216058.1634
# Epoch 33, Average Training Loss: 287741.4645
# Epoch 33, Average Validation Loss: 216000.3969
# Epoch 34, Average Training Loss: 287676.3384
# Epoch 34, Average Validation Loss: 215939.2709
# Epoch 35, Average Training Loss: 287622.5953
# Epoch 35, Average Validation Loss: 215881.0809
# Epoch 36, Average Training Loss: 287567.0154
# Epoch 36, Average Validation Loss: 215849.1703
# Epoch 37, Average Training Loss: 287519.7992
# Epoch 37, Average Validation Loss: 215790.2162
# Epoch 38, Average Training Loss: 287472.0015
# Epoch 38, Average Validation Loss: 215764.8266
# Epoch 39, Average Training Loss: 287428.7018
# Epoch 39, Average Validation Loss: 215711.1200
# Epoch 40, Average Training Loss: 287394.2953
# Epoch 40, Average Validation Loss: 215682.9625
# Epoch 41, Average Training Loss: 287350.1931
# Epoch 41, Average Validation Loss: 215653.6519
# Epoch 42, Average Training Loss: 287311.3940
# Epoch 42, Average Validation Loss: 215614.8697
# Epoch 43, Average Training Loss: 287274.1025
# Epoch 43, Average Validation Loss: 215579.4691
# Epoch 44, Average Training Loss: 287236.9800
# Epoch 44, Average Validation Loss: 215541.1441
# Epoch 45, Average Training Loss: 287208.5154
# Epoch 45, Average Validation Loss: 215515.8475
# Epoch 46, Average Training Loss: 287169.0046
# Epoch 46, Average Validation Loss: 215475.2156
# Epoch 47, Average Training Loss: 287138.2556
# Epoch 47, Average Validation Loss: 215454.4856
# Epoch 48, Average Training Loss: 287111.7605
# Epoch 48, Average Validation Loss: 215447.4309
# Epoch 49, Average Training Loss: 287075.0064
# Epoch 49, Average Validation Loss: 215408.9703
# Epoch 50, Average Training Loss: 287056.5169
# Epoch 50, Average Validation Loss: 215377.4856
# Epoch 51, Average Training Loss: 287026.6055
# Epoch 51, Average Validation Loss: 215366.3769
# Epoch 52, Average Training Loss: 286998.2851
# Epoch 52, Average Validation Loss: 215338.4113
# Epoch 53, Average Training Loss: 286973.7177
# Epoch 53, Average Validation Loss: 215319.1769
# Epoch 54, Average Training Loss: 286950.7999
# Epoch 54, Average Validation Loss: 215290.6019
# Epoch 55, Average Training Loss: 286926.8074
# Epoch 55, Average Validation Loss: 215266.9697
# Epoch 56, Average Training Loss: 286908.7480
# Epoch 56, Average Validation Loss: 215253.1772
# Epoch 57, Average Training Loss: 286879.4293
# Epoch 57, Average Validation Loss: 215235.3778
# Epoch 58, Average Training Loss: 286863.0553
# Epoch 58, Average Validation Loss: 215206.9463
# Epoch 59, Average Training Loss: 286842.6475
# Epoch 59, Average Validation Loss: 215196.0728
# Epoch 60, Average Training Loss: 286821.1924
# Epoch 60, Average Validation Loss: 215173.6669
# Epoch 61, Average Training Loss: 286806.8740
# Epoch 61, Average Validation Loss: 215163.7959
# Epoch 62, Average Training Loss: 286792.0666
# Epoch 62, Average Validation Loss: 215148.4025
# Epoch 63, Average Training Loss: 286769.3453
# Epoch 63, Average Validation Loss: 215127.9506
# Epoch 64, Average Training Loss: 286746.9823
# Epoch 64, Average Validation Loss: 215116.5641
# Epoch 65, Average Training Loss: 286734.6247
# Epoch 65, Average Validation Loss: 215102.1922
# Epoch 66, Average Training Loss: 286718.3238
# Epoch 66, Average Validation Loss: 215076.6225
# Epoch 67, Average Training Loss: 286699.9700
# Epoch 67, Average Validation Loss: 215076.8891
# Epoch 68, Average Training Loss: 286684.2961
# Epoch 68, Average Validation Loss: 215068.3884
# Epoch 69, Average Training Loss: 286671.4769
# Epoch 69, Average Validation Loss: 215048.0787
# Epoch 70, Average Training Loss: 286661.1765
# Epoch 70, Average Validation Loss: 215037.6228
# Epoch 71, Average Training Loss: 286646.2264
# Epoch 71, Average Validation Loss: 215032.8163
# Epoch 72, Average Training Loss: 286632.1936
# Epoch 72, Average Validation Loss: 215012.5328
# Epoch 73, Average Training Loss: 286615.5387
# Epoch 73, Average Validation Loss: 214991.2609
# Epoch 74, Average Training Loss: 286605.0261
# Epoch 74, Average Validation Loss: 214987.8897
# Epoch 75, Average Training Loss: 286585.4862
# Epoch 75, Average Validation Loss: 214967.4250
# Epoch 76, Average Training Loss: 286577.8363
# Epoch 76, Average Validation Loss: 214952.6016
# Epoch 77, Average Training Loss: 286568.3817
# Epoch 77, Average Validation Loss: 214958.8500
# Epoch 78, Average Training Loss: 286546.3535
# Epoch 78, Average Validation Loss: 214940.8931
# Epoch 79, Average Training Loss: 286540.2249
# Epoch 79, Average Validation Loss: 214938.7044
# Epoch 80, Average Training Loss: 286525.4549
# Epoch 80, Average Validation Loss: 214928.7322
# Epoch 81, Average Training Loss: 286515.0092
# Epoch 81, Average Validation Loss: 214899.3059
# Epoch 82, Average Training Loss: 286506.3309
# Epoch 82, Average Validation Loss: 214901.0228
# Epoch 83, Average Training Loss: 286500.7070
# Epoch 83, Average Validation Loss: 214888.2900
# Epoch 84, Average Training Loss: 286484.3893
# Epoch 84, Average Validation Loss: 214881.8797
# Epoch 85, Average Training Loss: 286472.5625
# Epoch 85, Average Validation Loss: 214865.3513
# Epoch 86, Average Training Loss: 286467.9273
# Epoch 86, Average Validation Loss: 214864.1837
# Epoch 87, Average Training Loss: 286454.5353
# Epoch 87, Average Validation Loss: 214855.3894
# Epoch 88, Average Training Loss: 286447.0126
# Epoch 88, Average Validation Loss: 214846.2225
# Epoch 89, Average Training Loss: 286432.1534
# Epoch 89, Average Validation Loss: 214835.8653
# Epoch 90, Average Training Loss: 286423.9173
# Epoch 90, Average Validation Loss: 214827.8394
# Epoch 91, Average Training Loss: 286420.9109
# Epoch 91, Average Validation Loss: 214820.3825
# Epoch 92, Average Training Loss: 286408.9120
# Epoch 92, Average Validation Loss: 214817.4003
# Epoch 93, Average Training Loss: 286396.0932
# Epoch 93, Average Validation Loss: 214811.9181
# Epoch 94, Average Training Loss: 286391.8412
# Epoch 94, Average Validation Loss: 214794.4425
# Epoch 95, Average Training Loss: 286379.8612
# Epoch 95, Average Validation Loss: 214800.7222
# Epoch 96, Average Training Loss: 286375.5507
# Epoch 96, Average Validation Loss: 214791.4569
# Epoch 97, Average Training Loss: 286367.5789
# Epoch 97, Average Validation Loss: 214780.0469
# Epoch 98, Average Training Loss: 286356.7923
# Epoch 98, Average Validation Loss: 214768.6825
# Epoch 99, Average Training Loss: 286349.7618
# Epoch 99, Average Validation Loss: 214771.5922
# Epoch 100, Average Training Loss: 286347.1829
# Epoch 100, Average Validation Loss: 214749.4947
# Epoch 101, Average Training Loss: 286338.1691
# Epoch 101, Average Validation Loss: 214763.5675
# Epoch 102, Average Training Loss: 286331.0064
# Epoch 102, Average Validation Loss: 214741.7928
# Epoch 103, Average Training Loss: 286327.2695
# Epoch 103, Average Validation Loss: 214737.3834
# Epoch 104, Average Training Loss: 286313.3730
# Epoch 104, Average Validation Loss: 214729.3356
# Epoch 105, Average Training Loss: 286308.6936
# Epoch 105, Average Validation Loss: 214720.6719
# Epoch 106, Average Training Loss: 286297.9944
# Epoch 106, Average Validation Loss: 214721.8956
# Epoch 107, Average Training Loss: 286294.3107
# Epoch 107, Average Validation Loss: 214710.4241
# Epoch 108, Average Training Loss: 286292.3284
# Epoch 108, Average Validation Loss: 214703.9147
# Epoch 109, Average Training Loss: 286285.0999
# Epoch 109, Average Validation Loss: 214711.4375
# Epoch 110, Average Training Loss: 286275.2546
# Epoch 110, Average Validation Loss: 214693.1481
# Epoch 111, Average Training Loss: 286270.5761
# Epoch 111, Average Validation Loss: 214701.2094
# Epoch 112, Average Training Loss: 286264.4422
# Epoch 112, Average Validation Loss: 214693.8206
# Epoch 113, Average Training Loss: 286263.0989
# Epoch 113, Average Validation Loss: 214683.6584
# Epoch 114, Average Training Loss: 286253.9762
# Epoch 114, Average Validation Loss: 214673.6356
# Epoch 115, Average Training Loss: 286248.1870
# Epoch 115, Average Validation Loss: 214673.3891
# Epoch 116, Average Training Loss: 286240.7935
# Epoch 116, Average Validation Loss: 214669.0694
# Epoch 117, Average Training Loss: 286234.1947
# Epoch 117, Average Validation Loss: 214669.1266
# Epoch 118, Average Training Loss: 286233.9780
# Epoch 118, Average Validation Loss: 214662.8059
# Epoch 119, Average Training Loss: 286224.7328
# Epoch 119, Average Validation Loss: 214650.2725
# Epoch 120, Average Training Loss: 286219.3471
# Epoch 120, Average Validation Loss: 214646.3888
# Epoch 121, Average Training Loss: 286215.7754
# Epoch 121, Average Validation Loss: 214641.5297
# Epoch 122, Average Training Loss: 286209.0804
# Epoch 122, Average Validation Loss: 214637.6719
# Epoch 123, Average Training Loss: 286201.3612
# Epoch 123, Average Validation Loss: 214636.2700
# Epoch 124, Average Training Loss: 286197.0610
# Epoch 124, Average Validation Loss: 214623.8153
# Epoch 125, Average Training Loss: 286190.4570
# Epoch 125, Average Validation Loss: 214623.5872
# Epoch 126, Average Training Loss: 286188.2300
# Epoch 126, Average Validation Loss: 214617.9709
# Epoch 127, Average Training Loss: 286181.0430
# Epoch 127, Average Validation Loss: 214614.3788
# Epoch 128, Average Training Loss: 286178.3811
# Epoch 128, Average Validation Loss: 214606.4325
# Epoch 129, Average Training Loss: 286172.2956
# Epoch 129, Average Validation Loss: 214605.8438
# Epoch 130, Average Training Loss: 286164.0389
# Epoch 130, Average Validation Loss: 214599.6581
# Epoch 131, Average Training Loss: 286161.8448
# Epoch 131, Average Validation Loss: 214588.8247
# Epoch 132, Average Training Loss: 286158.0881
# Epoch 132, Average Validation Loss: 214589.8859
# Epoch 133, Average Training Loss: 286148.1957
# Epoch 133, Average Validation Loss: 214587.8803
# Epoch 134, Average Training Loss: 286145.3417
# Epoch 134, Average Validation Loss: 214580.6744
# Epoch 135, Average Training Loss: 286144.5169
# Epoch 135, Average Validation Loss: 214574.1509
# Epoch 136, Average Training Loss: 286138.2485
# Epoch 136, Average Validation Loss: 214565.8991
# Epoch 137, Average Training Loss: 286130.8991
# Epoch 137, Average Validation Loss: 214571.9234
# Epoch 138, Average Training Loss: 286127.5092
# Epoch 138, Average Validation Loss: 214566.2306
# Epoch 139, Average Training Loss: 286121.6644
# Epoch 139, Average Validation Loss: 214562.0309
# Epoch 140, Average Training Loss: 286117.2659
# Epoch 140, Average Validation Loss: 214550.1016
# Epoch 141, Average Training Loss: 286111.1575
# Epoch 141, Average Validation Loss: 214552.2422
# Epoch 142, Average Training Loss: 286107.4273
# Epoch 142, Average Validation Loss: 214548.6059
# Epoch 143, Average Training Loss: 286105.3532
# Epoch 143, Average Validation Loss: 214546.1197
# Epoch 144, Average Training Loss: 286098.6132
# Epoch 144, Average Validation Loss: 214544.2141
# Epoch 145, Average Training Loss: 286094.1117
# Epoch 145, Average Validation Loss: 214541.0044
# Epoch 146, Average Training Loss: 286088.8023
# Epoch 146, Average Validation Loss: 214541.2319
# Epoch 147, Average Training Loss: 286088.1691
# Epoch 147, Average Validation Loss: 214528.0253
# Epoch 148, Average Training Loss: 286080.3422
# Epoch 148, Average Validation Loss: 214524.2141
# Epoch 149, Average Training Loss: 286073.2474
# Epoch 149, Average Validation Loss: 214522.3284
# Epoch 150, Average Training Loss: 286072.7736
# Epoch 150, Average Validation Loss: 214516.1706
# Epoch 151, Average Training Loss: 286068.9137
# Epoch 151, Average Validation Loss: 214515.4094
# Epoch 152, Average Training Loss: 286064.7123
# Epoch 152, Average Validation Loss: 214513.6028
# Epoch 153, Average Training Loss: 286061.8945
# Epoch 153, Average Validation Loss: 214503.7909
# Epoch 154, Average Training Loss: 286056.8870
# Epoch 154, Average Validation Loss: 214517.2969
# Epoch 155, Average Training Loss: 286056.6355
# Epoch 155, Average Validation Loss: 214503.4025
# Epoch 156, Average Training Loss: 286051.9232
# Epoch 156, Average Validation Loss: 214510.9662
# Epoch 157, Average Training Loss: 286047.6025
# Epoch 157, Average Validation Loss: 214491.9091
# Epoch 158, Average Training Loss: 286038.9088
# Epoch 158, Average Validation Loss: 214492.7669
# Epoch 159, Average Training Loss: 286034.5907
# Epoch 159, Average Validation Loss: 214491.3538
# Epoch 160, Average Training Loss: 286032.2141
# Epoch 160, Average Validation Loss: 214482.5478
# Epoch 161, Average Training Loss: 286028.7249
# Epoch 161, Average Validation Loss: 214478.2744
# Epoch 162, Average Training Loss: 286027.7482
# Epoch 162, Average Validation Loss: 214479.4181
# Epoch 163, Average Training Loss: 286022.4769
# Epoch 163, Average Validation Loss: 214477.4825
# Epoch 164, Average Training Loss: 286018.2341
# Epoch 164, Average Validation Loss: 214466.3722
# Epoch 165, Average Training Loss: 286013.0543
# Epoch 165, Average Validation Loss: 214471.8456
# Epoch 166, Average Training Loss: 286011.8148
# Epoch 166, Average Validation Loss: 214462.9619
# Epoch 167, Average Training Loss: 286004.8268
# Epoch 167, Average Validation Loss: 214459.1553
# Epoch 168, Average Training Loss: 286000.8655
# Epoch 168, Average Validation Loss: 214460.0691
# Epoch 169, Average Training Loss: 286000.0261
# Epoch 169, Average Validation Loss: 214444.2634
# Epoch 170, Average Training Loss: 285993.1639
# Epoch 170, Average Validation Loss: 214452.3000
# Epoch 171, Average Training Loss: 285993.1035
# Epoch 171, Average Validation Loss: 214440.8737
# Epoch 172, Average Training Loss: 285992.1342
# Epoch 172, Average Validation Loss: 214442.0178
# Epoch 173, Average Training Loss: 285982.8478
# Epoch 173, Average Validation Loss: 214432.8384
# Epoch 174, Average Training Loss: 285981.9252
# Epoch 174, Average Validation Loss: 214440.0466
# Epoch 175, Average Training Loss: 285979.2851
# Epoch 175, Average Validation Loss: 214426.4688
# Epoch 176, Average Training Loss: 285977.8694
# Epoch 176, Average Validation Loss: 214432.9163
# Epoch 177, Average Training Loss: 285969.2841
# Epoch 177, Average Validation Loss: 214423.9438
# Epoch 178, Average Training Loss: 285967.6614
# Epoch 178, Average Validation Loss: 214426.0150
# Epoch 179, Average Training Loss: 285965.2075
# Epoch 179, Average Validation Loss: 214428.2737
# Epoch 180, Average Training Loss: 285961.9823
# Epoch 180, Average Validation Loss: 214420.0791
# Epoch 181, Average Training Loss: 285958.0248
# Epoch 181, Average Validation Loss: 214415.1984
# Epoch 182, Average Training Loss: 285955.8309
# Epoch 182, Average Validation Loss: 214412.3491
# Epoch 183, Average Training Loss: 285954.3089
# Epoch 183, Average Validation Loss: 214405.7384
# Epoch 184, Average Training Loss: 285948.4298
# Epoch 184, Average Validation Loss: 214407.0994
# Epoch 185, Average Training Loss: 285948.6609
# Epoch 185, Average Validation Loss: 214399.1816
# Epoch 186, Average Training Loss: 285945.3714
# Epoch 186, Average Validation Loss: 214401.2031
# Epoch 187, Average Training Loss: 285941.5886
# Epoch 187, Average Validation Loss: 214410.2059
# Epoch 188, Average Training Loss: 285939.7126
# Epoch 188, Average Validation Loss: 214394.4756
# Epoch 189, Average Training Loss: 285933.0049
# Epoch 189, Average Validation Loss: 214396.8959
# Epoch 190, Average Training Loss: 285932.5856
# Epoch 190, Average Validation Loss: 214393.0528
# Epoch 191, Average Training Loss: 285926.9472
# Epoch 191, Average Validation Loss: 214390.8737
# Epoch 192, Average Training Loss: 285928.2946
# Epoch 192, Average Validation Loss: 214386.0872
# Epoch 193, Average Training Loss: 285922.8760
# Epoch 193, Average Validation Loss: 214380.3681
# Epoch 194, Average Training Loss: 285920.3735
# Epoch 194, Average Validation Loss: 214382.1494
# Epoch 195, Average Training Loss: 285920.5307
# Epoch 195, Average Validation Loss: 214376.0638
# Epoch 196, Average Training Loss: 285918.5663
# Epoch 196, Average Validation Loss: 214382.7106
# Epoch 197, Average Training Loss: 285913.6609
# Epoch 197, Average Validation Loss: 214376.0509
# Epoch 198, Average Training Loss: 285912.4331
# Epoch 198, Average Validation Loss: 214366.2756
# Epoch 199, Average Training Loss: 285908.2234
# Epoch 199, Average Validation Loss: 214370.9072
# Epoch 200, Average Training Loss: 285906.1112
# Epoch 200, Average Validation Loss: 214370.4794
# Epoch 201, Average Training Loss: 285905.2016
# Epoch 201, Average Validation Loss: 214362.0316
# Epoch 202, Average Training Loss: 285901.9913
# Epoch 202, Average Validation Loss: 214362.0100
# Epoch 203, Average Training Loss: 285901.7054
# Epoch 203, Average Validation Loss: 214359.1522
# Epoch 204, Average Training Loss: 285899.1368
# Epoch 204, Average Validation Loss: 214361.1406
# Epoch 205, Average Training Loss: 285897.0881
# Epoch 205, Average Validation Loss: 214361.9044
# Epoch 206, Average Training Loss: 285893.6647
# Epoch 206, Average Validation Loss: 214364.7300
# Epoch 207, Average Training Loss: 285891.8940
# Epoch 207, Average Validation Loss: 214360.9259
# Epoch 208, Average Training Loss: 285889.5707
# Epoch 208, Average Validation Loss: 214348.9634
# Epoch 209, Average Training Loss: 285885.3945
# Epoch 209, Average Validation Loss: 214352.7150
# Epoch 210, Average Training Loss: 285886.7843
# Epoch 210, Average Validation Loss: 214344.5584
# Epoch 211, Average Training Loss: 285880.5809
# Epoch 211, Average Validation Loss: 214347.6787
# Epoch 212, Average Training Loss: 285878.5000
# Epoch 212, Average Validation Loss: 214351.2447
# Epoch 213, Average Training Loss: 285879.4892
# Epoch 213, Average Validation Loss: 214343.5237
# Epoch 214, Average Training Loss: 285872.9734
# Epoch 214, Average Validation Loss: 214340.8588
# Epoch 215, Average Training Loss: 285873.3491
# Epoch 215, Average Validation Loss: 214340.3456
# Epoch 216, Average Training Loss: 285869.5236
# Epoch 216, Average Validation Loss: 214334.0797
# Epoch 217, Average Training Loss: 285868.2482
# Epoch 217, Average Validation Loss: 214328.1103
# Epoch 218, Average Training Loss: 285867.9452
# Epoch 218, Average Validation Loss: 214333.0250
# Epoch 219, Average Training Loss: 285863.0292
# Epoch 219, Average Validation Loss: 214331.0503
# Epoch 220, Average Training Loss: 285861.1857
# Epoch 220, Average Validation Loss: 214328.4194
# Epoch 221, Average Training Loss: 285861.5784
# Epoch 221, Average Validation Loss: 214328.4659
# Epoch 222, Average Training Loss: 285860.1742
# Epoch 222, Average Validation Loss: 214328.5187
# Epoch 223, Average Training Loss: 285857.9185
# Epoch 223, Average Validation Loss: 214326.0106
# Epoch 224, Average Training Loss: 285857.1814
# Epoch 224, Average Validation Loss: 214325.3134
# Epoch 225, Average Training Loss: 285851.5179
# Epoch 225, Average Validation Loss: 214322.7166
# Epoch 226, Average Training Loss: 285853.2218
# Epoch 226, Average Validation Loss: 214317.0341
# Epoch 227, Average Training Loss: 285850.4808
# Epoch 227, Average Validation Loss: 214322.4000
# Epoch 228, Average Training Loss: 285848.2239
# Epoch 228, Average Validation Loss: 214317.9672
# Epoch 229, Average Training Loss: 285845.9857
# Epoch 229, Average Validation Loss: 214315.9584
# Epoch 230, Average Training Loss: 285844.2100
# Epoch 230, Average Validation Loss: 214310.1178
# Epoch 231, Average Training Loss: 285843.1076
# Epoch 231, Average Validation Loss: 214317.4116
# Epoch 232, Average Training Loss: 285842.2959
# Epoch 232, Average Validation Loss: 214306.8987
# Epoch 233, Average Training Loss: 285837.0149
# Epoch 233, Average Validation Loss: 214313.3612
# Epoch 234, Average Training Loss: 285842.5051
# Epoch 234, Average Validation Loss: 214306.0003
# Epoch 235, Average Training Loss: 285836.8053
# Epoch 235, Average Validation Loss: 214305.9184
# Epoch 236, Average Training Loss: 285835.2487
# Epoch 236, Average Validation Loss: 214308.5250
# Epoch 237, Average Training Loss: 285831.5620
# Epoch 237, Average Validation Loss: 214310.3744
# Epoch 238, Average Training Loss: 285830.2147
# Epoch 238, Average Validation Loss: 214297.9525
# Epoch 239, Average Training Loss: 285831.7810
# Epoch 239, Average Validation Loss: 214296.0341
# Epoch 240, Average Training Loss: 285825.7272
# Epoch 240, Average Validation Loss: 214298.4113
# Epoch 241, Average Training Loss: 285823.1045
# Epoch 241, Average Validation Loss: 214293.8031
# Epoch 242, Average Training Loss: 285823.9631
# Epoch 242, Average Validation Loss: 214298.2103
# Epoch 243, Average Training Loss: 285822.0159
# Epoch 243, Average Validation Loss: 214302.5916
# Epoch 244, Average Training Loss: 285820.7228
# Epoch 244, Average Validation Loss: 214291.5428
# Epoch 245, Average Training Loss: 285818.1593
# Epoch 245, Average Validation Loss: 214286.4675
# Epoch 246, Average Training Loss: 285819.0489
# Epoch 246, Average Validation Loss: 214294.8037
# Epoch 247, Average Training Loss: 285814.7357
# Epoch 247, Average Validation Loss: 214283.8366
# Epoch 248, Average Training Loss: 285815.5320
# Epoch 248, Average Validation Loss: 214292.6300
# Epoch 249, Average Training Loss: 285813.3573
# Epoch 249, Average Validation Loss: 214283.3387
# Epoch 250, Average Training Loss: 285812.3832
# Epoch 250, Average Validation Loss: 214284.2056

# %%
model.eval()
test_loss = 0
with torch.no_grad():
    for data in test_loader:
        x = data[0].to(device, dtype=torch.float)
        recon_batch, mu, logvar = model(x)
        loss = loss_function(recon_batch, x, mu, logvar)
        test_loss += loss.item()
avg_test_loss = test_loss / len(test_loader.dataset)
print(f"Average Test Loss: {avg_test_loss:.4f}")
# Out:
# Average Test Loss: 269049.3879

# %%
import matplotlib.pyplot as plt

# Function to display original and reconstructed images
def visualize_reconstruction(model, data_loader):
    model.eval()
    with torch.no_grad():
        data = next(iter(data_loader))
        x = data[0].to(device, dtype=torch.float)
        recon_x, _, _ = model(x)
        
        # Move tensors to CPU and convert to numpy
        x = x.cpu().numpy()
        recon_x = recon_x.cpu().numpy()
        
        n = min(x.shape[0], 5)  # Number of samples to display
        for i in range(n):
            fig, axes = plt.subplots(2, 3, figsize=(12, 6))
            for j in range(3):
                axes[0, j].imshow(x[i, j], cmap='viridis')
                axes[0, j].set_title(f'Original - Matrix {j+1}')
                axes[0, j].axis('off')
                axes[1, j].imshow(recon_x[i, j], cmap='viridis')
                axes[1, j].set_title(f'Reconstructed - Matrix {j+1}')
                axes[1, j].axis('off')
            plt.show()

# Visualize reconstructions on test data
visualize_reconstruction(model, test_loader)

# %%
# Save the trained model
model_save_path = os.path.join(project_dir, 'conv_vae_model.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /home/diego/Escritorio/azheimer/conv_vae_model.pth

# %%
# Load the model
model = ConvVAE(latent_dim=latent_dim).to(device)
model.load_state_dict(torch.load(model_save_path))
model.eval()
# Out:
# ConvVAE(
#   (enc_conv1): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (fc_mu): Linear(in_features=12544, out_features=20, bias=True)
#   (fc_logvar): Linear(in_features=12544, out_features=20, bias=True)
#   (fc_decode): Linear(in_features=20, out_features=12544, bias=True)
#   (dec_conv1): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv2): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv3): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv4): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (output_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0)
# )
