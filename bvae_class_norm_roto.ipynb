# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Set paths
project_dir = '/home/diego/Escritorio/azheimer/'  # Adjust to your path
csv_path = os.path.join(project_dir, 'DataBaseSubjects.csv')
tensor_data_dir = os.path.join(project_dir, 'TensorData')

# Load the CSV file
subjects_df = pd.read_csv(csv_path)

# Calculate the median age and print it
median_age = subjects_df['Age'].median()
print(f"Median Age: {median_age}")

# Plot the age distribution
plt.figure(figsize=(8, 6))
sns.histplot(subjects_df['Age'], bins=20, kde=True, color='blue')
plt.axvline(median_age, color='red', linestyle='--', label=f'Median Age: {median_age}')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Plot the sex distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Plot the distribution of AD, CN, and Others
plt.figure(figsize=(8, 6))
sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
plt.title('AD, CN, and Others Distribution')
plt.xlabel('Research Group')
plt.ylabel('Count')
plt.show()

# Group subjects by Research Group and Sex
grouped_data = subjects_df.groupby(['ResearchGroup', 'Sex']).size().unstack().fillna(0)
print(grouped_data)

# Initialize dictionaries for storing tensor paths by group and sex
tensor_groups = {
    'AD_men': [],
    'AD_women': [],
    'CN_men': [],
    'CN_women': [],
    'Other_men': [],
    'Other_women': []
}

# Iterate over subjects and assign tensors to groups
for subject_id in subjects_df['SubjectID']:
    group = subjects_df[subjects_df['SubjectID'] == subject_id]['ResearchGroup'].values[0]
    sex = subjects_df[subjects_df['SubjectID'] == subject_id]['Sex'].values[0]
    file_name = f'{group}_tensor_{subject_id}.pt'
    file_path = os.path.join(tensor_data_dir, file_name)
    
    if os.path.exists(file_path):
        if group == 'AD':
            if sex == 'M':
                tensor_groups['AD_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['AD_women'].append(file_path)
        elif group == 'CN':
            if sex == 'M':
                tensor_groups['CN_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['CN_women'].append(file_path)
        else:  # Others
            if sex == 'M':
                tensor_groups['Other_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['Other_women'].append(file_path)

# Print the number of subjects in each group
for key, value in tensor_groups.items():
    print(f'{key}: {len(value)} subjects')

# Split data into train, validation, and test sets with equal proportions
def split_data(tensors, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    np.random.shuffle(tensors)
    n_total = len(tensors)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    
    train_set = tensors[:n_train]
    val_set = tensors[n_train:n_train + n_val]
    test_set = tensors[n_train + n_val:]
    
    return train_set, val_set, test_set

# Initialize lists for train, validation, and test sets
train_set, val_set, test_set = [], [], []

# Combine groups ensuring equal proportions of gender and research groups
for group in tensor_groups:
    train, val, test = split_data(tensor_groups[group])
    train_set.extend(train)
    val_set.extend(val)
    test_set.extend(test)

# Print final counts of train, validation, and test sets
print(f"Train set: {len(train_set)} subjects")
print(f"Validation set: {len(val_set)} subjects")
print(f"Test set: {len(test_set)} subjects")
# Out:
# Median Age: 74.25
# /tmp/ipykernel_20927/3646991604.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
# /tmp/ipykernel_20927/3646991604.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
# Sex             F   M
# ResearchGroup
# AD             40  55
# CN             52  37
# EMCI            8  10
# LMCI           23  32
# MCI            42  53
# AD_men: 55 subjects
# AD_women: 40 subjects
# CN_men: 37 subjects
# CN_women: 52 subjects
# Other_men: 95 subjects
# Other_women: 73 subjects
# Train set: 244 subjects
# Validation set: 50 subjects
# Test set: 58 subjects

# %%
# Load the tensors without normalization
def load_tensors(file_paths):
    tensors = []
    for fp in file_paths:
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        tensors.append(data)
    return torch.stack(tensors)

# Load training data
train_data = load_tensors(train_set)

# Compute mean and std per channel
def compute_mean_std_per_channel(dataset):
    # dataset shape: (N_samples, Channels, Height, Width)
    mean = dataset.mean(dim=(0, 2, 3))
    std = dataset.std(dim=(0, 2, 3))
    return mean, std

train_mean, train_std = compute_mean_std_per_channel(train_data)
print(f"Train Mean per Channel: {train_mean}")
print(f"Train Std per Channel: {train_std}")

# Normalize datasets
def normalize_dataset(dataset, mean, std):
    # Normalize each channel using the training mean and std
    return (dataset - mean[None, :, None, None]) / std[None, :, None, None]

train_data = normalize_dataset(train_data, train_mean, train_std)

# Load and normalize validation and test data
val_data = load_tensors(val_set)
val_data = normalize_dataset(val_data, train_mean, train_std)

test_data = load_tensors(test_set)
test_data = normalize_dataset(test_data, train_mean, train_std)

# Print final dataset shapes
print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")

import torch

# Assuming train_set, val_set, test_set are your datasets (could be PyTorch Datasets or DataLoaders)
torch.save(train_data, 'sets/train_set.pt')
torch.save(val_data, 'sets/val_set.pt')
torch.save(test_data, 'sets/test_set.pt')
# Out:
# Train Mean per Channel: tensor([0.3372, 0.3239, 3.1097], dtype=torch.float64)
# Train Std per Channel: tensor([0.2675, 0.1902, 3.9319], dtype=torch.float64)
# Train data shape: torch.Size([244, 3, 116, 116])
# Validation data shape: torch.Size([50, 3, 116, 116])
# Test data shape: torch.Size([58, 3, 116, 116])

# %%
import random
import matplotlib.pyplot as plt

# Function to plot the three matrices for a given subject's tensor
def plot_matrices(tensor, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    matrix_titles = ['Correlation Matrix', 'Mutual Information Matrix', 'Granger Causality Matrix']

    # Loop through the three matrices
    for i in range(3):
        ax = axes[i]
        cax = ax.matshow(tensor[i], cmap='viridis')
        fig.colorbar(cax, ax=ax)
        ax.set_title(f'{title_prefix} - {matrix_titles[i]}')
        ax.set_xlabel('ROIs')
        ax.set_ylabel('ROIs')

    plt.tight_layout()
    plt.show()

# Choose a random subject from each dataset and plot their matrices
def plot_random_subject_from_dataset(dataset, dataset_name):
    random_subject = random.choice(dataset)
    print(f"Plotting matrices for a random subject from {dataset_name} dataset: {random_subject}")
    
    # Load the tensor for the randomly selected subject
    tensor = torch.load(random_subject)
    
    # Plot the matrices
    plot_matrices(tensor, dataset_name)

# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_set, 'Train')
plot_random_subject_from_dataset(val_set, 'Validation')
plot_random_subject_from_dataset(test_set, 'Test')


# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_data, 'Train')
plot_random_subject_from_dataset(val_data, 'Validation')
plot_random_subject_from_dataset(test_data, 'Test')
# Out:
# Plotting matrices for a random subject from Train dataset: /home/diego/Escritorio/azheimer/TensorData/MCI_tensor_035_S_7021.pt
# Plotting matrices for a random subject from Validation dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_168_S_6938.pt
# Plotting matrices for a random subject from Test dataset: /home/diego/Escritorio/azheimer/TensorData/AD_tensor_006_S_6689.pt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ConvVAE(nn.Module):
    def __init__(self, latent_dim=2, hidden_dim=1024):  # Added hidden_dim
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim  # New hidden dimension for the linear layers
        self.dropout_rate = 0.2  # Dropout rate

        # Encoder Layers
        self.enc_conv1 = nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1)    # Output: (64, 58, 58)
        self.enc_conv2 = nn.Conv2d(64, 128, 4, 2, 1)  # Output: (128, 29, 29)
        self.enc_conv3 = nn.Conv2d(128, 256, 4, 2, 1)  # Output: (256, 14, 14)
        self.enc_conv4 = nn.Conv2d(256, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.enc_conv5 = nn.Conv2d(512, 512, 4, 2, 1)  # Output: (512, 3, 3)

        # Compute the size after convolutional layers to flatten
        self.flatten_size = 512 * 3 * 3  # Updated to 4608

        # Linear layers after the convolutional layers in the encoder
        self.fc1 = nn.Linear(self.flatten_size, self.hidden_dim)  # New linear layer
        self.fc2 = nn.Linear(self.hidden_dim, self.hidden_dim)    # Second linear layer
        
        # Latent space
        self.fc_mu = nn.Linear(self.hidden_dim, latent_dim)  # Adjusted to latent space
        self.fc_logvar = nn.Linear(self.hidden_dim, latent_dim)

        # Decoder Layers
        self.fc_decode = nn.Linear(latent_dim, self.hidden_dim)
        self.fc_decode2 = nn.Linear(self.hidden_dim, self.hidden_dim)  # Second linear layer
        self.fc_decode3 = nn.Linear(self.hidden_dim, self.flatten_size)  # Map back to the flattened convolutional output

        self.dec_conv1 = nn.ConvTranspose2d(512, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.dec_conv2 = nn.ConvTranspose2d(512, 256, 4, 2, 1)  # Output: (256, 15, 15)
        self.dec_conv3 = nn.ConvTranspose2d(256, 128, 4, 2, 1)  # Output: (128, 31, 31)
        self.dec_conv4 = nn.ConvTranspose2d(128, 64, 4, 2, 1)   # Output: (64, 63, 63)
        self.dec_conv5 = nn.ConvTranspose2d(64, 3, 4, 2, 1)     # Output: (3, 127, 127)

        # Adjust output size to (3, 116, 116)
        self.output_padding = nn.ReflectionPad2d((-5, -6, -5, -6))  # Crop to (3, 116, 116)

        # Dropout layer
        self.dropout = nn.Dropout(self.dropout_rate)

    def encode(self, x):
        # Apply convolutional layers
        x1 = F.relu(self.enc_conv1(x))
        x2 = F.relu(self.enc_conv2(x1))
        x3 = F.relu(self.enc_conv3(x2))
        x4 = F.relu(self.enc_conv4(x3))
        x5 = F.relu(self.enc_conv5(x4))
        x5 = x5.view(x.size(0), -1)  # Flatten the output
        
        # Apply fully connected layers
        x5 = F.relu(self.fc1(x5))  # First linear layer
        x5 = self.dropout(x5)
        x5 = F.relu(self.fc2(x5))  # Second linear layer

        # Get the latent space variables
        mu = self.fc_mu(x5)
        logvar = self.fc_logvar(x5)
        return mu, logvar

    def decode(self, z):
        # Apply fully connected layers
        x = F.relu(self.fc_decode(z))  # First linear layer in decoder
        x = F.relu(self.fc_decode2(x))  # Second linear layer in decoder
        x = F.relu(self.fc_decode3(x))  # Map to the size before deconvolution
        x = x.view(z.size(0), 512, 3, 3)  # Reshape to convolutional output dimensions
        
        # Apply transposed convolutional layers to upsample
        x = F.relu(self.dec_conv1(x))
        x = F.relu(self.dec_conv2(x))
        x = F.relu(self.dec_conv3(x))
        x = F.relu(self.dec_conv4(x))
        x = torch.sigmoid(self.dec_conv5(x))
        x = F.interpolate(x, size=(116, 116), mode='bilinear', align_corners=False)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar, z

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

# %%
def loss_function(recon_x, x, mu, logvar, beta=1):
    # Reconstruction loss
    recon_loss = F.mse_loss(recon_x, x, reduction='mean')

    # KL Divergence (normalized per batch)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    KLD = KLD / x.size(0)  # Normalize KLD per batch

    # Total loss
    total_loss = recon_loss + beta * KLD

    return total_loss, recon_loss.item(), KLD.item()

# %%
from torch.utils.data import Dataset, DataLoader

class CustomTensorDataset(Dataset):
    def __init__(self, file_paths):
        self.file_paths = file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        fp = self.file_paths[idx]
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        #data = normalize_tensor(data)
        # Extract the label from the file name
        file_name = os.path.basename(fp)
        # Expected format: '{group}_tensor_{subject_id}.pt'
        group = file_name.split('_')[0]
        # Map group to labels
        if group in ['AD', 'CN']:
            label = group
        else:
            label = 'Others'
        return data, label

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create datasets
train_dataset = TensorDataset(train_data)
val_dataset = TensorDataset(val_data)
# Create the test dataset with labels
test_dataset = CustomTensorDataset(test_set)

# Create data loaders
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
# Create the data loader
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize model
latent_dim = 20  # You can adjust the size of the latent space
hidden_dim= 1024*4  # Hidden dimension for the linear layers
model = ConvVAE(latent_dim=latent_dim).to(device)

# Optimizer with L2 regularization (weight decay)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-8)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
# Out:
# Using device: cuda

# %%
# Early stopping parameters
early_stopping_patience = 25
best_val_loss = float('inf')
epochs_without_improvement = 0
model_save_path = os.path.join(project_dir, 'best_beta_vae_model.pth')

# %%
# Lists to store losses
train_total_losses = []
val_total_losses = []
train_recon_losses = []
train_kld_losses = []

num_epochs = 500  # Adjust the number of epochs as needed
beta = 100  # Set the beta value for the loss function

for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0
    train_recon_loss = 0
    train_kld_loss = 0

    for data in train_loader:
        x = data[0].to(device, dtype=torch.float)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar, _ = model(x)
        loss, recon_loss, kld_loss = loss_function(recon_batch, x, mu, logvar, beta=beta)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * x.size(0)  # Multiply by batch size
        train_recon_loss += recon_loss * x.size(0)
        train_kld_loss += kld_loss * x.size(0)
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    avg_train_recon_loss = train_recon_loss / len(train_loader.dataset)
    avg_train_kld_loss = train_kld_loss / len(train_loader.dataset)

    train_total_losses.append(avg_train_loss)
    train_recon_losses.append(avg_train_recon_loss)
    train_kld_losses.append(avg_train_kld_loss)
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data in val_loader:
            x = data[0].to(device, dtype=torch.float)
            recon_batch, mu, logvar, _ = model(x)
            loss, _, _ = loss_function(recon_batch, x, mu, logvar, beta=beta)
            val_loss += loss.item() * x.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_total_losses.append(avg_val_loss)
    
    print(f"Epoch {epoch}, Average Training Loss: {avg_train_loss:.6f}, Average Validation Loss: {avg_val_loss:.6f}")
    
    # Step the scheduler
    scheduler.step(avg_val_loss)
    
    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        # Save the model
        torch.save(model.state_dict(), model_save_path)
        print(f"Validation loss improved. Model saved to {model_save_path}")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= early_stopping_patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1, Average Training Loss: 1.721440, Average Validation Loss: 1.532467
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 2, Average Training Loss: 1.491713, Average Validation Loss: 1.313498
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 3, Average Training Loss: 1.324877, Average Validation Loss: 1.227178
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 4, Average Training Loss: 1.277751, Average Validation Loss: 1.205556
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 5, Average Training Loss: 1.268125, Average Validation Loss: 1.201034
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 6, Average Training Loss: 1.259537, Average Validation Loss: 1.196844
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 7, Average Training Loss: 1.255557, Average Validation Loss: 1.194885
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 8, Average Training Loss: 1.251189, Average Validation Loss: 1.190894
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 9, Average Training Loss: 1.244666, Average Validation Loss: 1.182114
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 10, Average Training Loss: 1.232217, Average Validation Loss: 1.164061
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 11, Average Training Loss: 1.208079, Average Validation Loss: 1.132248
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 12, Average Training Loss: 1.168564, Average Validation Loss: 1.088754
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 13, Average Training Loss: 1.125554, Average Validation Loss: 1.053166
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 14, Average Training Loss: 1.088118, Average Validation Loss: 1.024221
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 15, Average Training Loss: 1.058163, Average Validation Loss: 1.000840
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 16, Average Training Loss: 1.035179, Average Validation Loss: 0.985121
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 17, Average Training Loss: 1.020323, Average Validation Loss: 0.978144
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 18, Average Training Loss: 1.011224, Average Validation Loss: 0.974261
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 19, Average Training Loss: 1.006200, Average Validation Loss: 0.969843
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 20, Average Training Loss: 1.002713, Average Validation Loss: 0.968956
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 21, Average Training Loss: 0.999987, Average Validation Loss: 0.965656
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 22, Average Training Loss: 0.997710, Average Validation Loss: 0.963529
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 23, Average Training Loss: 0.995298, Average Validation Loss: 0.961998
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 24, Average Training Loss: 0.993126, Average Validation Loss: 0.960621
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 25, Average Training Loss: 0.991645, Average Validation Loss: 0.958959
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 26, Average Training Loss: 0.990280, Average Validation Loss: 0.957070
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 27, Average Training Loss: 0.988728, Average Validation Loss: 0.956130
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 28, Average Training Loss: 0.987131, Average Validation Loss: 0.954975
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 29, Average Training Loss: 0.985740, Average Validation Loss: 0.953627
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 30, Average Training Loss: 0.984458, Average Validation Loss: 0.952898
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 31, Average Training Loss: 0.983084, Average Validation Loss: 0.951752
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 32, Average Training Loss: 0.981681, Average Validation Loss: 0.950040
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 33, Average Training Loss: 0.980562, Average Validation Loss: 0.948705
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 34, Average Training Loss: 0.979084, Average Validation Loss: 0.947312
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 35, Average Training Loss: 0.977001, Average Validation Loss: 0.945779
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 36, Average Training Loss: 0.975453, Average Validation Loss: 0.943546
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 37, Average Training Loss: 0.973381, Average Validation Loss: 0.942499
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 38, Average Training Loss: 0.972222, Average Validation Loss: 0.941669
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 39, Average Training Loss: 0.970826, Average Validation Loss: 0.940333
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 40, Average Training Loss: 0.969635, Average Validation Loss: 0.939537
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 41, Average Training Loss: 0.968507, Average Validation Loss: 0.938871
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 42, Average Training Loss: 0.967836, Average Validation Loss: 0.937950
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 43, Average Training Loss: 0.966976, Average Validation Loss: 0.936797
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 44, Average Training Loss: 0.966135, Average Validation Loss: 0.936005
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 45, Average Training Loss: 0.965187, Average Validation Loss: 0.935254
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 46, Average Training Loss: 0.964439, Average Validation Loss: 0.934594
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 47, Average Training Loss: 0.963642, Average Validation Loss: 0.933998
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 48, Average Training Loss: 0.962841, Average Validation Loss: 0.933590
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 49, Average Training Loss: 0.962202, Average Validation Loss: 0.933065
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 50, Average Training Loss: 0.961745, Average Validation Loss: 0.932350
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 51, Average Training Loss: 0.961392, Average Validation Loss: 0.932030
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 52, Average Training Loss: 0.960768, Average Validation Loss: 0.932018
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 53, Average Training Loss: 0.960222, Average Validation Loss: 0.931133
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 54, Average Training Loss: 0.959901, Average Validation Loss: 0.931131
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 55, Average Training Loss: 0.959512, Average Validation Loss: 0.931094
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 56, Average Training Loss: 0.959000, Average Validation Loss: 0.930312
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 57, Average Training Loss: 0.958586, Average Validation Loss: 0.930077
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 58, Average Training Loss: 0.958469, Average Validation Loss: 0.929728
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 59, Average Training Loss: 0.957849, Average Validation Loss: 0.929327
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 60, Average Training Loss: 0.957269, Average Validation Loss: 0.928733
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 61, Average Training Loss: 0.956867, Average Validation Loss: 0.928531
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 62, Average Training Loss: 0.956579, Average Validation Loss: 0.927818
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 63, Average Training Loss: 0.956069, Average Validation Loss: 0.927409
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 64, Average Training Loss: 0.955750, Average Validation Loss: 0.927252
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 65, Average Training Loss: 0.955154, Average Validation Loss: 0.926779
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 66, Average Training Loss: 0.955047, Average Validation Loss: 0.926599
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 67, Average Training Loss: 0.954855, Average Validation Loss: 0.926219
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 68, Average Training Loss: 0.954378, Average Validation Loss: 0.926459
# Epoch 69, Average Training Loss: 0.954165, Average Validation Loss: 0.926254
# Epoch 70, Average Training Loss: 0.953891, Average Validation Loss: 0.925789
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 71, Average Training Loss: 0.953732, Average Validation Loss: 0.925457
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 72, Average Training Loss: 0.953457, Average Validation Loss: 0.925589
# Epoch 73, Average Training Loss: 0.953320, Average Validation Loss: 0.925727
# Epoch 74, Average Training Loss: 0.952822, Average Validation Loss: 0.925099
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 75, Average Training Loss: 0.952656, Average Validation Loss: 0.924941
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 76, Average Training Loss: 0.952428, Average Validation Loss: 0.924556
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 77, Average Training Loss: 0.952184, Average Validation Loss: 0.923978
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 78, Average Training Loss: 0.951600, Average Validation Loss: 0.924168
# Epoch 79, Average Training Loss: 0.951309, Average Validation Loss: 0.923480
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 80, Average Training Loss: 0.950971, Average Validation Loss: 0.923277
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 81, Average Training Loss: 0.950832, Average Validation Loss: 0.923053
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 82, Average Training Loss: 0.950522, Average Validation Loss: 0.922872
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 83, Average Training Loss: 0.950364, Average Validation Loss: 0.922665
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 84, Average Training Loss: 0.950310, Average Validation Loss: 0.922479
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 85, Average Training Loss: 0.950162, Average Validation Loss: 0.922417
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 86, Average Training Loss: 0.950247, Average Validation Loss: 0.922745
# Epoch 87, Average Training Loss: 0.949906, Average Validation Loss: 0.922531
# Epoch 88, Average Training Loss: 0.949725, Average Validation Loss: 0.922093
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 89, Average Training Loss: 0.949607, Average Validation Loss: 0.922175
# Epoch 90, Average Training Loss: 0.949432, Average Validation Loss: 0.921768
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 91, Average Training Loss: 0.949382, Average Validation Loss: 0.921708
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 92, Average Training Loss: 0.949259, Average Validation Loss: 0.921733
# Epoch 93, Average Training Loss: 0.949116, Average Validation Loss: 0.921511
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 94, Average Training Loss: 0.949064, Average Validation Loss: 0.921262
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 95, Average Training Loss: 0.948990, Average Validation Loss: 0.921430
# Epoch 96, Average Training Loss: 0.948822, Average Validation Loss: 0.921597
# Epoch 97, Average Training Loss: 0.948817, Average Validation Loss: 0.921119
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 98, Average Training Loss: 0.948710, Average Validation Loss: 0.921216
# Epoch 99, Average Training Loss: 0.948557, Average Validation Loss: 0.921245
# Epoch 100, Average Training Loss: 0.948514, Average Validation Loss: 0.920834
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 101, Average Training Loss: 0.948379, Average Validation Loss: 0.920887
# Epoch 102, Average Training Loss: 0.948226, Average Validation Loss: 0.920913
# Epoch 103, Average Training Loss: 0.948338, Average Validation Loss: 0.920661
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 104, Average Training Loss: 0.948314, Average Validation Loss: 0.920877
# Epoch 105, Average Training Loss: 0.948145, Average Validation Loss: 0.920832
# Epoch 106, Average Training Loss: 0.947968, Average Validation Loss: 0.920525
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 107, Average Training Loss: 0.948044, Average Validation Loss: 0.920312
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 108, Average Training Loss: 0.947835, Average Validation Loss: 0.920598
# Epoch 109, Average Training Loss: 0.947813, Average Validation Loss: 0.920341
# Epoch 110, Average Training Loss: 0.947821, Average Validation Loss: 0.920314
# Epoch 111, Average Training Loss: 0.947648, Average Validation Loss: 0.920534
# Epoch 112, Average Training Loss: 0.947587, Average Validation Loss: 0.920135
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 113, Average Training Loss: 0.947485, Average Validation Loss: 0.920466
# Epoch 114, Average Training Loss: 0.947475, Average Validation Loss: 0.920235
# Epoch 115, Average Training Loss: 0.947425, Average Validation Loss: 0.920138
# Epoch 116, Average Training Loss: 0.947291, Average Validation Loss: 0.919953
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 117, Average Training Loss: 0.947258, Average Validation Loss: 0.919862
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 118, Average Training Loss: 0.947256, Average Validation Loss: 0.920080
# Epoch 119, Average Training Loss: 0.947227, Average Validation Loss: 0.919909
# Epoch 120, Average Training Loss: 0.947132, Average Validation Loss: 0.919712
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 121, Average Training Loss: 0.947019, Average Validation Loss: 0.919555
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 122, Average Training Loss: 0.947034, Average Validation Loss: 0.920034
# Epoch 123, Average Training Loss: 0.947015, Average Validation Loss: 0.919668
# Epoch 124, Average Training Loss: 0.946890, Average Validation Loss: 0.919757
# Epoch 125, Average Training Loss: 0.946896, Average Validation Loss: 0.919901
# Epoch 126, Average Training Loss: 0.946796, Average Validation Loss: 0.919507
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 127, Average Training Loss: 0.946761, Average Validation Loss: 0.919503
# Epoch 00127: reducing learning rate of group 0 to 5.0000e-06.
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 128, Average Training Loss: 0.946688, Average Validation Loss: 0.919578
# Epoch 129, Average Training Loss: 0.946658, Average Validation Loss: 0.919375
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 130, Average Training Loss: 0.946605, Average Validation Loss: 0.919321
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 131, Average Training Loss: 0.946648, Average Validation Loss: 0.919260
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 132, Average Training Loss: 0.946546, Average Validation Loss: 0.919364
# Epoch 133, Average Training Loss: 0.946439, Average Validation Loss: 0.919332
# Epoch 134, Average Training Loss: 0.946559, Average Validation Loss: 0.919366
# Epoch 135, Average Training Loss: 0.946442, Average Validation Loss: 0.919277
# Epoch 136, Average Training Loss: 0.946446, Average Validation Loss: 0.919211
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 137, Average Training Loss: 0.946548, Average Validation Loss: 0.919208
# Epoch 00137: reducing learning rate of group 0 to 2.5000e-06.
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 138, Average Training Loss: 0.946406, Average Validation Loss: 0.919149
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 139, Average Training Loss: 0.946356, Average Validation Loss: 0.919012
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 140, Average Training Loss: 0.946326, Average Validation Loss: 0.919234
# Epoch 141, Average Training Loss: 0.946324, Average Validation Loss: 0.919172
# Epoch 142, Average Training Loss: 0.946357, Average Validation Loss: 0.919073
# Epoch 143, Average Training Loss: 0.946373, Average Validation Loss: 0.918962
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 144, Average Training Loss: 0.946311, Average Validation Loss: 0.919040
# Epoch 145, Average Training Loss: 0.946250, Average Validation Loss: 0.918999
# Epoch 00145: reducing learning rate of group 0 to 1.2500e-06.
# Epoch 146, Average Training Loss: 0.946198, Average Validation Loss: 0.918965
# Epoch 147, Average Training Loss: 0.946244, Average Validation Loss: 0.918960
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 148, Average Training Loss: 0.946209, Average Validation Loss: 0.918984
# Epoch 149, Average Training Loss: 0.946089, Average Validation Loss: 0.918929
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 150, Average Training Loss: 0.946249, Average Validation Loss: 0.919095
# Epoch 151, Average Training Loss: 0.946183, Average Validation Loss: 0.918907
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 152, Average Training Loss: 0.946188, Average Validation Loss: 0.918953
# Epoch 153, Average Training Loss: 0.946183, Average Validation Loss: 0.919035
# Epoch 154, Average Training Loss: 0.946136, Average Validation Loss: 0.918974
# Epoch 155, Average Training Loss: 0.946130, Average Validation Loss: 0.918914
# Epoch 156, Average Training Loss: 0.946135, Average Validation Loss: 0.918966
# Epoch 157, Average Training Loss: 0.946063, Average Validation Loss: 0.918838
# Epoch 00157: reducing learning rate of group 0 to 6.2500e-07.
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 158, Average Training Loss: 0.946063, Average Validation Loss: 0.918859
# Epoch 159, Average Training Loss: 0.946087, Average Validation Loss: 0.918950
# Epoch 160, Average Training Loss: 0.946092, Average Validation Loss: 0.919008
# Epoch 161, Average Training Loss: 0.946109, Average Validation Loss: 0.918954
# Epoch 162, Average Training Loss: 0.946146, Average Validation Loss: 0.918947
# Epoch 163, Average Training Loss: 0.946134, Average Validation Loss: 0.918883
# Epoch 00163: reducing learning rate of group 0 to 3.1250e-07.
# Epoch 164, Average Training Loss: 0.946048, Average Validation Loss: 0.918913
# Epoch 165, Average Training Loss: 0.946074, Average Validation Loss: 0.918864
# Epoch 166, Average Training Loss: 0.946096, Average Validation Loss: 0.918965
# Epoch 167, Average Training Loss: 0.946152, Average Validation Loss: 0.918911
# Epoch 168, Average Training Loss: 0.946143, Average Validation Loss: 0.918945
# Epoch 169, Average Training Loss: 0.946067, Average Validation Loss: 0.918962
# Epoch 00169: reducing learning rate of group 0 to 1.5625e-07.
# Epoch 170, Average Training Loss: 0.946069, Average Validation Loss: 0.918931
# Epoch 171, Average Training Loss: 0.946132, Average Validation Loss: 0.918939
# Epoch 172, Average Training Loss: 0.946067, Average Validation Loss: 0.918916
# Epoch 173, Average Training Loss: 0.946047, Average Validation Loss: 0.918820
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 174, Average Training Loss: 0.946080, Average Validation Loss: 0.918789
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_beta_vae_model.pth
# Epoch 175, Average Training Loss: 0.946061, Average Validation Loss: 0.918951
# Epoch 176, Average Training Loss: 0.946103, Average Validation Loss: 0.918955
# Epoch 177, Average Training Loss: 0.946125, Average Validation Loss: 0.918897
# Epoch 178, Average Training Loss: 0.946081, Average Validation Loss: 0.918977
# Epoch 179, Average Training Loss: 0.946043, Average Validation Loss: 0.918899
# Epoch 180, Average Training Loss: 0.946061, Average Validation Loss: 0.918895
# Epoch 00180: reducing learning rate of group 0 to 7.8125e-08.
# Epoch 181, Average Training Loss: 0.946105, Average Validation Loss: 0.918850
# Epoch 182, Average Training Loss: 0.946082, Average Validation Loss: 0.918916
# Epoch 183, Average Training Loss: 0.946165, Average Validation Loss: 0.919055
# Epoch 184, Average Training Loss: 0.946108, Average Validation Loss: 0.918892
# Epoch 185, Average Training Loss: 0.946139, Average Validation Loss: 0.918841
# Epoch 186, Average Training Loss: 0.946077, Average Validation Loss: 0.918811
# Epoch 00186: reducing learning rate of group 0 to 3.9063e-08.
# Epoch 187, Average Training Loss: 0.946079, Average Validation Loss: 0.918934
# Epoch 188, Average Training Loss: 0.946048, Average Validation Loss: 0.918935
# Epoch 189, Average Training Loss: 0.946067, Average Validation Loss: 0.918850
# Epoch 190, Average Training Loss: 0.946088, Average Validation Loss: 0.918861
# Epoch 191, Average Training Loss: 0.946069, Average Validation Loss: 0.918946
# Epoch 192, Average Training Loss: 0.946027, Average Validation Loss: 0.918927
# Epoch 00192: reducing learning rate of group 0 to 1.9531e-08.
# Epoch 193, Average Training Loss: 0.946045, Average Validation Loss: 0.918976
# Epoch 194, Average Training Loss: 0.946072, Average Validation Loss: 0.918844
# Epoch 195, Average Training Loss: 0.946083, Average Validation Loss: 0.918888
# Epoch 196, Average Training Loss: 0.946096, Average Validation Loss: 0.918831
# Epoch 197, Average Training Loss: 0.946063, Average Validation Loss: 0.918954
# Epoch 198, Average Training Loss: 0.946133, Average Validation Loss: 0.918813
# Epoch 199, Average Training Loss: 0.946115, Average Validation Loss: 0.918861
# Early stopping triggered.

# %%
# Plot training and validation loss over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_total_losses) + 1), train_total_losses, label='Training Loss')
plt.plot(range(1, len(val_total_losses) + 1), val_total_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
# Plot reconstruction loss and KL divergence over epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_recon_losses) + 1), train_recon_losses, label='Reconstruction Loss')
plt.plot(range(1, len(train_kld_losses) + 1), train_kld_losses, label='KL Divergence')
plt.plot(range(1, len(train_total_losses) + 1), beta * np.array(train_kld_losses), label='Beta * KL Divergence')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Reconstruction Loss and KL Divergence over Epochs')
plt.legend()
plt.show()

# %%
model.eval()
test_loss = 0
with torch.no_grad():
    for data in test_loader:
        x = data[0].to(device, dtype=torch.float)
        recon_batch, mu, logvar, z = model(x)
        loss , _ , _ = loss_function(recon_batch, x, mu, logvar)
        test_loss += loss.item()
avg_test_loss = test_loss / len(test_loader.dataset)
print(f"Average Test Loss: {avg_test_loss:.4f}")
# Out:
# Average Test Loss: 0.3013

# %%
import matplotlib.pyplot as plt

# Function to display original and reconstructed images
def visualize_reconstruction(model, data_loader):
    model.eval()
    with torch.no_grad():
        data = next(iter(data_loader))
        x = data[0].to(device, dtype=torch.float)
        recon_x, _, _ , _ = model(x)
        
        # Move tensors to CPU and convert to numpy
        x = x.cpu().numpy()
        recon_x = recon_x.cpu().numpy()
        
        n = min(x.shape[0], 5)  # Number of samples to display
        for i in range(n):
            fig, axes = plt.subplots(2, 3, figsize=(12, 6))
            for j in range(3):
                axes[0, j].imshow(x[i, j], cmap='viridis')
                axes[0, j].set_title(f'Original - Matrix {j+1}')
                axes[0, j].axis('off')
                axes[1, j].imshow(recon_x[i, j], cmap='viridis')
                axes[1, j].set_title(f'Reconstructed - Matrix {j+1}')
                axes[1, j].axis('off')
            plt.show()

# Visualize reconstructions on test data
visualize_reconstruction(model, test_loader)

# %%
# Save the trained model
model_save_path = os.path.join(project_dir, 'conv_vae_model.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /home/diego/Escritorio/azheimer/conv_vae_model.pth

# %%
# Load the model
model = ConvVAE(latent_dim=latent_dim).to(device)
model.load_state_dict(torch.load(model_save_path))
model.eval()
# Out:
# ConvVAE(
#   (enc_conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv5): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (fc1): Linear(in_features=4608, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc_mu): Linear(in_features=1024, out_features=20, bias=True)
#   (fc_logvar): Linear(in_features=1024, out_features=20, bias=True)
#   (fc_decode): Linear(in_features=20, out_features=1024, bias=True)
#   (fc_decode2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc_decode3): Linear(in_features=1024, out_features=4608, bias=True)
#   (dec_conv1): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (output_padding): ReflectionPad2d((-5, -6, -5, -6))
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
model.eval()
latents = []
labels = []

with torch.no_grad():
    for data, label in test_loader:
        x = data.to(device, dtype=torch.float)
        mu, logvar = model.encode(x)
        z = model.reparameterize(mu, logvar)
        latents.append(mu.cpu())
        labels.extend(label)  # Collect labels

# Concatenate all latent vectors and convert labels to a NumPy array
latents = torch.cat(latents, dim=0).numpy()
labels = np.array(labels)

# %%
from sklearn.manifold import TSNE

# Reduce latent dimensions to 2D using t-SNE
tsne = TSNE(n_components=2, random_state=42)
latents_2d = tsne.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
from sklearn.decomposition import PCA

# Reduce latent dimensions to 2D using PCA
pca = PCA(n_components=2)
latents_2d = pca.fit_transform(latents)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
latent_df = pd.DataFrame({
    'Dimension 1': latents_2d[:, 0],
    'Dimension 2': latents_2d[:, 1],
    'Group': labels
})

# Plot using seaborn
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=latent_df,
    x='Dimension 1',
    y='Dimension 2',
    hue='Group',
    palette='bright',
    alpha=0.7
)
plt.title('Latent Space Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Research Group')
plt.show()

# %%
# Function to extract latent representations and labels for AD and CN subjects
def extract_latents_and_labels(file_paths, model, device):
    latents = []
    labels = []
    
    model.eval()
    with torch.no_grad():
        for fp in file_paths:
            file_name = os.path.basename(fp)
            group = file_name.split('_')[0]
            if group not in ['AD', 'CN']:
                continue  # Skip "Others" category
            label = 1 if group == 'AD' else 0  # Assign labels: AD=1, CN=0
            data = torch.load(fp)
            if isinstance(data, np.ndarray):
                data = torch.tensor(data)
            #data = normalize_tensor(data)
            x = data.unsqueeze(0).to(device, dtype=torch.float)  # Add batch dimension
            mu, logvar = model.encode(x)
            z = model.reparameterize(mu, logvar)
            latents.append(mu.cpu().numpy().squeeze()) # Squeeze to remove batch dimension, mu instead of z
            labels.append(label)
    return np.array(latents), np.array(labels)

# %%
# Combine train and validation file paths
train_val_set = train_set + val_set

# Extract latents and labels for training (train + validation sets)
X_train, y_train = extract_latents_and_labels(train_val_set, model, device)

# Extract latents and labels for test set
X_test, y_test = extract_latents_and_labels(test_set, model, device)

# Print the shapes
print(f"Training data shape: {X_train.shape}, Training labels shape: {y_train.shape}")
print(f"Test data shape: {X_test.shape}, Test labels shape: {y_test.shape}")
# Out:
# Training data shape: (153, 20), Training labels shape: (153,)
# Test data shape: (31, 20), Test labels shape: (31,)

# %%
from collections import Counter

print(f"Training labels distribution: {Counter(y_train)}")
print(f"Test labels distribution: {Counter(y_test)}")
# Out:
# Training labels distribution: Counter({1: 80, 0: 73})
# Test labels distribution: Counter({0: 16, 1: 15})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
)

# Define classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM (Linear Kernel)": SVC(kernel='linear', probability=True),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "k-NN": KNeighborsClassifier(n_neighbors=5),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "Neural Network": MLPClassifier(hidden_layer_sizes=(50,), max_iter=1000),
}

# Dictionary to store performance metrics
performance_metrics = {}

# Train and evaluate each classifier
for name, clf in classifiers.items():
    # Train the classifier
    clf.fit(X_train, y_train)
    # Predict on test set
    y_pred = clf.predict(X_test)
    y_proba = clf.predict_proba(X_test)[:, 1] if hasattr(clf, "predict_proba") else None
    # Compute metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
    # Store metrics
    performance_metrics[name] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "ROC AUC": roc_auc,
    }
    # Print classification report
    print(f"Classifier: {name}")
    print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
    print("-" * 50)
# Out:
# Classifier: Logistic Regression
#               precision    recall  f1-score   support
#
#           CN       0.62      0.50      0.55        16
#           AD       0.56      0.67      0.61        15
#
#     accuracy                           0.58        31
#    macro avg       0.59      0.58      0.58        31
# weighted avg       0.59      0.58      0.58        31
#
# --------------------------------------------------
# Classifier: SVM (Linear Kernel)
#               precision    recall  f1-score   support
#
#           CN       0.53      0.50      0.52        16
#           AD       0.50      0.53      0.52        15
#
#     accuracy                           0.52        31
#    macro avg       0.52      0.52      0.52        31
# weighted avg       0.52      0.52      0.52        31
#
# --------------------------------------------------
# Classifier: Random Forest
#               precision    recall  f1-score   support
#
#           CN       0.67      0.50      0.57        16
#           AD       0.58      0.73      0.65        15
#
#     accuracy                           0.61        31
#    macro avg       0.62      0.62      0.61        31
# weighted avg       0.62      0.61      0.61        31
#
# --------------------------------------------------
# Classifier: k-NN
#               precision    recall  f1-score   support
#
#           CN       0.57      0.50      0.53        16
#           AD       0.53      0.60      0.56        15
#
#     accuracy                           0.55        31
#    macro avg       0.55      0.55      0.55        31
# weighted avg       0.55      0.55      0.55        31
#
# --------------------------------------------------
# Classifier: Gradient Boosting
#               precision    recall  f1-score   support
#
#           CN       0.67      0.50      0.57        16
#           AD       0.58      0.73      0.65        15
#
#     accuracy                           0.61        31
#    macro avg       0.62      0.62      0.61        31
# weighted avg       0.62      0.61      0.61        31
#
# --------------------------------------------------
# Classifier: Neural Network
#               precision    recall  f1-score   support
#
#           CN       0.54      0.44      0.48        16
#           AD       0.50      0.60      0.55        15
#
#     accuracy                           0.52        31
#    macro avg       0.52      0.52      0.51        31
# weighted avg       0.52      0.52      0.51        31
#
# --------------------------------------------------
# /home/diego/anaconda3/envs/santiago_env/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(
    estimator=RandomForestClassifier(),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")

# Evaluate the best model
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
# Best parameters: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#           CN       0.58      0.44      0.50        16
#           AD       0.53      0.67      0.59        15
#
#     accuracy                           0.55        31
#    macro avg       0.55      0.55      0.54        31
# weighted avg       0.56      0.55      0.54        31

# %%
import matplotlib.pyplot as plt

# Assuming you have trained a Random Forest classifier named 'best_rf'
importances = best_rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices], color="r", align="center")
plt.xticks(range(X_train.shape[1]), indices)
plt.xlabel("Feature Index")
plt.ylabel("Importance")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'class_weight': [None, 'balanced']
}

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit to training data
grid_search.fit(X_train, y_train)

# Best parameters and estimator
print(f"Best parameters: {grid_search.best_params_}")
best_rf = grid_search.best_estimator_

# Evaluate on test data
y_pred = best_rf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
# Best parameters: {'class_weight': None, 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 300}
#               precision    recall  f1-score   support
#
#           CN       0.58      0.44      0.50        16
#           AD       0.53      0.67      0.59        15
#
#     accuracy                           0.55        31
#    macro avg       0.55      0.55      0.54        31
# weighted avg       0.56      0.55      0.54        31

# %%
from sklearn.ensemble import VotingClassifier

# Initialize individual classifiers
clf1 = LogisticRegression(max_iter=1000, random_state=42)
clf2 = RandomForestClassifier(n_estimators=200, random_state=42)
clf3 = GradientBoostingClassifier(n_estimators=200, random_state=42)

# Create a voting classifier
voting_clf = VotingClassifier(
    estimators=[('lr', clf1), ('rf', clf2), ('gb', clf3)],
    voting='soft'  # Use 'hard' for majority voting
)

# Fit the voting classifier
voting_clf.fit(X_train, y_train)

# Evaluate on test data
y_pred = voting_clf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
#               precision    recall  f1-score   support
#
#           CN       0.67      0.50      0.57        16
#           AD       0.58      0.73      0.65        15
#
#     accuracy                           0.61        31
#    macro avg       0.62      0.62      0.61        31
# weighted avg       0.62      0.61      0.61        31

# %%
from sklearn.feature_selection import RFE

# Initialize a classifier
estimator = RandomForestClassifier(n_estimators=200, random_state=42)

# Initialize RFE
selector = RFE(estimator, n_features_to_select=10, step=1)
selector = selector.fit(X_train, y_train)

# Transform datasets
X_train_selected = selector.transform(X_train)
X_test_selected = selector.transform(X_test)

# Retrain classifier on selected features
estimator.fit(X_train_selected, y_train)

# Evaluate on test data
y_pred = estimator.predict(X_test_selected)
print(classification_report(y_test, y_pred, target_names=["CN", "AD"]))
# Out:
#               precision    recall  f1-score   support
#
#           CN       0.64      0.44      0.52        16
#           AD       0.55      0.73      0.63        15
#
#     accuracy                           0.58        31
#    macro avg       0.59      0.59      0.57        31
# weighted avg       0.59      0.58      0.57        31

# %%
# Assume we've identified that Random Forest and Gradient Boosting perform best

# Hyperparameter tuning for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5],
    'class_weight': [None, 'balanced']
}
grid_rf = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid_rf,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_rf.fit(X_train, y_train)
best_rf = grid_rf.best_estimator_

# Hyperparameter tuning for Gradient Boosting
param_grid_gb = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
}
grid_gb = GridSearchCV(
    GradientBoostingClassifier(random_state=42),
    param_grid_gb,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_gb.fit(X_train, y_train)
best_gb = grid_gb.best_estimator_

# Feature selection using feature importances from Random Forest
import numpy as np

# Get feature importances
importances = best_rf.feature_importances_

# Select top features
indices = np.argsort(importances)[::-1]
top_n = 10  # Number of top features to select
selected_features = indices[:top_n]

# Transform datasets
X_train_selected = X_train[:, selected_features]
X_test_selected = X_test[:, selected_features]

# Retrain best models on selected features
best_rf.fit(X_train_selected, y_train)
best_gb.fit(X_train_selected, y_train)

# Evaluate on test data
y_pred_rf = best_rf.predict(X_test_selected)
y_pred_gb = best_gb.predict(X_test_selected)

# Print classification reports
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf, target_names=["CN", "AD"]))
print("Gradient Boosting Classification Report:")
print(classification_report(y_test, y_pred_gb, target_names=["CN", "AD"]))

# Ensemble with Voting Classifier
from sklearn.ensemble import VotingClassifier

voting_clf = VotingClassifier(
    estimators=[('rf', best_rf), ('gb', best_gb)],
    voting='soft'
)
voting_clf.fit(X_train_selected, y_train)
y_pred_voting = voting_clf.predict(X_test_selected)
print("Voting Classifier Classification Report:")
print(classification_report(y_test, y_pred_voting, target_names=["CN", "AD"]))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#           CN       0.64      0.44      0.52        16
#           AD       0.55      0.73      0.63        15
#
#     accuracy                           0.58        31
#    macro avg       0.59      0.59      0.57        31
# weighted avg       0.59      0.58      0.57        31
#
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#           CN       0.50      0.31      0.38        16
#           AD       0.48      0.67      0.56        15
#
#     accuracy                           0.48        31
#    macro avg       0.49      0.49      0.47        31
# weighted avg       0.49      0.48      0.47        31
#
# Voting Classifier Classification Report:
#               precision    recall  f1-score   support
#
#           CN       0.60      0.38      0.46        16
#           AD       0.52      0.73      0.61        15
#
#     accuracy                           0.55        31
#    macro avg       0.56      0.55      0.54        31
# weighted avg       0.56      0.55      0.53        31
