# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# Set paths
project_dir = '/home/diego/Escritorio/azheimer/'  # Adjust to your path
csv_path = os.path.join(project_dir, 'DataBaseSubjects.csv')
tensor_data_dir = os.path.join(project_dir, 'TensorData')

# Load the CSV file
subjects_df = pd.read_csv(csv_path)

# Calculate the median age and print it
median_age = subjects_df['Age'].median()
print(f"Median Age: {median_age}")

# Plot the age distribution
plt.figure(figsize=(8, 6))
sns.histplot(subjects_df['Age'], bins=20, kde=True, color='blue')
plt.axvline(median_age, color='red', linestyle='--', label=f'Median Age: {median_age}')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Plot the sex distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# Plot the distribution of AD, CN, and Others
plt.figure(figsize=(8, 6))
sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
plt.title('AD, CN, and Others Distribution')
plt.xlabel('Research Group')
plt.ylabel('Count')
plt.show()

# Group subjects by Research Group and Sex
grouped_data = subjects_df.groupby(['ResearchGroup', 'Sex']).size().unstack().fillna(0)
print(grouped_data)

# Initialize dictionaries for storing tensor paths by group and sex
tensor_groups = {
    'AD_men': [],
    'AD_women': [],
    'CN_men': [],
    'CN_women': [],
    'Other_men': [],
    'Other_women': []
}

# Iterate over subjects and assign tensors to groups
for subject_id in subjects_df['SubjectID']:
    group = subjects_df[subjects_df['SubjectID'] == subject_id]['ResearchGroup'].values[0]
    sex = subjects_df[subjects_df['SubjectID'] == subject_id]['Sex'].values[0]
    file_name = f'{group}_tensor_{subject_id}.pt'
    file_path = os.path.join(tensor_data_dir, file_name)
    
    if os.path.exists(file_path):
        if group == 'AD':
            if sex == 'M':
                tensor_groups['AD_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['AD_women'].append(file_path)
        elif group == 'CN':
            if sex == 'M':
                tensor_groups['CN_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['CN_women'].append(file_path)
        else:  # Others
            if sex == 'M':
                tensor_groups['Other_men'].append(file_path)
            elif sex == 'F':
                tensor_groups['Other_women'].append(file_path)

# Print the number of subjects in each group
for key, value in tensor_groups.items():
    print(f'{key}: {len(value)} subjects')

# Split data into train, validation, and test sets with equal proportions
def split_data(tensors, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    np.random.shuffle(tensors)
    n_total = len(tensors)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    
    train_set = tensors[:n_train]
    val_set = tensors[n_train:n_train + n_val]
    test_set = tensors[n_train + n_val:]
    
    return train_set, val_set, test_set

# Initialize lists for train, validation, and test sets
train_set, val_set, test_set = [], [], []

# Combine groups ensuring equal proportions of gender and research groups
for group in tensor_groups:
    train, val, test = split_data(tensor_groups[group])
    train_set.extend(train)
    val_set.extend(val)
    test_set.extend(test)

# Print final counts of train, validation, and test sets
print(f"Train set: {len(train_set)} subjects")
print(f"Validation set: {len(val_set)} subjects")
print(f"Test set: {len(test_set)} subjects")
# Out:
# Median Age: 74.25
# /tmp/ipykernel_660978/3646991604.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=subjects_df, palette='coolwarm')
# /tmp/ipykernel_660978/3646991604.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ResearchGroup', data=subjects_df, palette='viridis')
# Sex             F   M
# ResearchGroup
# AD             40  55
# CN             52  37
# EMCI            8  10
# LMCI           23  32
# MCI            42  53
# AD_men: 55 subjects
# AD_women: 40 subjects
# CN_men: 37 subjects
# CN_women: 52 subjects
# Other_men: 95 subjects
# Other_women: 73 subjects
# Train set: 244 subjects
# Validation set: 50 subjects
# Test set: 58 subjects

# %%
# Function to normalize each channel of the tensor between 0 and 1
def normalize_tensor(tensor):
    normalized_tensor = torch.zeros_like(tensor)
    for i in range(tensor.shape[0]):  # For each channel
        channel_data = tensor[i]
        min_val = channel_data.min()
        max_val = channel_data.max()
        # Avoid division by zero
        if max_val - min_val != 0:
            normalized_tensor[i] = (channel_data - min_val) / (max_val - min_val)
        else:
            normalized_tensor[i] = channel_data - min_val
    return normalized_tensor

# %%
# Load the tensors and create datasets
def load_tensors(file_paths):
    tensors = []
    for fp in file_paths:
        data = torch.load(fp)
        if isinstance(data, np.ndarray):  # Convert numpy arrays to tensors
            data = torch.tensor(data)
        # Normalize the data
        data = normalize_tensor(data)
        tensors.append(data)
    return torch.stack(tensors)


# Load data for train, validation, and test sets
train_data = load_tensors(train_set)
val_data = load_tensors(val_set)
test_data = load_tensors(test_set)

# Print final dataset shapes
print(f"Train data shape: {train_data.shape}")
print(f"Validation data shape: {val_data.shape}")
print(f"Test data shape: {test_data.shape}")
# Out:
# Train data shape: torch.Size([244, 3, 116, 116])
# Validation data shape: torch.Size([50, 3, 116, 116])
# Test data shape: torch.Size([58, 3, 116, 116])

# %%
import random
import matplotlib.pyplot as plt

# Function to plot the three matrices for a given subject's tensor
def plot_matrices(tensor, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    matrix_titles = ['Correlation Matrix', 'Mutual Information Matrix', 'Granger Causality Matrix']

    # Loop through the three matrices
    for i in range(3):
        ax = axes[i]
        cax = ax.matshow(tensor[i], cmap='viridis')
        fig.colorbar(cax, ax=ax)
        ax.set_title(f'{title_prefix} - {matrix_titles[i]}')
        ax.set_xlabel('ROIs')
        ax.set_ylabel('ROIs')

    plt.tight_layout()
    plt.show()

# Choose a random subject from each dataset and plot their matrices
def plot_random_subject_from_dataset(dataset, dataset_name):
    random_subject = random.choice(dataset)
    print(f"Plotting matrices for a random subject from {dataset_name} dataset: {random_subject}")
    
    # Load the tensor for the randomly selected subject
    tensor = torch.load(random_subject)
    
    # Plot the matrices
    plot_matrices(tensor, dataset_name)

# Plot one random subject from train, validation, and test datasets
plot_random_subject_from_dataset(train_set, 'Train')
plot_random_subject_from_dataset(val_set, 'Validation')
plot_random_subject_from_dataset(test_set, 'Test')
# Out:
# Plotting matrices for a random subject from Train dataset: /home/diego/Escritorio/azheimer/TensorData/LMCI_tensor_012_S_4094.pt
# Plotting matrices for a random subject from Validation dataset: /home/diego/Escritorio/azheimer/TensorData/MCI_tensor_003_S_1122.pt
# Plotting matrices for a random subject from Test dataset: /home/diego/Escritorio/azheimer/TensorData/MCI_tensor_053_S_6598.pt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class ConvVAE(nn.Module):
    def __init__(self, latent_dim=2):
        super(ConvVAE, self).__init__()
        self.latent_dim = latent_dim
        self.dropout_rate = 0.3  # Dropout rate

        # Encoder Layers
        self.enc_conv1 = nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1)    # Output: (64, 58, 58)
        self.enc_conv2 = nn.Conv2d(64, 128, 4, 2, 1)  # Output: (128, 29, 29)
        self.enc_conv3 = nn.Conv2d(128, 256, 4, 2, 1)  # Output: (256, 14, 14)
        self.enc_conv4 = nn.Conv2d(256, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.enc_conv5 = nn.Conv2d(512, 512, 4, 2, 1)  # Output: (512, 3, 3)

        # Compute the size after convolutional layers to flatten
        self.flatten_size = 512 * 3 * 3  # Updated to 4608

        # Latent space
        self.fc_mu = nn.Linear(self.flatten_size, latent_dim)
        self.fc_logvar = nn.Linear(self.flatten_size, latent_dim)

        # Decoder Layers
        self.fc_decode = nn.Linear(latent_dim, self.flatten_size)
        self.dec_conv1 = nn.ConvTranspose2d(512, 512, 4, 2, 1)  # Output: (512, 7, 7)
        self.dec_conv2 = nn.ConvTranspose2d(512, 256, 4, 2, 1)  # Output: (256, 15, 15)
        self.dec_conv3 = nn.ConvTranspose2d(256, 128, 4, 2, 1)  # Output: (128, 31, 31)
        self.dec_conv4 = nn.ConvTranspose2d(128, 64, 4, 2, 1)   # Output: (64, 63, 63)
        self.dec_conv5 = nn.ConvTranspose2d(64, 3, 4, 2, 1)     # Output: (3, 127, 127)

        # Adjust output size to (3, 116, 116)
        self.output_padding = nn.ReflectionPad2d((-5, -6, -5, -6))  # Crop to (3, 116, 116)

        # Dropout layer
        self.dropout = nn.Dropout(self.dropout_rate)

    def encode(self, x):
        x1 = F.relu(self.enc_conv1(x))
        x2 = F.relu(self.enc_conv2(x1))
        x3 = F.relu(self.enc_conv3(x2))
        x4 = F.relu(self.enc_conv4(x3))
        x5 = F.relu(self.enc_conv5(x4))
        x5 = x5.view(x.size(0), -1)
        x5 = self.dropout(x5)
        mu = self.fc_mu(x5)
        logvar = self.fc_logvar(x5)
        return mu, logvar

    def decode(self, z):
        x = F.relu(self.fc_decode(z))
        x = x.view(z.size(0), 512, 3, 3)
        x = F.relu(self.dec_conv1(x))
        x = F.relu(self.dec_conv2(x))
        x = F.relu(self.dec_conv3(x))
        x = F.relu(self.dec_conv4(x))
        x = torch.sigmoid(self.dec_conv5(x))
        x = F.interpolate(x, size=(116, 116), mode='bilinear', align_corners=False)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        recon_x = self.decode(z)
        return recon_x, mu, logvar, z


    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

# %%
def loss_function(recon_x, x, mu, logvar):
    # Reconstruction loss
    recon_loss = F.binary_cross_entropy(recon_x, x, reduction='sum')

    # KL Divergence
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return recon_loss + KLD

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create datasets
train_dataset = TensorDataset(train_data)
val_dataset = TensorDataset(val_data)
test_dataset = TensorDataset(test_data)

# Create data loaders
batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize model
latent_dim = 20  # You can adjust the size of the latent space
model = ConvVAE(latent_dim=latent_dim).to(device)

# Optimizer with L2 regularization (weight decay)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
# Out:
# Using device: cuda

# %%
# Early stopping parameters
early_stopping_patience = 10
best_val_loss = float('inf')
epochs_without_improvement = 0
model_save_path = os.path.join(project_dir, 'best_conv_vae_model.pth')

# %%
num_epochs = 100  # Increase the number of epochs
for epoch in range(1, num_epochs + 1):
    model.train()
    train_loss = 0
    for data in train_loader:
        x = data[0].to(device, dtype=torch.float)
        
        optimizer.zero_grad()
        recon_batch, mu, logvar, _ = model(x)
        print(f"Training Loop - x shape: {x.shape}, recon_batch shape: {recon_batch.shape}")
        loss = loss_function(recon_batch, x, mu, logvar)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    
    avg_train_loss = train_loss / len(train_loader.dataset)
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data in val_loader:
            x = data[0].to(device, dtype=torch.float)
            recon_batch, mu, logvar, _ = model(x)
            loss = loss_function(recon_batch, x, mu, logvar)
            val_loss += loss.item()
    avg_val_loss = val_loss / len(val_loader.dataset)
    
    print(f"Epoch {epoch}, Average Training Loss: {avg_train_loss:.4f}, Average Validation Loss: {avg_val_loss:.4f}")
    
    # Step the scheduler
    scheduler.step(avg_val_loss)
    
    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        # Save the model
        torch.save(model.state_dict(), model_save_path)
        print(f"Validation loss improved. Model saved to {model_save_path}")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= early_stopping_patience:
            print("Early stopping triggered.")
            break
# Out:
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 1, Average Training Loss: 52968.8003, Average Validation Loss: 22699.7062
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 2, Average Training Loss: 21901.0985, Average Validation Loss: 20921.4731
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 3, Average Training Loss: 20503.0804, Average Validation Loss: 20389.3819
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 4, Average Training Loss: 19868.0780, Average Validation Loss: 19639.4744
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 5, Average Training Loss: 19124.2952, Average Validation Loss: 18843.4700
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 6, Average Training Loss: 18534.5443, Average Validation Loss: 18579.3375
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 7, Average Training Loss: 18338.8284, Average Validation Loss: 18357.4950
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 8, Average Training Loss: 18087.0968, Average Validation Loss: 18063.6331
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 9, Average Training Loss: 17854.4663, Average Validation Loss: 17903.9719
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 10, Average Training Loss: 17653.5653, Average Validation Loss: 17722.9313
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 11, Average Training Loss: 17574.7009, Average Validation Loss: 17682.5681
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 12, Average Training Loss: 17542.5695, Average Validation Loss: 17726.7225
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 13, Average Training Loss: 17500.0268, Average Validation Loss: 17603.9206
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 14, Average Training Loss: 17445.2880, Average Validation Loss: 17611.3138
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 15, Average Training Loss: 17423.0309, Average Validation Loss: 17576.3175
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 16, Average Training Loss: 17417.2300, Average Validation Loss: 17643.3037
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 17, Average Training Loss: 17440.5435, Average Validation Loss: 17603.3500
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 18, Average Training Loss: 17401.4945, Average Validation Loss: 17506.0200
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 19, Average Training Loss: 17351.8764, Average Validation Loss: 17520.4950
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 20, Average Training Loss: 17338.5295, Average Validation Loss: 17492.6613
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 21, Average Training Loss: 17336.0416, Average Validation Loss: 17505.4244
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 22, Average Training Loss: 17333.4201, Average Validation Loss: 17433.6256
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 23, Average Training Loss: 17280.2371, Average Validation Loss: 17463.7925
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 24, Average Training Loss: 17268.9685, Average Validation Loss: 17408.2894
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 25, Average Training Loss: 17236.3048, Average Validation Loss: 17373.9225
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 26, Average Training Loss: 17208.9340, Average Validation Loss: 17359.1488
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 27, Average Training Loss: 17174.1870, Average Validation Loss: 17350.3119
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 28, Average Training Loss: 17166.8722, Average Validation Loss: 17291.9469
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 29, Average Training Loss: 17132.0603, Average Validation Loss: 17275.4637
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 30, Average Training Loss: 17111.5907, Average Validation Loss: 17259.7363
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 31, Average Training Loss: 17109.4889, Average Validation Loss: 17297.0481
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 32, Average Training Loss: 17098.8868, Average Validation Loss: 17279.4750
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 33, Average Training Loss: 17098.7126, Average Validation Loss: 17265.5681
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 34, Average Training Loss: 17093.2177, Average Validation Loss: 17250.1312
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 35, Average Training Loss: 17063.9433, Average Validation Loss: 17221.7631
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 36, Average Training Loss: 17045.8279, Average Validation Loss: 17202.8162
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 37, Average Training Loss: 17045.3742, Average Validation Loss: 17230.2544
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 38, Average Training Loss: 17038.9582, Average Validation Loss: 17189.7113
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 39, Average Training Loss: 17026.4203, Average Validation Loss: 17238.7287
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 40, Average Training Loss: 17043.5954, Average Validation Loss: 17186.6869
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 41, Average Training Loss: 17035.4744, Average Validation Loss: 17180.8000
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 42, Average Training Loss: 17022.4153, Average Validation Loss: 17152.8488
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 43, Average Training Loss: 17000.3357, Average Validation Loss: 17195.0144
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 44, Average Training Loss: 16993.0581, Average Validation Loss: 17141.4987
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 45, Average Training Loss: 16977.3338, Average Validation Loss: 17151.7069
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 46, Average Training Loss: 16970.6376, Average Validation Loss: 17135.7869
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 47, Average Training Loss: 16957.2239, Average Validation Loss: 17112.8400
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 48, Average Training Loss: 16945.3338, Average Validation Loss: 17117.0044
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# ...
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 84, Average Training Loss: 16787.7572, Average Validation Loss: 16955.7475
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 85, Average Training Loss: 16785.5097, Average Validation Loss: 16949.3681
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 86, Average Training Loss: 16786.4188, Average Validation Loss: 16951.4694
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 87, Average Training Loss: 16785.1595, Average Validation Loss: 16948.2300
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 88, Average Training Loss: 16783.0327, Average Validation Loss: 16947.3250
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 89, Average Training Loss: 16779.8439, Average Validation Loss: 16950.5163
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 90, Average Training Loss: 16779.9351, Average Validation Loss: 16945.7119
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 91, Average Training Loss: 16780.1270, Average Validation Loss: 16946.1875
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 92, Average Training Loss: 16777.7044, Average Validation Loss: 16944.3944
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 93, Average Training Loss: 16776.9859, Average Validation Loss: 16940.5750
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 94, Average Training Loss: 16776.7659, Average Validation Loss: 16943.1075
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 95, Average Training Loss: 16774.2789, Average Validation Loss: 16940.3319
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 96, Average Training Loss: 16774.3444, Average Validation Loss: 16941.2369
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 97, Average Training Loss: 16772.8498, Average Validation Loss: 16939.0375
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 98, Average Training Loss: 16770.1757, Average Validation Loss: 16939.1225
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 99, Average Training Loss: 16771.4415, Average Validation Loss: 16936.9200
# Validation loss improved. Model saved to /home/diego/Escritorio/azheimer/best_conv_vae_model.pth
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([32, 3, 116, 116]), recon_batch shape: torch.Size([32, 3, 116, 116])
# Training Loop - x shape: torch.Size([20, 3, 116, 116]), recon_batch shape: torch.Size([20, 3, 116, 116])
# Epoch 100, Average Training Loss: 16769.1383, Average Validation Loss: 16946.1044

# %%
model.eval()
test_loss = 0
with torch.no_grad():
    for data in test_loader:
        x = data[0].to(device, dtype=torch.float)
        recon_batch, mu, logvar, z = model(x)
        loss = loss_function(recon_batch, x, mu, logvar)
        test_loss += loss.item()
avg_test_loss = test_loss / len(test_loader.dataset)
print(f"Average Test Loss: {avg_test_loss:.4f}")
# Out:
# Average Test Loss: 16591.3675

# %%
import matplotlib.pyplot as plt

# Function to display original and reconstructed images
def visualize_reconstruction(model, data_loader):
    model.eval()
    with torch.no_grad():
        data = next(iter(data_loader))
        x = data[0].to(device, dtype=torch.float)
        recon_x, _, _ , _ = model(x)
        
        # Move tensors to CPU and convert to numpy
        x = x.cpu().numpy()
        recon_x = recon_x.cpu().numpy()
        
        n = min(x.shape[0], 5)  # Number of samples to display
        for i in range(n):
            fig, axes = plt.subplots(2, 3, figsize=(12, 6))
            for j in range(3):
                axes[0, j].imshow(x[i, j], cmap='viridis')
                axes[0, j].set_title(f'Original - Matrix {j+1}')
                axes[0, j].axis('off')
                axes[1, j].imshow(recon_x[i, j], cmap='viridis')
                axes[1, j].set_title(f'Reconstructed - Matrix {j+1}')
                axes[1, j].axis('off')
            plt.show()

# Visualize reconstructions on test data
visualize_reconstruction(model, test_loader)

# %%
# Save the trained model
model_save_path = os.path.join(project_dir, 'conv_vae_model.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /home/diego/Escritorio/azheimer/conv_vae_model.pth

# %%
# Load the model
model = ConvVAE(latent_dim=latent_dim).to(device)
model.load_state_dict(torch.load(model_save_path))
model.eval()
# Out:
# ConvVAE(
#   (enc_conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (enc_conv5): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (fc_mu): Linear(in_features=4608, out_features=20, bias=True)
#   (fc_logvar): Linear(in_features=4608, out_features=20, bias=True)
#   (fc_decode): Linear(in_features=20, out_features=4608, bias=True)
#   (dec_conv1): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (dec_conv5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (output_padding): ReflectionPad2d((-5, -6, -5, -6))
#   (dropout): Dropout(p=0.3, inplace=False)
# )
